# %% [markdown]
# # read PDFs, makeproject, extract images and create octrees

# %% [markdown]
# ### variables

# %%
# where is ami3? (assume you have checked out or copied `ami3` distrib).
# set AMI3 to location of LOCAL AMI repository
# EDIT THIS >>>>>>>
HOME = "/Users/pm286/"
WORKSPACE = HOME + "workspace/"
AMI3 = WORKSPACE + "cmdev/ami3/"
# <<<<<<<<<<

# local workspace
# EDIT this >>>>>>>>
WORK = WORKSPACE + "work/"
# <<<<<<<<<<

# specific problem
# EDIT THIS to your project (battery10, thermo at present)
# >>>>>>>
PROJECT = "steffen/llzo"
# <<<<<<<

PROJECT_WORK = WORK + PROJECT + "/"


# specific for projects under ami3/src/test/resources
# PROJECT_DATA = AMI_DATA + PROJECT + ".raw" + "/"
PROJECT_DATA = "/Users/pm286/projects/steffen"

# %%
print ("working in " + PROJECT_WORK)
! cd $PROJECT_WORK
! ls
print ("copying raw project " + PROJECT_DATA + " => " + PROJECT_WORK)
! cp -R $PROJECT_DATA $PROJECT_WORK
# Out:
# working in /Users/pm286/workspace/work/steffen/llzo/
# llzo             logs             pdf2octree.ipynb
# copying raw project /Users/pm286/projects/steffen => /Users/pm286/workspace/work/steffen/llzo/

# %%
import os 
os.getcwd()
os.listdir()
# Out:
# ['steffen',
#  'weppner2011',
#  'heitjans2012',
#  'figures.txt',
#  'make_project.json',
#  'vaughey2013',
#  'rettenwander2016',
#  'kilner2014',
#  'wang2015',
#  'larraz2015',
#  'janek2011']

# %%
## make project
# ! ami -p . makeproject --rawfiletypes pdf
! ls */*.pdf
! ls */*.xml
# Out:
# heitjans2012/fulltext.pdf     rettenwander2016/fulltext.pdf
# janek2011/fulltext.pdf        vaughey2013/fulltext.pdf
# kilner2014/fulltext.pdf       wang2015/fulltext.pdf
# larraz2015/fulltext.pdf       weppner2011/fulltext.pdf
# ls: */*.xml: No such file or directory

# %%
! ami -vv -p . pdfbox
# Out:
# (The console will show DEBUG level messages)
# (Logs will also be printed to /Users/pm286/workspace/work/steffen/llzo/logs/ami.log)
# Version: ami 2020.08.09_09.54-NEXT-SNAPSHOT
# (jar:file:/Users/pm286/workspace/cmdev/ami3/target/appassembler/repo/ami3-2020.08.09_09.54-NEXT-SNAPSHOT.jar)
# JVM: 14.0.1 (Oracle Corporation Java HotSpot(TM) 64-Bit Server VM 14.0.1+7)
# OS: Mac OS X 10.15.6 x86_64
#
#
# Generic values (AMIPDFTool)
# ================================
# input basename      null
# input basename list null
# cproject            /Users/pm286/workspace/work/steffen/llzo/.
# ctree
# cTreeList           10 trees [./heitjans2012, ./janek2011, ./kilner2014, ./larr
# excludeBase         {}
# excludeTrees        {}
# forceMake           false
# includeBase         {}
# includeTrees        null
# log4j               {}
# verbose             2
#
# Specific values (AMIPDFTool)
# ================================
# Command line options for 'ami pdfbox':
# --debug             : d AMI_BRIEF
# --imagedir          : d pdfimages/
# --maxpages          : d         5
# --maxprimitives     : d      5000
# --minimagesize      : d   (10,10)
# --pages             : d      null
# --parser            : d       two
# --no-pdfimages      : d      true
# --pdf2txt           : d     false
# --svgdir            : d      svg/
# --no-svgpages       : d      true
# --tidysvg           : d [concat, spaces]
# --help              : d     false
# --version           : d     false
# AMIPDFTool cTree: heitjans2012
# cTree: heitjans2012
# pi>include: [-1]
#
# make skipped AMIPDFTool cTree: janek2011
# cTree: janek2011
# pi>include: [-1]
#
# make skipped AMIPDFTool cTree: kilner2014
# cTree: kilner2014
# pi>include: [-1]
#
# make skipped AMIPDFTool cTree: larraz2015
# cTree: larraz2015
# pi>include: [-1]
#
# make skipped AMIPDFTool cTree: logs
# cTree: logs
# pi>include: [-1]
#
# AMIPDFTool cTree: rettenwander2016
# cTree: rettenwander2016
# pi>include: [-1]
#
# make skipped AMIPDFTool cTree: steffen
# cTree: steffen
# pi>include: [-1]
#
# AMIPDFTool cTree: vaughey2013
# cTree: vaughey2013
# pi>include: [-1]
#
# make skipped AMIPDFTool cTree: wang2015
# cTree: wang2015
# pi>include: [-1]
#
# make skipped AMIPDFTool cTree: weppner2011
# cTree: weppner2011
# pi>include: [-1]
#
# make skipped

# %%
! ami -vv -p .  --inputname raw --output octree image --octree 8 --outputfiles binary channels histogram neighbours octree
# Out:
# (The console will show DEBUG level messages)
# (Logs will also be printed to /Users/pm286/workspace/work/steffen/llzo/logs/ami.log)
# Version: ami 2020.08.09_09.54-NEXT-SNAPSHOT
# (jar:file:/Users/pm286/workspace/cmdev/ami3/target/appassembler/repo/ami3-2020.08.09_09.54-NEXT-SNAPSHOT.jar)
# JVM: 14.0.1 (Oracle Corporation Java HotSpot(TM) 64-Bit Server VM 14.0.1+7)
# OS: Mac OS X 10.15.6 x86_64
#
#
# Generic values (AMIImageTool)
# ================================
# input basename      raw
# input basename list null
# cproject            /Users/pm286/workspace/work/steffen/llzo/.
# ctree
# cTreeList           10 trees [./heitjans2012, ./janek2011, ./kilner2014, ./larr
# excludeBase         {}
# excludeTrees        {}
# forceMake           false
# includeBase         {}
# includeTrees        null
# log4j               {}
# verbose             2
#
# Specific values (AMIImageTool)
# ================================
# Command line options for 'ami image':
# --borders           : d      null
# --filter            : d     false
# --exclude           : d      null
# --include           : d      null
# --minheight         : d       100
# --minwidth          : d       100
# --annotate          : d     false
# --binarize          : d      null
# --despeckle         : d     false
# --dither            : d      true
# --erodedilate       : d     false
# --maxheight         : d      1000
# --maxwidth          : d      1000
# --mediancut         : d      null
# --merge             : d         0
# --minpixels         : d       100
# --octree            : m         8
# --outputfiles       : m [binary, channels, histogram, neighbours, octree]
# --panels            : d      null
# --posterize         : d      null
# --priority          : d       RAW
# --rotate            : d      null
# --scalefactor       : d      null
# --serpentine        : d      true
# --sharpen           : d      none
# --template          : d      null
# --thinning          : d      null
# --threshold         : d      null
# --toolkit           : d      null
# --help              : d     false
# --version           : d     false
# AMIImageTool cTree: heitjans2012
# AMIImageTool processTree
#  >>>>> imageDirs: 9
# T: 616792/W: 608605/NW: 8187
# *****OK...heitjans2012//image.3.1.67_294.51_207
# heitjans2012//image.3.1.67_294.51_207
# transforming: image.3.1.67_294.51_207/raw.png
# Freq: fdfdfd: 595058
# Freq: ec262c: 1542
# Freq: 2b3131: 17898
# Freq: 7a8287: 1404
# Freq: 1f53a4: 342
# Freq: 4b75b6: 274
# Freq: 002c90: 261
# neighbours: fdfdfd>  2b3131 ec262c 7a8287 1f53a4 4b75b6 002c90 f47c82
# 2b3131>  ec262c 7a8287 1f53a4 4b75b6 002c90 f47c82
# ec262c>  7a8287 1f53a4 4b75b6 002c90 f47c82
# 7a8287>  1f53a4 4b75b6 002c90 f47c82
# 1f53a4>  4b75b6 002c90 f47c82
# 4b75b6>  002c90 f47c82
# 002c90>  f47c82
#
# htmlFile ./heitjans2012/pdfimages/image.3.1.67_294.51_207/images.html
# T: 1995721/W: 1910472/NW: 85249
# *****OK...heitjans2012//image.3.2.110_515.425_709
# heitjans2012//image.3.2.110_515.425_709
# transforming: image.3.2.110_515.425_709/raw.png
# Freq: 080c09: 88328
# Freq: f17d82: 424
# Freq: fafcfc: 1895325
# Freq: e21f22: 7512
# Freq: 164ac2: 1016
# Freq: 52acaf: 1472
# Freq: 079c39: 1621
# neighbours: fafcfc>  080c09 e21f22 079c39 52acaf 164ac2 f17d82 81807e
# 080c09>  e21f22 079c39 52acaf 164ac2 f17d82 81807e
# e21f22>  079c39 52acaf 164ac2 f17d82 81807e
# 079c39>  52acaf 164ac2 f17d82 81807e
# 52acaf>  164ac2 f17d82 81807e
# 164ac2>  f17d82 81807e
# f17d82>  81807e
#
# htmlFile ./heitjans2012/pdfimages/image.3.2.110_515.425_709/images.html
# T: 2101411/W: 2082881/NW: 18530
# *****OK...heitjans2012//image.4.1.135_490.51_391
# heitjans2012//image.4.1.135_490.51_391
# transforming: image.4.1.135_490.51_391/raw.png
# Freq: fbfcfc: 2036443
# Freq: 1559a6: 990
# Freq: 09a54f: 4176
# Freq: 2d3636: 51635
# Freq: ee3e45: 5791
# Freq: 719c90: 2316
# neighbours: fbfcfc>  2d3636 ee3e45 09a54f 719c90 1559a6 ec7c81
# 2d3636>  ee3e45 09a54f 719c90 1559a6 ec7c81
# ee3e45>  09a54f 719c90 1559a6 ec7c81
# 09a54f>  719c90 1559a6 ec7c81
# 719c90>  1559a6 ec7c81
# 1559a6>  ec7c81
#
# htmlFile ./heitjans2012/pdfimages/image.4.1.135_490.51_391/images.html
# T: 1601099/W: 1571879/NW: 29220
# *****OK...heitjans2012//image.5.1.128_497.51_300
# heitjans2012//image.5.1.128_497.51_300
# transforming: image.5.1.128_497.51_300/raw.png
# Freq: ea242c: 2654
# Freq: 38469c: 1053
# Freq: 09a44e: 3072
# Freq: fcfcfc: 1548951
# Freq: 68b796: 727
# Freq: 201f1f: 44598
# neighbours: fcfcfc>  201f1f 09a44e ea242c 38469c 68b796 dd7c81 81807f
# 201f1f>  09a44e ea242c 38469c 68b796 dd7c81 81807f
# 09a44e>  ea242c 38469c 68b796 dd7c81 81807f
# ea242c>  38469c 68b796 dd7c81 81807f
# 38469c>  68b796 dd7c81 81807f
# 68b796>  dd7c81 81807f
# dd7c81>  81807f
#
# htmlFile ./heitjans2012/pdfimages/image.5.1.128_497.51_300/images.html
# T: 405756/W: 392258/NW: 13498
# *****OK...heitjans2012//image.6.1.96_265.51_189
# heitjans2012//image.6.1.96_265.51_189
# transforming: image.6.1.96_265.51_189/raw.png
# Freq: 08a349: 1208
# Freq: fdfdfd: 383804
# Freq: eb1f2a: 1960
# Freq: 1a1a1a: 17085
# Freq: 1f3e9a: 1449
# Freq: 62c196: 243
# neighbours: fdfdfd>  1a1a1a eb1f2a 1f3e9a 08a349 62c196 a17c81 909877
# 1a1a1a>  eb1f2a 1f3e9a 08a349 62c196 a17c81 909877
# eb1f2a>  1f3e9a 08a349 62c196 a17c81 909877
# 1f3e9a>  08a349 62c196 a17c81 909877
# 08a349>  62c196 a17c81 909877
# 62c196>  a17c81 909877
# a17c81>  909877
#
# htmlFile ./heitjans2012/pdfimages/image.6.1.96_265.51_189/images.html
# T: 1377590/W: 1364330/NW: 13260
# *****OK...heitjans2012//image.6.2.104_521.498_689
# heitjans2012//image.6.2.104_521.498_689
# transforming: image.6.2.104_521.498_689/raw.png
# Freq: fcfcfd: 1335368
# Freq: 303636: 33727
# Freq: ed353c: 3738
# Freq: 6f9e97: 1584
# Freq: 0e55a5: 1077
# Freq: 13a64e: 2002
# neighbours: fcfcfd>  303636 ed353c 13a64e 6f9e97 0e55a5 e27d81
# 303636>  ed353c 13a64e 6f9e97 0e55a5 e27d81
# ed353c>  13a64e 6f9e97 0e55a5 e27d81
# 13a64e>  6f9e97 0e55a5 e27d81
# 6f9e97>  0e55a5 e27d81
# 0e55a5>  e27d81
#
# htmlFile ./heitjans2012/pdfimages/image.6.2.104_521.498_689/images.html
# T: 1509741/W: 1486070/NW: 23671
# *****OK...heitjans2012//image.7.1.90_535.51_246
# heitjans2012//image.7.1.90_535.51_246
# transforming: image.7.1.90_535.51_246/raw.png
# Freq: fcfcfd: 1465402
# Freq: e93339: 3315
# Freq: 222121: 37308
# Freq: 33acd2: 1842
# Freq: 0ea64c: 1806
# neighbours: fcfcfd>  222121 e93339 33acd2 0ea64c 117cc5 b87e80
# 222121>  e93339 33acd2 0ea64c 117cc5 b87e80
# e93339>  33acd2 0ea64c 117cc5 b87e80
# 33acd2>  0ea64c 117cc5 b87e80
# 0ea64c>  117cc5 b87e80
# 117cc5>  b87e80
#
# htmlFile ./heitjans2012/pdfimages/image.7.1.90_535.51_246/images.html
# T: 1114560/W: 1105412/NW: 9148
# *****OK...heitjans2012//image.8.1.127_498.51_224
# heitjans2012//image.8.1.127_498.51_224
# transforming: image.8.1.127_498.51_224/raw.png
# Freq: fefdfd: 1088550
# Freq: e9313c: 543
# Freq: 2b3131: 24940
# Freq: 7c8282: 493
# neighbours: fefdfd>  2b3131 e9313c 7c8282 f57c83 817f80
# 2b3131>  e9313c 7c8282 f57c83 817f80
# e9313c>  7c8282 f57c83 817f80
# 7c8282>  f57c83 817f80
# f57c83>  817f80
#
# htmlFile ./heitjans2012/pdfimages/image.8.1.127_498.51_224/images.html
# T: 599038/W: 596173/NW: 2865
# *****OK...heitjans2012//image.8.2.348_541.510_689
# heitjans2012//image.8.2.348_541.510_689
# transforming: image.8.2.348_541.510_689/raw.png
# Freq: fefefe: 578455
# Freq: 7a848f: 284
# Freq: e2222c: 741
# Freq: 363a3a: 19058
# Freq: 26459a: 495
# neighbours: fefefe>  363a3a e2222c 26459a 7a848f 65807e 817f80
# 363a3a>  e2222c 26459a 7a848f 65807e 817f80
# e2222c>  26459a 7a848f 65807e 817f80
# 26459a>  7a848f 65807e 817f80
# 7a848f>  65807e 817f80
# 65807e>  817f80
#
# htmlFile ./heitjans2012/pdfimages/image.8.2.348_541.510_689/images.html
# AMIImageTool cTree: janek2011
# AMIImageTool processTree
#  >>>>> imageDirs: 7
# T: 868399/W: 862832/NW: 5567
# *****OK...janek2011//image.11.1.57_284.78_298
# janek2011//image.11.1.57_284.78_298
# transforming: image.11.1.57_284.78_298/raw.png
# Freq: 7c7e80: 128
# Freq: fcfcfa: 815984
# Freq: 2c292a: 45756
# Freq: de3639: 6085
# Freq: de8678: 204
# Freq: 7e8082: 220
# neighbours: fcfcfa>  2c292a de3639 7e8082 de8678 7c7e80 b47c82 72807d
# 2c292a>  de3639 7e8082 de8678 7c7e80 b47c82 72807d
# de3639>  7e8082 de8678 7c7e80 b47c82 72807d
# 7e8082>  de8678 7c7e80 b47c82 72807d
# de8678>  7c7e80 b47c82 72807d
# 7c7e80>  b47c82 72807d
# b47c82>  72807d
#
# htmlFile ./janek2011/pdfimages/image.11.1.57_284.78_298/images.html
# T: 715737/W: 715101/NW: 636
# *****OK...janek2011//image.11.2.312_538.78_260
# janek2011//image.11.2.312_538.78_260
# transforming: image.11.2.312_538.78_260/raw.png
# Freq: 7d7e80: 114
# Freq: fefdfc: 696130
# Freq: eb8677: 137
# Freq: 312e2f: 16448
# Freq: 7e8082: 151
# Freq: e5383b: 2752
# neighbours: fefdfc>  312e2f e5383b 7e8082 eb8677 7d7e80 cf7b82 86807e
# 312e2f>  e5383b 7e8082 eb8677 7d7e80 cf7b82 86807e
# e5383b>  7e8082 eb8677 7d7e80 cf7b82 86807e
# 7e8082>  eb8677 7d7e80 cf7b82 86807e
# eb8677>  7d7e80 cf7b82 86807e
# 7d7e80>  cf7b82 86807e
# cf7b82>  86807e
#
# htmlFile ./janek2011/pdfimages/image.11.2.312_538.78_260/images.html
# T: 2671383/W: 2671321/NW: 62
# *****OK...janek2011//image.12.1.75_521.339_683
# janek2011//image.12.1.75_521.339_683
# transforming: image.12.1.75_521.339_683/raw.png
# Freq: 3b393b: 52992
# Freq: df8c6a: 181
# Freq: fdfdfb: 2615432
# Freq: d84940: 716
# Freq: 4d5d97: 1590
# Freq: 7e8084: 445
# neighbours: fdfdfb>  3b393b 4d5d97 d84940 7e8084 df8c6a 967092 7d807f
# 3b393b>  4d5d97 d84940 7e8084 df8c6a 967092 7d807f
# 4d5d97>  d84940 7e8084 df8c6a 967092 7d807f
# d84940>  7e8084 df8c6a 967092 7d807f
# 7e8084>  df8c6a 967092 7d807f
# df8c6a>  967092 7d807f
# 967092>  7d807f
#
# htmlFile ./janek2011/pdfimages/image.12.1.75_521.339_683/images.html
# T: 2791530/W: 2599953/NW: 191577
# *****OK...janek2011//image.4.2.312_539.506_683
# janek2011//image.4.2.312_539.506_683
# transforming: image.4.2.312_539.506_683/raw.png
# Freq: ffffff: 2599953
# Freq: 000000: 191577
# neighbours: ffffff>  000000
#
# htmlFile ./janek2011/pdfimages/image.4.2.312_539.506_683/images.html
# T: 1940841/W: 1873205/NW: 67636
# *****OK...janek2011//image.5.1.91_250.78_255
# janek2011//image.5.1.91_250.78_255
# transforming: image.5.1.91_250.78_255/raw.png
# Freq: ffffff: 1873205
# Freq: 000000: 67636
# neighbours: ffffff>  000000
#
# htmlFile ./janek2011/pdfimages/image.5.1.91_250.78_255/images.html
# T: 1096794/W: 1059624/NW: 37170
# *****OK...janek2011//image.5.2.364_487.78_207
# janek2011//image.5.2.364_487.78_207
# transforming: image.5.2.364_487.78_207/raw.png
# Freq: ffffff: 1059624
# Freq: 000000: 37170
# neighbours: ffffff>  000000
#
# htmlFile ./janek2011/pdfimages/image.5.2.364_487.78_207/images.html
# T: 1790895/W: 1696470/NW: 94425
# *****OK...janek2011//image.7.1.58_538.409_623
# janek2011//image.7.1.58_538.409_623
# transforming: image.7.1.58_538.409_623/raw.png
# Freq: 6f6f6f: 17214
# Freq: 050505: 103775
# Freq: fefefe: 1571757
# Freq: 4e4e4e: 19753
# Freq: d0d0d0: 17548
# Freq: b0b0b0: 18080
# Freq: 909090: 17979
# Freq: 303030: 24789
# neighbours: fefefe>  050505 303030 4e4e4e b0b0b0 909090 d0d0d0 6f6f6f
# 050505>  303030 4e4e4e b0b0b0 909090 d0d0d0 6f6f6f
# 303030>  4e4e4e b0b0b0 909090 d0d0d0 6f6f6f
# 4e4e4e>  b0b0b0 909090 d0d0d0 6f6f6f
# b0b0b0>  909090 d0d0d0 6f6f6f
# 909090>  d0d0d0 6f6f6f
# d0d0d0>  6f6f6f
#
# htmlFile ./janek2011/pdfimages/image.7.1.58_538.409_623/images.html
# AMIImageTool cTree: kilner2014
# AMIImageTool processTree
#  >>>>> imageDirs: 5
# T: 595698/W: 558533/NW: 37165
# *****OK...kilner2014//image.3.1.326_562.128_273
# kilner2014//image.3.1.326_562.128_273
# transforming: image.3.1.326_562.128_273/raw.png
# Freq: fdfdfd: 550993
# Freq: 0d0d0d: 15474
# Freq: 07b155: 7670
# Freq: fa0b0a: 9739
# Freq: 439fc0: 2183
# Freq: 0070bf: 9593
# neighbours: fdfdfd>  0d0d0d fa0b0a 0070bf 07b155 439fc0 839668 806d95
# 0d0d0d>  fa0b0a 0070bf 07b155 439fc0 839668 806d95
# fa0b0a>  0070bf 07b155 439fc0 839668 806d95
# 0070bf>  07b155 439fc0 839668 806d95
# 07b155>  439fc0 839668 806d95
# 439fc0>  839668 806d95
# 839668>  806d95
#
# htmlFile ./kilner2014/pdfimages/image.3.1.326_562.128_273/images.html
# T: 744786/W: 713423/NW: 31363
# *****OK...kilner2014//image.4.2.329_560.51_236
# kilner2014//image.4.2.329_560.51_236
# transforming: image.4.2.329_560.51_236/raw.png
# Freq: fdfdfd: 704542
# Freq: 8064a2: 792
# Freq: 4e90be: 2776
# Freq: 07b254: 3540
# Freq: 0c0b0b: 25725
# Freq: 0170c0: 3479
# Freq: f70a0a: 3932
# neighbours: fdfdfd>  0c0b0b f70a0a 07b254 0170c0 4e90be 8064a2
# 0c0b0b>  f70a0a 07b254 0170c0 4e90be 8064a2
# f70a0a>  07b254 0170c0 4e90be 8064a2
# 07b254>  0170c0 4e90be 8064a2
# 0170c0>  4e90be 8064a2
# 4e90be>  8064a2
#
# htmlFile ./kilner2014/pdfimages/image.4.2.329_560.51_236/images.html
# T: 306590/W: 292521/NW: 14069
# *****OK...kilner2014//image.5.1.95_266.51_154
# kilner2014//image.5.1.95_266.51_154
# transforming: image.5.1.95_266.51_154/raw.png
# Freq: 563ea4: 2110
# Freq: 48bcaf: 570
# Freq: fcfcfc: 281495
# Freq: 09b052: 2476
# Freq: ed1818: 4296
# Freq: 1f2125: 15568
# neighbours: fcfcfc>  1f2125 ed1818 09b052 563ea4 48bcaf 905bb1 c4836d
# 1f2125>  ed1818 09b052 563ea4 48bcaf 905bb1 c4836d
# ed1818>  09b052 563ea4 48bcaf 905bb1 c4836d
# 09b052>  563ea4 48bcaf 905bb1 c4836d
# 563ea4>  48bcaf 905bb1 c4836d
# 48bcaf>  905bb1 c4836d
# 905bb1>  c4836d
#
# htmlFile ./kilner2014/pdfimages/image.5.1.95_266.51_154/images.html
# T: 583590/W: 569927/NW: 13663
# *****OK...kilner2014//image.5.2.85_276.512_689
# kilner2014//image.5.2.85_276.512_689
# transforming: image.5.2.85_276.512_689/raw.png
# Freq: a1a1a1: 9708
# Freq: 616161: 10484
# Freq: ff2f2f: 974
# Freq: ff5e5e: 1310
# Freq: fefefe: 537397
# Freq: 141414: 18520
# Freq: ff0505: 3818
# Freq: ffa2a2: 1379
# neighbours: fefefe>  141414 616161 a1a1a1 ff0505 ffa2a2 ff5e5e ff2f2f
# 141414>  616161 a1a1a1 ff0505 ffa2a2 ff5e5e ff2f2f
# 616161>  a1a1a1 ff0505 ffa2a2 ff5e5e ff2f2f
# a1a1a1>  ff0505 ffa2a2 ff5e5e ff2f2f
# ff0505>  ffa2a2 ff5e5e ff2f2f
# ffa2a2>  ff5e5e ff2f2f
# ff5e5e>  ff2f2f
#
# htmlFile ./kilner2014/pdfimages/image.5.2.85_276.512_689/images.html
# T: 22863552/W: 22172812/NW: 690740
# *****OK...kilner2014//image.6.1.88_273.51_495
# kilner2014//image.6.1.88_273.51_495
# transforming: image.6.1.88_273.51_495/raw.png
# Freq: 3d3d3d: 22172812
# Freq: 000000: 690740
# neighbours: 3d3d3d>  000000
#
# htmlFile ./kilner2014/pdfimages/image.6.1.88_273.51_495/images.html
# AMIImageTool cTree: larraz2015
# AMIImageTool processTree
#  >>>>> imageDirs: 8
# T: 734536/W: 719322/NW: 15214
# *****OK...larraz2015//image.3.1.310_546.71_250
# larraz2015//image.3.1.310_546.71_250
# transforming: image.3.1.310_546.71_250/raw.png
# Freq: d1d1d1: 7761
# Freq: 6f6f6f: 4798
# Freq: 090909: 19950
# Freq: 8f8f8f: 5029
# Freq: fefefe: 673643
# Freq: 303030: 10396
# Freq: b0b0b0: 5770
# Freq: 505050: 7189
# neighbours: fefefe>  090909 303030 d1d1d1 505050 b0b0b0 8f8f8f 6f6f6f
# 090909>  303030 d1d1d1 505050 b0b0b0 8f8f8f 6f6f6f
# 303030>  d1d1d1 505050 b0b0b0 8f8f8f 6f6f6f
# d1d1d1>  505050 b0b0b0 8f8f8f 6f6f6f
# 505050>  b0b0b0 8f8f8f 6f6f6f
# b0b0b0>  8f8f8f 6f6f6f
# 8f8f8f>  6f6f6f
#
# htmlFile ./larraz2015/pdfimages/image.3.1.310_546.71_250/images.html
# T: 832736/W: 814921/NW: 17815
# *****OK...larraz2015//image.3.2.310_546.478_681
# larraz2015//image.3.2.310_546.478_681
# transforming: image.3.2.310_546.478_681/raw.png
# Freq: adadad: 7509
# Freq: d1d1d1: 9611
# Freq: 2f2f2f: 10592
# Freq: 4f4f4f: 8269
# Freq: fefefe: 758125
# Freq: 8e8e8e: 9455
# Freq: 707070: 8116
# Freq: 080808: 21059
# neighbours: fefefe>  080808 2f2f2f d1d1d1 8e8e8e 4f4f4f 707070 adadad
# 080808>  2f2f2f d1d1d1 8e8e8e 4f4f4f 707070 adadad
# 2f2f2f>  d1d1d1 8e8e8e 4f4f4f 707070 adadad
# d1d1d1>  8e8e8e 4f4f4f 707070 adadad
# 8e8e8e>  4f4f4f 707070 adadad
# 4f4f4f>  707070 adadad
# 707070>  adadad
#
# htmlFile ./larraz2015/pdfimages/image.3.2.310_546.478_681/images.html
# T: 812114/W: 800460/NW: 11654
# *****OK...larraz2015//image.4.1.310_546.71_269
# larraz2015//image.4.1.310_546.71_269
# transforming: image.4.1.310_546.71_269/raw.png
# Freq: 050505: 12787
# Freq: 717171: 3262
# Freq: 2d2d2d: 4162
# Freq: fefefe: 776788
# Freq: cecece: 3886
# Freq: 8e8e8e: 4808
# Freq: 4e4e4e: 3152
# Freq: aeaeae: 3269
# neighbours: fefefe>  050505 8e8e8e 2d2d2d cecece aeaeae 717171 4e4e4e
# 050505>  8e8e8e 2d2d2d cecece aeaeae 717171 4e4e4e
# 8e8e8e>  2d2d2d cecece aeaeae 717171 4e4e4e
# 2d2d2d>  cecece aeaeae 717171 4e4e4e
# cecece>  aeaeae 717171 4e4e4e
# aeaeae>  717171 4e4e4e
# 717171>  4e4e4e
#
# htmlFile ./larraz2015/pdfimages/image.4.1.310_546.71_269/images.html
# T: 811132/W: 797374/NW: 13758
# *****OK...larraz2015//image.5.1.49_285.71_269
# larraz2015//image.5.1.49_285.71_269
# transforming: image.5.1.49_285.71_269/raw.png
# Freq: d1d1d1: 5908
# Freq: adadad: 4323
# Freq: 8f8f8f: 3339
# Freq: 2d2d2d: 4771
# Freq: 070707: 16444
# Freq: 535353: 5252
# Freq: fefefe: 765703
# Freq: 707070: 5392
# neighbours: fefefe>  070707 d1d1d1 707070 535353 2d2d2d adadad 8f8f8f
# 070707>  d1d1d1 707070 535353 2d2d2d adadad 8f8f8f
# d1d1d1>  707070 535353 2d2d2d adadad 8f8f8f
# 707070>  535353 2d2d2d adadad 8f8f8f
# 535353>  2d2d2d adadad 8f8f8f
# 2d2d2d>  adadad 8f8f8f
# adadad>  8f8f8f
#
# htmlFile ./larraz2015/pdfimages/image.5.1.49_285.71_269/images.html
# T: 734536/W: 726655/NW: 7881
# *****OK...larraz2015//image.6.1.49_285.542_721
# larraz2015//image.6.1.49_285.542_721
# transforming: image.6.1.49_285.542_721/raw.png
# Freq: 8f8f8f: 1095
# Freq: b3b3b3: 2034
# Freq: cdcdcd: 4142
# Freq: fefefe: 709991
# Freq: 060606: 8965
# Freq: 6e6e6e: 1044
# Freq: 2c2c2c: 3896
# Freq: 505050: 3369
# neighbours: fefefe>  060606 cdcdcd 2c2c2c 505050 b3b3b3 8f8f8f 6e6e6e
# 060606>  cdcdcd 2c2c2c 505050 b3b3b3 8f8f8f 6e6e6e
# cdcdcd>  2c2c2c 505050 b3b3b3 8f8f8f 6e6e6e
# 2c2c2c>  505050 b3b3b3 8f8f8f 6e6e6e
# 505050>  b3b3b3 8f8f8f 6e6e6e
# b3b3b3>  8f8f8f 6e6e6e
# 8f8f8f>  6e6e6e
#
# htmlFile ./larraz2015/pdfimages/image.6.1.49_285.542_721/images.html
# T: 819970/W: 808634/NW: 11336
# *****OK...larraz2015//image.6.2.310_546.511_711
# larraz2015//image.6.2.310_546.511_711
# transforming: image.6.2.310_546.511_711/raw.png
# Freq: afafaf: 5396
# Freq: 919191: 5555
# Freq: 6f6f6f: 3469
# Freq: 4d4d4d: 3433
# Freq: 090909: 14462
# Freq: fefefe: 776726
# Freq: cecece: 5324
# Freq: 303030: 5605
# neighbours: fefefe>  090909 303030 919191 afafaf cecece 6f6f6f 4d4d4d
# 090909>  303030 919191 afafaf cecece 6f6f6f 4d4d4d
# 303030>  919191 afafaf cecece 6f6f6f 4d4d4d
# 919191>  afafaf cecece 6f6f6f 4d4d4d
# afafaf>  cecece 6f6f6f 4d4d4d
# cecece>  6f6f6f 4d4d4d
# 6f6f6f>  4d4d4d
#
# htmlFile ./larraz2015/pdfimages/image.6.2.310_546.511_711/images.html
# T: 814078/W: 803124/NW: 10954
# *****OK...larraz2015//image.7.1.49_285.308_507
# larraz2015//image.7.1.49_285.308_507
# transforming: image.7.1.49_285.308_507/raw.png
# Freq: 6b6b6b: 3975
# Freq: 8d8d8d: 2254
# Freq: fefefe: 786181
# Freq: aeaeae: 2505
# Freq: 4e4e4e: 2867
# Freq: cecece: 1982
# Freq: 060606: 12251
# Freq: 2c2c2c: 2063
# neighbours: fefefe>  060606 6b6b6b 4e4e4e aeaeae 8d8d8d 2c2c2c cecece
# 060606>  6b6b6b 4e4e4e aeaeae 8d8d8d 2c2c2c cecece
# 6b6b6b>  4e4e4e aeaeae 8d8d8d 2c2c2c cecece
# 4e4e4e>  aeaeae 8d8d8d 2c2c2c cecece
# aeaeae>  8d8d8d 2c2c2c cecece
# 8d8d8d>  2c2c2c cecece
# 2c2c2c>  cecece
#
# htmlFile ./larraz2015/pdfimages/image.7.1.49_285.308_507/images.html
# T: 1051484/W: 1032240/NW: 19244
# *****OK...larraz2015//image.7.2.106_489.563_721
# larraz2015//image.7.2.106_489.563_721
# transforming: image.7.2.106_489.563_721/raw.png
# Freq: cfcfcf: 6649
# Freq: 8f8f8f: 3130
# Freq: 6f6f6f: 2771
# Freq: 4f4f4f: 3103
# Freq: fefefe: 1004660
# Freq: b2b2b2: 4781
# Freq: 060606: 22811
# Freq: 2e2e2e: 3579
# neighbours: fefefe>  060606 cfcfcf b2b2b2 2e2e2e 8f8f8f 4f4f4f 6f6f6f
# 060606>  cfcfcf b2b2b2 2e2e2e 8f8f8f 4f4f4f 6f6f6f
# cfcfcf>  b2b2b2 2e2e2e 8f8f8f 4f4f4f 6f6f6f
# b2b2b2>  2e2e2e 8f8f8f 4f4f4f 6f6f6f
# 2e2e2e>  8f8f8f 4f4f4f 6f6f6f
# 8f8f8f>  4f4f4f 6f6f6f
# 4f4f4f>  6f6f6f
#
# htmlFile ./larraz2015/pdfimages/image.7.2.106_489.563_721/images.html
# AMIImageTool cTree: logs
# AMIImageTool processTree
# no pdfimages/ dir and no image/ dir
# AMIImageTool cTree: rettenwander2016
# AMIImageTool processTree
#  >>>>> imageDirs: 5
# T: 199430/W: 199378/NW: 52
# *****OK...rettenwander2016//image.4.2.52_288.91_286
# rettenwander2016//image.4.2.52_288.91_286
# transforming: image.4.2.52_288.91_286/raw.png
# Freq: 605e92: 1202
# Freq: 628e61: 1094
# Freq: a29477: 619
# Freq: 3e403c: 12065
# Freq: b15955: 1655
# Freq: 907399: 149
# Freq: f9f9f8: 182600
# neighbours: f9f9f8>  3e403c b15955 605e92 628e61 a29477 907399 71958d
# 3e403c>  b15955 605e92 628e61 a29477 907399 71958d
# b15955>  605e92 628e61 a29477 907399 71958d
# 605e92>  628e61 a29477 907399 71958d
# 628e61>  a29477 907399 71958d
# a29477>  907399 71958d
# 907399>  71958d
#
# htmlFile ./rettenwander2016/pdfimages/image.4.2.52_288.91_286/images.html
# T: 178360/W: 178360/NW: 0
# *****OK...rettenwander2016//image.6.1.308_543.481_656
# rettenwander2016//image.6.1.308_543.481_656
# transforming: image.6.1.308_543.481_656/raw.png
# Freq: f3f3f3: 170573
# Freq: 535693: 5058
# Freq: 4a4856: 2515
# neighbours: f3f3f3>  535693 4a4856 827ca6 827b78 7c81ba 88817e 7e87c1
# 535693>  4a4856 827ca6 827b78 7c81ba 88817e 7e87c1
# 4a4856>  827ca6 827b78 7c81ba 88817e 7e87c1
# 827ca6>  827b78 7c81ba 88817e 7e87c1
# 827b78>  7c81ba 88817e 7e87c1
# 7c81ba>  88817e 7e87c1
# 88817e>  7e87c1
#
# htmlFile ./rettenwander2016/pdfimages/image.6.1.308_543.481_656/images.html
# T: 329770/W: 328842/NW: 928
# *****OK...rettenwander2016//image.6.2.308_543.91_414
# rettenwander2016//image.6.2.308_543.91_414
# transforming: image.6.2.308_543.91_414/raw.png
# Freq: 8775a8: 461
# Freq: fafaf9: 309941
# Freq: 309d53: 2332
# Freq: c25645: 796
# Freq: cd9c45: 2492
# Freq: 51468c: 3805
# Freq: 47445b: 9698
# Freq: 63a98f: 245
# neighbours: fafaf9>  47445b 51468c cd9c45 309d53 c25645 8775a8 63a98f
# 47445b>  51468c cd9c45 309d53 c25645 8775a8 63a98f
# 51468c>  cd9c45 309d53 c25645 8775a8 63a98f
# cd9c45>  309d53 c25645 8775a8 63a98f
# 309d53>  c25645 8775a8 63a98f
# c25645>  8775a8 63a98f
# 8775a8>  63a98f
#
# htmlFile ./rettenwander2016/pdfimages/image.6.2.308_543.91_414/images.html
# T: 513588/W: 498111/NW: 15477
# *****OK...rettenwander2016//image.7.1.303_547.252_737
# rettenwander2016//image.7.1.303_547.252_737
# transforming: image.7.1.303_547.252_737/raw.png
# Freq: afafaf: 2706
# Freq: 8f8f8f: 2872
# Freq: 6f6f6f: 2817
# Freq: 4f4f4f: 2737
# Freq: fefefe: 479090
# Freq: 060606: 16667
# Freq: 2e2e2e: 3229
# Freq: d0d0d0: 3470
# neighbours: fefefe>  060606 d0d0d0 2e2e2e 8f8f8f 6f6f6f 4f4f4f afafaf
# 060606>  d0d0d0 2e2e2e 8f8f8f 6f6f6f 4f4f4f afafaf
# d0d0d0>  2e2e2e 8f8f8f 6f6f6f 4f4f4f afafaf
# 2e2e2e>  8f8f8f 6f6f6f 4f4f4f afafaf
# 8f8f8f>  6f6f6f 4f4f4f afafaf
# 6f6f6f>  4f4f4f afafaf
# 4f4f4f>  afafaf
#
# htmlFile ./rettenwander2016/pdfimages/image.7.1.303_547.252_737/images.html
# T: 242550/W: 242550/NW: 0
# *****OK...rettenwander2016//image.7.2.52_288.488_726
# rettenwander2016//image.7.2.52_288.488_726
# transforming: image.7.2.52_288.488_726/raw.png
# Freq: 877497: 240
# Freq: 847b77: 151
# Freq: fcfcfb: 237180
# Freq: 50494a: 4464
# Freq: 746589: 435
# neighbours: fcfcfb>  50494a 746589 877497 847b77 89817d
# 50494a>  746589 877497 847b77 89817d
# 746589>  877497 847b77 89817d
# 877497>  847b77 89817d
# 847b77>  89817d
#
# htmlFile ./rettenwander2016/pdfimages/image.7.2.52_288.488_726/images.html
# AMIImageTool cTree: steffen
# AMIImageTool processTree
# no pdfimages/ dir and no image/ dir
# AMIImageTool cTree: vaughey2013
# AMIImageTool processTree
#  >>>>> imageDirs: 7
# T: 834700/W: 833634/NW: 1066
# *****OK...vaughey2013//image.3.1.49_285.71_275
# vaughey2013//image.3.1.49_285.71_275
# transforming: image.3.1.49_285.71_275/raw.png
# Freq: 546395: 5505
# Freq: fafafa: 806136
# Freq: c57697: 1867
# Freq: c65a63: 2751
# Freq: 6ba69e: 3325
# Freq: 3d4248: 12033
# Freq: 34966a: 3075
# neighbours: fafafa>  3d4248 546395 6ba69e 34966a c65a63 c57697 e1817c
# 3d4248>  546395 6ba69e 34966a c65a63 c57697 e1817c
# 546395>  6ba69e 34966a c65a63 c57697 e1817c
# 6ba69e>  34966a c65a63 c57697 e1817c
# 34966a>  c65a63 c57697 e1817c
# c65a63>  c57697 e1817c
# c57697>  e1817c
#
# htmlFile ./vaughey2013/pdfimages/image.3.1.49_285.71_275/images.html
# T: 1000658/W: 987890/NW: 12768
# *****OK...vaughey2013//image.3.2.49_285.351_596
# vaughey2013//image.3.2.49_285.351_596
# transforming: image.3.2.49_285.351_596/raw.png
# Freq: fdfdfd: 953975
# Freq: 525992: 5427
# Freq: bf689b: 4607
# Freq: 71a195: 1363
# Freq: 25292d: 28009
# Freq: 1f8c56: 3367
# Freq: d7474d: 3892
# neighbours: fdfdfd>  25292d 525992 bf689b d7474d 1f8c56 71a195 dc827c
# 25292d>  525992 bf689b d7474d 1f8c56 71a195 dc827c
# 525992>  bf689b d7474d 1f8c56 71a195 dc827c
# bf689b>  d7474d 1f8c56 71a195 dc827c
# d7474d>  1f8c56 71a195 dc827c
# 1f8c56>  71a195 dc827c
# 71a195>  dc827c
#
# htmlFile ./vaughey2013/pdfimages/image.3.2.49_285.351_596/images.html
# T: 885764/W: 876167/NW: 9597
# *****OK...vaughey2013//image.3.3.310_546.230_446
# vaughey2013//image.3.3.310_546.230_446
# transforming: image.3.3.310_546.230_446/raw.png
# Freq: fdfdfd: 851979
# Freq: 6eaa9c: 983
# Freq: 218e58: 2643
# Freq: be689a: 2858
# Freq: 23262b: 19975
# Freq: d4494f: 3179
# Freq: 4f5594: 4138
# neighbours: fdfdfd>  23262b 4f5594 d4494f be689a 218e58 6eaa9c e3817b
# 23262b>  4f5594 d4494f be689a 218e58 6eaa9c e3817b
# 4f5594>  d4494f be689a 218e58 6eaa9c e3817b
# d4494f>  be689a 218e58 6eaa9c e3817b
# be689a>  218e58 6eaa9c e3817b
# 218e58>  6eaa9c e3817b
# 6eaa9c>  e3817b
#
# htmlFile ./vaughey2013/pdfimages/image.3.3.310_546.230_446/images.html
# T: 856304/W: 837446/NW: 18858
# *****OK...vaughey2013//image.3.4.310_546.502_711
# vaughey2013//image.3.4.310_546.502_711
# transforming: image.3.4.310_546.502_711/raw.png
# Freq: b1b1b1: 5768
# Freq: 4d4d4d: 5100
# Freq: 8f8f8f: 5226
# Freq: 2f2f2f: 3840
# Freq: fefefe: 804253
# Freq: 6e6e6e: 6561
# Freq: 060606: 20955
# Freq: d0d0d0: 4601
# neighbours: fefefe>  060606 6e6e6e b1b1b1 8f8f8f 4d4d4d d0d0d0 2f2f2f
# 060606>  6e6e6e b1b1b1 8f8f8f 4d4d4d d0d0d0 2f2f2f
# 6e6e6e>  b1b1b1 8f8f8f 4d4d4d d0d0d0 2f2f2f
# b1b1b1>  8f8f8f 4d4d4d d0d0d0 2f2f2f
# 8f8f8f>  4d4d4d d0d0d0 2f2f2f
# 4d4d4d>  d0d0d0 2f2f2f
# d0d0d0>  2f2f2f
#
# htmlFile ./vaughey2013/pdfimages/image.3.4.310_546.502_711/images.html
# T: 2154463/W: 2140527/NW: 13936
# *****OK...vaughey2013//image.4.1.134_461.311_691
# vaughey2013//image.4.1.134_461.311_691
# transforming: image.4.1.134_461.311_691/raw.png
# Freq: 3b3e3c: 45802
# Freq: ab8579: 159
# Freq: 72a095: 1200
# Freq: fcfcfc: 2093995
# Freq: b5688d: 301
# Freq: 4d5797: 4835
# Freq: ca3b47: 5727
# Freq: 488c67: 2444
# neighbours: fcfcfc>  3b3e3c ca3b47 4d5797 488c67 72a095 b5688d ab8579
# 3b3e3c>  ca3b47 4d5797 488c67 72a095 b5688d ab8579
# ca3b47>  4d5797 488c67 72a095 b5688d ab8579
# 4d5797>  488c67 72a095 b5688d ab8579
# 488c67>  72a095 b5688d ab8579
# 72a095>  b5688d ab8579
# b5688d>  ab8579
#
# htmlFile ./vaughey2013/pdfimages/image.4.1.134_461.311_691/images.html
# T: 710968/W: 705743/NW: 5225
# *****OK...vaughey2013//image.5.1.49_285.538_711
# vaughey2013//image.5.1.49_285.538_711
# transforming: image.5.1.49_285.538_711/raw.png
# Freq: fdfdfd: 687481
# Freq: 3e3e3e: 22811
# Freq: d84850: 631
# neighbours: fdfdfd>  3e3e3e d84850 d67a84 7d7d82 ee837d 78837d
# 3e3e3e>  d84850 d67a84 7d7d82 ee837d 78837d
# d84850>  d67a84 7d7d82 ee837d 78837d
# d67a84>  7d7d82 ee837d 78837d
# 7d7d82>  ee837d 78837d
# ee837d>  78837d
#
# htmlFile ./vaughey2013/pdfimages/image.5.1.49_285.538_711/images.html
# T: 737482/W: 734775/NW: 2707
# *****OK...vaughey2013//image.5.3.310_546.531_711
# vaughey2013//image.5.3.310_546.531_711
# transforming: image.5.3.310_546.531_711/raw.png
# Freq: fefefe: 728125
# Freq: 3e4093: 1387
# Freq: 27272a: 7940
# neighbours: fefefe>  27272a 3e4093 7c83b2 817ab3 7d82c1
# 27272a>  3e4093 7c83b2 817ab3 7d82c1
# 3e4093>  7c83b2 817ab3 7d82c1
# 7c83b2>  817ab3 7d82c1
# 817ab3>  7d82c1
#
# htmlFile ./vaughey2013/pdfimages/image.5.3.310_546.531_711/images.html
# AMIImageTool cTree: wang2015
# AMIImageTool processTree
#  >>>>> imageDirs: 1
# T: 458980/W: 451569/NW: 7411
# *****OK...wang2015//image.4.1.137_449.59_250
# wang2015//image.4.1.137_449.59_250
# transforming: image.4.1.137_449.59_250/raw.png
# Freq: 222e23: 8374
# Freq: 369737: 1488
# Freq: f62627: 2390
# Freq: fdfdfd: 442718
# Freq: f677f3: 715
# Freq: 2526f0: 3203
# neighbours: fdfdfd>  222e23 2526f0 f62627 369737 f677f3 b1a178 7599bb
# 222e23>  2526f0 f62627 369737 f677f3 b1a178 7599bb
# 2526f0>  f62627 369737 f677f3 b1a178 7599bb
# f62627>  369737 f677f3 b1a178 7599bb
# 369737>  f677f3 b1a178 7599bb
# f677f3>  b1a178 7599bb
# b1a178>  7599bb
#
# htmlFile ./wang2015/pdfimages/image.4.1.137_449.59_250/images.html
# AMIImageTool cTree: weppner2011
# AMIImageTool processTree
#  >>>>> imageDirs: 4
# T: 8810780/W: 8391652/NW: 419128
# *****OK...weppner2011//image.2.1.340_532.50_216
# weppner2011//image.2.1.340_532.50_216
# transforming: image.2.1.340_532.50_216/raw.png
# Freq: ffffff: 8391652
# Freq: 000000: 419128
# neighbours: ffffff>  000000
#
# htmlFile ./weppner2011/pdfimages/image.2.1.340_532.50_216/images.html
# T: 11368560/W: 11132684/NW: 235876
# *****OK...weppner2011//image.6.1.134_473.50_170
# weppner2011//image.6.1.134_473.50_170
# transforming: image.6.1.134_473.50_170/raw.png
# Freq: f8f8f8: 11132684
# Freq: 000000: 235876
# neighbours: f8f8f8>  000000
#
# htmlFile ./weppner2011/pdfimages/image.6.1.134_473.50_170/images.html
# T: 9736000/W: 9234436/NW: 501564
# *****OK...weppner2011//image.7.1.51_292.50_196
# weppner2011//image.7.1.51_292.50_196
# transforming: image.7.1.51_292.50_196/raw.png
# Freq: f7f7f7: 9234436
# Freq: 000000: 501564
# neighbours: f7f7f7>  000000
#
# htmlFile ./weppner2011/pdfimages/image.7.1.51_292.50_196/images.html
# T: 23912000/W: 22991791/NW: 920209
# *****OK...weppner2011//image.8.1.51_292.50_409
# weppner2011//image.8.1.51_292.50_409
# transforming: image.8.1.51_292.50_409/raw.png
# Freq: 454545: 22991791
# Freq: 000000: 920209
# neighbours: 454545>  000000
#
# htmlFile ./weppner2011/pdfimages/image.8.1.51_292.50_409/images.html

# %%
! tree .
# Out:
# .
# ├── figures.txt
# ├── heitjans2012
# │   ├── fulltext.pdf
# │   ├── pdfimages
# │   │   ├── image.3.1.67_294.51_207
# │   │   │   ├── images.html
# │   │   │   ├── octree
# │   │   │   │   ├── binary.png
# │   │   │   │   ├── channel.002c90.png
# │   │   │   │   ├── channel.1f53a4.png
# │   │   │   │   ├── channel.2b3131.png
# │   │   │   │   ├── channel.4b75b6.png
# │   │   │   │   ├── channel.7a8287.png
# │   │   │   │   ├── channel.ec262c.png
# │   │   │   │   ├── channel.fdfdfd.png
# │   │   │   │   ├── histogram.svg
# │   │   │   │   └── octree.png
# │   │   │   ├── octree16
# │   │   │   │   ├── channel.002c90.png
# │   │   │   │   ├── channel.0f1616.png
# │   │   │   │   ├── channel.1f53a4.png
# │   │   │   │   ├── channel.3b4343.png
# │   │   │   │   ├── channel.4b75b6.png
# │   │   │   │   ├── channel.5c6262.png
# │   │   │   │   ├── channel.7393c6.png
# │   │   │   │   ├── channel.7b8182.png
# │   │   │   │   ├── channel.eb1118.png
# │   │   │   │   ├── channel.f05a61.png
# │   │   │   │   ├── channel.fdfdfd.png
# │   │   │   │   └── octree.png
# │   │   │   ├── raw
# │   │   │   │   └── raw.svg
# │   │   │   ├── raw.png
# │   │   │   ├── raw_o16.png
# │   │   │   ├── raw_o8.png
# │   │   │   └── testx
# │   │   │       ├── channel.002c90.png
# │   │   │       ├── channel.1f53a4.png
# │   │   │       ├── channel.2b3131.png
# │   │   │       ├── channel.4b75b6.png
# │   │   │       ├── channel.7a8287.png
# │   │   │       ├── channel.ec262c.png
# │   │   │       ├── channel.fdfdfd.png
# │   │   │       └── octree.png
# │   │   ├── image.3.2.110_515.425_709
# │   │   │   ├── images.html
# │   │   │   ├── octree
# │   │   │   │   ├── binary.png
# │   │   │   │   ├── channel.079c39.png
# │   │   │   │   ├── channel.080c09.png
# │   │   │   │   ├── channel.164ac2.png
# │   │   │   │   ├── channel.52acaf.png
# │   │   │   │   ├── channel.e21f22.png
# │   │   │   │   ├── channel.f17d82.png
# │   │   │   │   ├── channel.fafcfc.png
# │   │   │   │   ├── histogram.svg
# │   │   │   │   └── octree.png
# │   │   │   ├── octree16
# │   │   │   │   ├── channel.002fd7.png
# │   │   │   │   ├── channel.005edf.png
# │   │   │   │   ├── channel.008f1a.png
# │   │   │   │   ├── channel.080c09.png
# │   │   │   │   ├── channel.10ac5e.png
# │   │   │   │   ├── channel.52719d.png
# │   │   │   │   ├── channel.52acaf.png
# │   │   │   │   ├── channel.e21f22.png
# │   │   │   │   ├── channel.f17d82.png
# │   │   │   │   ├── channel.fafcfc.png
# │   │   │   │   └── octree.png
# │   │   │   ├── raw
# │   │   │   ├── raw.orig.png
# │   │   │   ├── raw.png
# │   │   │   ├── raw_o16.png
# │   │   │   ├── raw_o8.png
# │   │   │   └── testx
# │   │   │       ├── channel.0ca54e.png
# │   │   │       ├── channel.252525.png
# │   │   │       ├── channel.343e96.png
# │   │   │       ├── channel.4fb8b2.png
# │   │   │       ├── channel.ea2f36.png
# │   │   │       ├── channel.fcfcfc.png
# │   │   │       └── octree.png
# │   │   ├── image.4.1.135_490.51_391
# │   │   │   ├── images.html
# │   │   │   ├── octree
# │   │   │   │   ├── binary.png
# │   │   │   │   ├── channel.09a54f.png
# │   │   │   │   ├── channel.1559a6.png
# │   │   │   │   ├── channel.2d3636.png
# │   │   │   │   ├── channel.719c90.png
# │   │   │   │   ├── channel.ee3e45.png
# │   │   │   │   ├── channel.fbfcfc.png
# │   │   │   │   ├── histogram.svg
# │   │   │   │   └── octree.png
# │   │   │   ├── octree16
# │   │   │   │   ├── channel.003c9a.png
# │   │   │   │   ├── channel.009a3a.png
# │   │   │   │   ├── channel.09a651.png
# │   │   │   │   ├── channel.145ba8.png
# │   │   │   │   ├── channel.2d3636.png
# │   │   │   │   ├── channel.66c996.png
# │   │   │   │   ├── channel.6d9cc9.png
# │   │   │   │   ├── channel.778684.png
# │   │   │   │   ├── channel.ee3e45.png
# │   │   │   │   ├── channel.fbfcfc.png
# │   │   │   │   └── octree.png
# │   │   │   ├── raw.png
# │   │   │   ├── raw_o16.png
# │   │   │   ├── raw_o8.png
# │   │   │   └── testx
# │   │   │       ├── channel.09a54f.png
# │   │   │       ├── channel.1559a6.png
# │   │   │       ├── channel.2d3636.png
# │   │   │       ├── channel.719c90.png
# │   │   │       ├── channel.ee3e45.png
# │   │   │       ├── channel.fbfcfc.png
# │   │   │       └── octree.png
# │   │   ├── image.5.1.128_497.51_300
# │   │   │   ├── images.html
# │   │   │   ├── octree
# │   │   │   │   ├── binary.png
# │   │   │   │   ├── channel.09a44e.png
# │   │   │   │   ├── channel.201f1f.png
# │   │   │   │   ├── channel.38469c.png
# │   │   │   │   ├── channel.68b796.png
# │   │   │   │   ├── channel.ea242c.png
# │   │   │   │   ├── channel.fcfcfc.png
# │   │   │   │   ├── histogram.svg
# │   │   │   │   └── octree.png
# │   │   │   ├── octree16
# │   │   │   │   ├── channel.009a3a.png
# │   │   │   │   ├── channel.0aa651.png
# │   │   │   │   ├── channel.1e268c.png
# │   │   │   │   ├── channel.201f1f.png
# │   │   │   │   ├── channel.3451a2.png
# │   │   │   │   ├── channel.5563aa.png
# │   │   │   │   ├── channel.63c894.png
# │   │   │   │   ├── channel.70948a.png
# │   │   │   │   ├── channel.ea242c.png
# │   │   │   │   ├── channel.fcfcfc.png
# │   │   │   │   └── octree.png
# │   │   │   ├── raw.png
# │   │   │   ├── raw_o16.png
# │   │   │   ├── raw_o8.png
# │   │   │   └── testx
# │   │   │       ├── channel.09a44e.png
# │   │   │       ├── channel.201f1f.png
# │   │   │       ├── channel.38469c.png
# │   │   │       ├── channel.68b796.png
# │   │   │       ├── channel.ea242c.png
# │   │   │       ├── channel.fcfcfc.png
# │   │   │       └── octree.png
# │   │   ├── image.6.1.96_265.51_189
# │   │   │   ├── images.html
# │   │   │   ├── octree
# │   │   │   │   ├── binary.png
# │   │   │   │   ├── channel.08a349.png
# │   │   │   │   ├── channel.1a1a1a.png
# │   │   │   │   ├── channel.1f3e9a.png
# │   │   │   │   ├── channel.62c196.png
# │   │   │   │   ├── channel.eb1f2a.png
# │   │   │   │   ├── channel.fdfdfd.png
# │   │   │   │   ├── histogram.svg
# │   │   │   │   └── octree.png
# │   │   │   ├── octree16
# │   │   │   │   ├── channel.009836.png
# │   │   │   │   ├── channel.0ca955.png
# │   │   │   │   ├── channel.1a1a1a.png
# │   │   │   │   ├── channel.1f3e9a.png
# │   │   │   │   ├── channel.64c995.png
# │   │   │   │   ├── channel.eb1f2a.png
# │   │   │   │   ├── channel.fdfdfd.png
# │   │   │   │   └── octree.png
# │   │   │   ├── raw.png
# │   │   │   ├── raw_o16.png
# │   │   │   ├── raw_o8.png
# │   │   │   └── testx
# │   │   │       ├── channel.08a349.png
# │   │   │       ├── channel.1a1a1a.png
# │   │   │       ├── channel.1f3e9a.png
# │   │   │       ├── channel.62c196.png
# │   │   │       ├── channel.eb1f2a.png
# │   │   │       ├── channel.fdfdfd.png
# │   │   │       └── octree.png
# │   │   ├── image.6.2.104_521.498_689
# │   │   │   ├── images.html
# │   │   │   ├── octree
# │   │   │   │   ├── binary.png
# │   │   │   │   ├── channel.0e55a5.png
# │   │   │   │   ├── channel.13a64e.png
# │   │   │   │   ├── channel.303636.png
# │   │   │   │   ├── channel.6f9e97.png
# │   │   │   │   ├── channel.ed353c.png
# │   │   │   │   ├── channel.fcfcfd.png
# │   │   │   │   ├── histogram.svg
# │   │   │   │   └── octree.png
# │   │   │   ├── octree16
# │   │   │   │   ├── channel.059934.png
# │   │   │   │   ├── channel.0d55a6.png
# │   │   │   │   ├── channel.11a956.png
# │   │   │   │   ├── channel.303636.png
# │   │   │   │   ├── channel.4cb868.png
# │   │   │   │   ├── channel.66c893.png
# │   │   │   │   ├── channel.6c9bc8.png
# │   │   │   │   ├── channel.768684.png
# │   │   │   │   ├── channel.ed353c.png
# │   │   │   │   ├── channel.fcfcfd.png
# │   │   │   │   └── octree.png
# │   │   │   ├── raw.png
# │   │   │   ├── raw_o16.png
# │   │   │   ├── raw_o8.png
# │   │   │   └── testx
# │   │   │       ├── channel.0e55a5.png
# │   │   │       ├── channel.13a64e.png
# │   │   │       ├── channel.303636.png
# │   │   │       ├── channel.6f9e97.png
# │   │   │       ├── channel.ed353c.png
# │   │   │       ├── channel.fcfcfd.png
# │   │   │       └── octree.png
# │   │   ├── image.7.1.90_535.51_246
# │   │   │   ├── images.html
# │   │   │   ├── octree
# │   │   │   │   ├── binary.png
# │   │   │   │   ├── channel.0ea64c.png
# │   │   │   │   ├── channel.222121.png
# │   │   │   │   ├── channel.33acd2.png
# │   │   │   │   ├── channel.e93339.png
# │   │   │   │   ├── channel.fcfcfd.png
# │   │   │   │   ├── histogram.svg
# │   │   │   │   └── octree.png
# │   │   │   ├── octree16
# │   │   │   │   ├── channel.009d34.png
# │   │   │   │   ├── channel.0a9adf.png
# │   │   │   │   ├── channel.12a956.png
# │   │   │   │   ├── channel.222121.png
# │   │   │   │   ├── channel.50bae7.png
# │   │   │   │   ├── channel.65c5eb.png
# │   │   │   │   ├── channel.65c995.png
# │   │   │   │   ├── channel.e93339.png
# │   │   │   │   ├── channel.fcfcfd.png
# │   │   │   │   └── octree.png
# │   │   │   ├── raw.png
# │   │   │   ├── raw_o16.png
# │   │   │   ├── raw_o8.png
# │   │   │   └── testx
# │   │   │       ├── channel.0ea64c.png
# │   │   │       ├── channel.222121.png
# │   │   │       ├── channel.33acd2.png
# │   │   │       ├── channel.e93339.png
# │   │   │       ├── channel.fcfcfd.png
# │   │   │       └── octree.png
# │   │   ├── image.8.1.127_498.51_224
# │   │   │   ├── images.html
# │   │   │   ├── octree
# │   │   │   │   ├── binary.png
# │   │   │   │   ├── channel.2b3131.png
# │   │   │   │   ├── channel.7c8282.png
# │   │   │   │   ├── channel.e9313c.png
# │   │   │   │   ├── channel.fefdfd.png
# │   │   │   │   ├── histogram.svg
# │   │   │   │   └── octree.png
# │   │   │   ├── octree16
# │   │   │   │   ├── channel.151c1c.png
# │   │   │   │   ├── channel.3b4343.png
# │   │   │   │   ├── channel.5c6161.png
# │   │   │   │   ├── channel.7c8282.png
# │   │   │   │   ├── channel.ee1f2b.png
# │   │   │   │   ├── channel.f03843.png
# │   │   │   │   ├── channel.fefdfd.png
# │   │   │   │   └── octree.png
# │   │   │   ├── raw.png
# │   │   │   ├── raw_o16.png
# │   │   │   ├── raw_o8.png
# │   │   │   └── testx
# │   │   │       ├── channel.2b3131.png
# │   │   │       ├── channel.7c8282.png
# │   │   │       ├── channel.e9313c.png
# │   │   │       ├── channel.fefdfd.png
# │   │   │       └── octree.png
# │   │   └── image.8.2.348_541.510_689
# │   │       ├── images.html
# │   │       ├── octree
# │   │       │   ├── binary.png
# │   │       │   ├── channel.26459a.png
# │   │       │   ├── channel.363a3a.png
# │   │       │   ├── channel.7a848f.png
# │   │       │   ├── channel.e2222c.png
# │   │       │   ├── channel.fefefe.png
# │   │       │   ├── histogram.svg
# │   │       │   └── octree.png
# │   │       ├── octree16
# │   │       │   ├── channel.0e308f.png
# │   │       │   ├── channel.2d4c9f.png
# │   │       │   ├── channel.363a3a.png
# │   │       │   ├── channel.566fb1.png
# │   │       │   ├── channel.7a838a.png
# │   │       │   ├── channel.a12027.png
# │   │       │   ├── channel.ef212c.png
# │   │       │   ├── channel.fefefe.png
# │   │       │   └── octree.png
# │   │       ├── raw.png
# │   │       ├── raw_o16.png
# │   │       ├── raw_o8.png
# │   │       └── testx
# │   │           ├── channel.26459a.png
# │   │           ├── channel.363a3a.png
# │   │           ├── channel.7a848f.png
# │   │           ├── channel.e2222c.png
# │   │           ├── channel.fefefe.png
# │   │           └── octree.png
# │   └── svg
# │       ├── fulltext-page.0.svg
# │       ├── fulltext-page.1.svg
# │       ├── fulltext-page.10.svg
# │       ├── fulltext-page.2.svg
# │       ├── fulltext-page.3.svg
# │       ├── fulltext-page.4.svg
# │       ├── fulltext-page.5.svg
# │       ├── fulltext-page.6.svg
# │       ├── fulltext-page.7.svg
# │       ├── fulltext-page.8.svg
# │       └── fulltext-page.9.svg
# ├── janek2011
# │   ├── fulltext.pdf
# │   ├── pdfimages
# │   │   ├── image.11.1.57_284.78_298
# │   │   │   ├── images.html
# │   │   │   ├── octree
# │   │   │   │   ├── binary.png
# │   │   │   │   ├── channel.2c292a.png
# │   │   │   │   ├── channel.7c7e80.png
# │   │   │   │   ├── channel.7e8082.png
# │   │   │   │   ├── channel.de3639.png
# │   │   │   │   ├── channel.de8678.png
# │   │   │   │   ├── channel.fcfcfa.png
# │   │   │   │   ├── histogram.svg
# │   │   │   │   └── octree.png
# │   │   │   ├── octree16
# │   │   │   │   ├── channel.2c292a.png
# │   │   │   │   ├── channel.7c7e80.png
# │   │   │   │   ├── channel.7e8082.png
# │   │   │   │   ├── channel.de3639.png
# │   │   │   │   ├── channel.e98677.png
# │   │   │   │   ├── channel.fcfcfa.png
# │   │   │   │   └── octree.png
# │   │   │   ├── raw.png
# │   │   │   ├── raw_o16.png
# │   │   │   ├── raw_o8.png
# │   │   │   └── testx
# │   │   │       ├── channel.2c292a.png
# │   │   │       ├── channel.7c7e80.png
# │   │   │       ├── channel.7e8082.png
# │   │   │       ├── channel.de3639.png
# │   │   │       ├── channel.de8678.png
# │   │   │       ├── channel.fcfcfa.png
# │   │   │       └── octree.png
# │   │   ├── image.11.2.312_538.78_260
# │   │   │   ├── images.html
# │   │   │   ├── octree
# │   │   │   │   ├── binary.png
# │   │   │   │   ├── channel.312e2f.png
# │   │   │   │   ├── channel.7d7e80.png
# │   │   │   │   ├── channel.7e8082.png
# │   │   │   │   ├── channel.e5383b.png
# │   │   │   │   ├── channel.eb8677.png
# │   │   │   │   ├── channel.fefdfc.png
# │   │   │   │   ├── histogram.svg
# │   │   │   │   └── octree.png
# │   │   │   ├── octree16
# │   │   │   │   ├── channel.312e2f.png
# │   │   │   │   ├── channel.7d7e80.png
# │   │   │   │   ├── channel.7e8082.png
# │   │   │   │   ├── channel.e53544.png
# │   │   │   │   ├── channel.e65f59.png
# │   │   │   │   ├── channel.e7282e.png
# │   │   │   │   ├── channel.eb8677.png
# │   │   │   │   ├── channel.fefdfc.png
# │   │   │   │   └── octree.png
# │   │   │   ├── raw.png
# │   │   │   ├── raw_o16.png
# │   │   │   ├── raw_o8.png
# │   │   │   └── testx
# │   │   │       ├── channel.312e2f.png
# │   │   │       ├── channel.7d7e80.png
# │   │   │       ├── channel.7e8082.png
# │   │   │       ├── channel.e5383b.png
# │   │   │       ├── channel.eb8677.png
# │   │   │       ├── channel.fefdfc.png
# │   │   │       └── octree.png
# │   │   ├── image.12.1.75_521.339_683
# │   │   │   ├── images.html
# │   │   │   ├── octree
# │   │   │   │   ├── binary.png
# │   │   │   │   ├── channel.3b393b.png
# │   │   │   │   ├── channel.4d5d97.png
# │   │   │   │   ├── channel.7e8084.png
# │   │   │   │   ├── channel.d84940.png
# │   │   │   │   ├── channel.df8c6a.png
# │   │   │   │   ├── channel.fdfdfb.png
# │   │   │   │   ├── histogram.svg
# │   │   │   │   └── octree.png
# │   │   │   ├── octree16
# │   │   │   │   ├── channel.3b393b.png
# │   │   │   │   ├── channel.4d5d97.png
# │   │   │   │   ├── channel.7e8084.png
# │   │   │   │   ├── channel.df8c6a.png
# │   │   │   │   ├── channel.e3262b.png
# │   │   │   │   ├── channel.e46853.png
# │   │   │   │   ├── channel.e85731.png
# │   │   │   │   ├── channel.fdfdfb.png
# │   │   │   │   └── octree.png
# │   │   │   ├── raw.png
# │   │   │   ├── raw_o16.png
# │   │   │   ├── raw_o8.png
# │   │   │   └── testx
# │   │   │       ├── channel.3b393b.png
# │   │   │       ├── channel.4d5d97.png
# │   │   │       ├── channel.7e8084.png
# │   │   │       ├── channel.d84940.png
# │   │   │       ├── channel.df8c6a.png
# │   │   │       ├── channel.fdfdfb.png
# │   │   │       └── octree.png
# │   │   ├── image.4.2.312_539.506_683
# │   │   │   ├── images.html
# │   │   │   ├── octree
# │   │   │   │   ├── binary.png
# │   │   │   │   ├── channel.000000.png
# │   │   │   │   ├── channel.ffffff.png
# │   │   │   │   ├── histogram.svg
# │   │   │   │   └── octree.png
# │   │   │   ├── octree16
# │   │   │   │   ├── channel.000000.png
# │   │   │   │   ├── channel.ffffff.png
# │   │   │   │   └── octree.png
# │   │   │   ├── raw.png
# │   │   │   ├── raw_o16.png
# │   │   │   ├── raw_o8.png
# │   │   │   └── testx
# │   │   │       ├── channel.000000.png
# │   │   │       ├── channel.ffffff.png
# │   │   │       └── octree.png
# │   │   ├── image.5.1.91_250.78_255
# │   │   │   ├── images.html
# │   │   │   ├── octree
# │   │   │   │   ├── binary.png
# │   │   │   │   ├── channel.000000.png
# │   │   │   │   ├── channel.ffffff.png
# │   │   │   │   ├── histogram.svg
# │   │   │   │   └── octree.png
# │   │   │   ├── octree16
# │   │   │   │   ├── channel.000000.png
# │   │   │   │   ├── channel.ffffff.png
# │   │   │   │   └── octree.png
# │   │   │   ├── raw.png
# │   │   │   ├── raw_o16.png
# │   │   │   ├── raw_o8.png
# │   │   │   └── testx
# │   │   │       ├── channel.000000.png
# │   │   │       ├── channel.ffffff.png
# │   │   │       └── octree.png
# │   │   ├── image.5.2.364_487.78_207
# │   │   │   ├── images.html
# │   │   │   ├── octree
# │   │   │   │   ├── binary.png
# │   │   │   │   ├── channel.000000.png
# │   │   │   │   ├── channel.ffffff.png
# │   │   │   │   ├── histogram.svg
# │   │   │   │   └── octree.png
# │   │   │   ├── octree16
# │   │   │   │   ├── channel.000000.png
# │   │   │   │   ├── channel.ffffff.png
# │   │   │   │   └── octree.png
# │   │   │   ├── raw.png
# │   │   │   ├── raw_o16.png
# │   │   │   ├── raw_o8.png
# │   │   │   └── testx
# │   │   │       ├── channel.000000.png
# │   │   │       ├── channel.ffffff.png
# │   │   │       └── octree.png
# │   │   └── image.7.1.58_538.409_623
# │   │       ├── images.html
# │   │       ├── octree
# │   │       │   ├── binary.png
# │   │       │   ├── channel.050505.png
# │   │       │   ├── channel.303030.png
# │   │       │   ├── channel.4e4e4e.png
# │   │       │   ├── channel.6f6f6f.png
# │   │       │   ├── channel.909090.png
# │   │       │   ├── channel.b0b0b0.png
# │   │       │   ├── channel.d0d0d0.png
# │   │       │   ├── channel.fefefe.png
# │   │       │   ├── histogram.svg
# │   │       │   └── octree.png
# │   │       ├── octree16
# │   │       │   ├── channel.020202.png
# │   │       │   ├── channel.161616.png
# │   │       │   ├── channel.272727.png
# │   │       │   ├── channel.373737.png
# │   │       │   ├── channel.464646.png
# │   │       │   ├── channel.575757.png
# │   │       │   ├── channel.686868.png
# │   │       │   ├── channel.777777.png
# │   │       │   ├── channel.878787.png
# │   │       │   ├── channel.979797.png
# │   │       │   ├── channel.a7a7a7.png
# │   │       │   ├── channel.b7b7b7.png
# │   │       │   ├── channel.c7c7c7.png
# │   │       │   ├── channel.d8d8d8.png
# │   │       │   ├── channel.e8e8e8.png
# │   │       │   ├── channel.fefefe.png
# │   │       │   └── octree.png
# │   │       ├── raw.png
# │   │       ├── raw_o16.png
# │   │       ├── raw_o8.png
# │   │       └── testx
# │   │           ├── channel.050505.png
# │   │           ├── channel.303030.png
# │   │           ├── channel.4e4e4e.png
# │   │           ├── channel.6f6f6f.png
# │   │           ├── channel.909090.png
# │   │           ├── channel.b0b0b0.png
# │   │           ├── channel.d0d0d0.png
# │   │           ├── channel.fefefe.png
# │   │           └── octree.png
# │   └── svg
# │       ├── fulltext-page.0.svg
# │       ├── fulltext-page.1.svg
# │       ├── fulltext-page.10.svg
# │       ├── fulltext-page.11.svg
# │       ├── fulltext-page.12.svg
# │       ├── fulltext-page.13.svg
# │       ├── fulltext-page.14.svg
# │       ├── fulltext-page.2.svg
# │       ├── fulltext-page.3.svg
# │       ├── fulltext-page.4.svg
# │       ├── fulltext-page.5.svg
# │       ├── fulltext-page.6.svg
# │       ├── fulltext-page.7.svg
# │       ├── fulltext-page.8.svg
# │       └── fulltext-page.9.svg
# ├── kilner2014
# │   ├── fulltext.pdf
# │   ├── pdfimages
# │   │   ├── image.3.1.326_562.128_273
# │   │   │   ├── images.html
# │   │   │   ├── octree
# │   │   │   │   ├── binary.png
# │   │   │   │   ├── channel.0070bf.png
# │   │   │   │   ├── channel.07b155.png
# │   │   │   │   ├── channel.0d0d0d.png
# │   │   │   │   ├── channel.439fc0.png
# │   │   │   │   ├── channel.fa0b0a.png
# │   │   │   │   ├── channel.fdfdfd.png
# │   │   │   │   ├── histogram.svg
# │   │   │   │   └── octree.png
# │   │   │   ├── octree16
# │   │   │   │   ├── channel.0070bf.png
# │   │   │   │   ├── channel.07b155.png
# │   │   │   │   ├── channel.0d0d0d.png
# │   │   │   │   ├── channel.439fc0.png
# │   │   │   │   ├── channel.835527.png
# │   │   │   │   ├── channel.ab160c.png
# │   │   │   │   ├── channel.fdfdfd.png
# │   │   │   │   ├── channel.fe0101.png
# │   │   │   │   ├── channel.fe4a4a.png
# │   │   │   │   └── octree.png
# │   │   │   ├── raw.png
# │   │   │   ├── raw_o16.png
# │   │   │   ├── raw_o8.png
# │   │   │   └── testx
# │   │   │       ├── channel.0070bf.png
# │   │   │       ├── channel.07b155.png
# │   │   │       ├── channel.0d0d0d.png
# │   │   │       ├── channel.439fc0.png
# │   │   │       ├── channel.fa0b0a.png
# │   │   │       ├── channel.fdfdfd.png
# │   │   │       └── octree.png
# │   │   ├── image.4.2.329_560.51_236
# │   │   │   ├── images.html
# │   │   │   ├── octree
# │   │   │   │   ├── binary.png
# │   │   │   │   ├── channel.0170c0.png
# │   │   │   │   ├── channel.07b254.png
# │   │   │   │   ├── channel.0c0b0b.png
# │   │   │   │   ├── channel.4e90be.png
# │   │   │   │   ├── channel.8064a2.png
# │   │   │   │   ├── channel.f70a0a.png
# │   │   │   │   ├── channel.fdfdfd.png
# │   │   │   │   ├── histogram.svg
# │   │   │   │   └── octree.png
# │   │   │   ├── octree16
# │   │   │   │   ├── channel.0070c0.png
# │   │   │   │   ├── channel.03b152.png
# │   │   │   │   ├── channel.0c0b0b.png
# │   │   │   │   ├── channel.40c47c.png
# │   │   │   │   ├── channel.4e90be.png
# │   │   │   │   ├── channel.8064a2.png
# │   │   │   │   ├── channel.9b0100.png
# │   │   │   │   ├── channel.fdfdfd.png
# │   │   │   │   ├── channel.fe0202.png
# │   │   │   │   ├── channel.fe5353.png
# │   │   │   │   └── octree.png
# │   │   │   ├── raw.png
# │   │   │   ├── raw_o16.png
# │   │   │   ├── raw_o8.png
# │   │   │   └── testx
# │   │   │       ├── channel.0170c0.png
# │   │   │       ├── channel.07b254.png
# │   │   │       ├── channel.0c0b0b.png
# │   │   │       ├── channel.4e90be.png
# │   │   │       ├── channel.8064a2.png
# │   │   │       ├── channel.f70a0a.png
# │   │   │       ├── channel.fdfdfd.png
# │   │   │       └── octree.png
# │   │   ├── image.5.1.95_266.51_154
# │   │   │   ├── images.html
# │   │   │   ├── octree
# │   │   │   │   ├── binary.png
# │   │   │   │   ├── channel.09b052.png
# │   │   │   │   ├── channel.1f2125.png
# │   │   │   │   ├── channel.48bcaf.png
# │   │   │   │   ├── channel.563ea4.png
# │   │   │   │   ├── channel.ed1818.png
# │   │   │   │   ├── channel.fcfcfc.png
# │   │   │   │   ├── histogram.svg
# │   │   │   │   └── octree.png
# │   │   │   ├── octree16
# │   │   │   │   ├── channel.0171c1.png
# │   │   │   │   ├── channel.0962ae.png
# │   │   │   │   ├── channel.09b052.png
# │   │   │   │   ├── channel.1f2125.png
# │   │   │   │   ├── channel.48bcaf.png
# │   │   │   │   ├── channel.6f2f9f.png
# │   │   │   │   ├── channel.ed1818.png
# │   │   │   │   ├── channel.fcfcfc.png
# │   │   │   │   └── octree.png
# │   │   │   ├── raw.png
# │   │   │   ├── raw_o16.png
# │   │   │   ├── raw_o8.png
# │   │   │   └── testx
# │   │   │       ├── channel.09b052.png
# │   │   │       ├── channel.1f2125.png
# │   │   │       ├── channel.48bcaf.png
# │   │   │       ├── channel.563ea4.png
# │   │   │       ├── channel.ed1818.png
# │   │   │       ├── channel.fcfcfc.png
# │   │   │       └── octree.png
# │   │   ├── image.5.2.85_276.512_689
# │   │   │   ├── images.html
# │   │   │   ├── octree
# │   │   │   │   ├── binary.png
# │   │   │   │   ├── channel.141414.png
# │   │   │   │   ├── channel.616161.png
# │   │   │   │   ├── channel.a1a1a1.png
# │   │   │   │   ├── channel.fefefe.png
# │   │   │   │   ├── channel.ff0505.png
# │   │   │   │   ├── channel.ff2f2f.png
# │   │   │   │   ├── channel.ff5e5e.png
# │   │   │   │   ├── channel.ffa2a2.png
# │   │   │   │   ├── histogram.svg
# │   │   │   │   └── octree.png
# │   │   │   ├── octree16
# │   │   │   │   ├── channel.090909.png
# │   │   │   │   ├── channel.2f2f2f.png
# │   │   │   │   ├── channel.4f4f4f.png
# │   │   │   │   ├── channel.707070.png
# │   │   │   │   ├── channel.8f8f8f.png
# │   │   │   │   ├── channel.b0b0b0.png
# │   │   │   │   ├── channel.d0d0d0.png
# │   │   │   │   ├── channel.fefefe.png
# │   │   │   │   ├── channel.ff0505.png
# │   │   │   │   ├── channel.ff2f2f.png
# │   │   │   │   ├── channel.ff4c4c.png
# │   │   │   │   ├── channel.ff6e6e.png
# │   │   │   │   ├── channel.ff8f8f.png
# │   │   │   │   ├── channel.ffa6a6.png
# │   │   │   │   ├── channel.ffb8b8.png
# │   │   │   │   ├── channel.ffd0d0.png
# │   │   │   │   └── octree.png
# │   │   │   ├── raw.png
# │   │   │   ├── raw_o16.png
# │   │   │   ├── raw_o8.png
# │   │   │   └── testx
# │   │   │       ├── channel.141414.png
# │   │   │       ├── channel.616161.png
# │   │   │       ├── channel.a1a1a1.png
# │   │   │       ├── channel.fefefe.png
# │   │   │       ├── channel.ff0505.png
# │   │   │       ├── channel.ff2f2f.png
# │   │   │       ├── channel.ff5e5e.png
# │   │   │       ├── channel.ffa2a2.png
# │   │   │       └── octree.png
# │   │   └── image.6.1.88_273.51_495
# │   │       ├── images.html
# │   │       ├── octree
# │   │       │   ├── binary.png
# │   │       │   ├── channel.000000.png
# │   │       │   ├── channel.3d3d3d.png
# │   │       │   ├── histogram.svg
# │   │       │   └── octree.png
# │   │       ├── octree16
# │   │       │   ├── channel.000000.png
# │   │       │   ├── channel.3d3d3d.png
# │   │       │   └── octree.png
# │   │       ├── raw.png
# │   │       ├── raw_o16.png
# │   │       ├── raw_o8.png
# │   │       └── testx
# │   │           ├── channel.000000.png
# │   │           ├── channel.3d3d3d.png
# │   │           └── octree.png
# │   └── svg
# │       ├── fulltext-page.0.svg
# │       ├── fulltext-page.1.svg
# │       ├── fulltext-page.2.svg
# │       ├── fulltext-page.3.svg
# │       ├── fulltext-page.4.svg
# │       ├── fulltext-page.5.svg
# │       ├── fulltext-page.6.svg
# │       └── fulltext-page.7.svg
# ├── larraz2015
# │   ├── fulltext.pdf
# │   ├── pdfimages
# │   │   ├── image.3.1.310_546.71_250
# │   │   │   ├── images.html
# │   │   │   ├── octree
# │   │   │   │   ├── binary.png
# │   │   │   │   ├── channel.090909.png
# │   │   │   │   ├── channel.303030.png
# │   │   │   │   ├── channel.505050.png
# │   │   │   │   ├── channel.6f6f6f.png
# │   │   │   │   ├── channel.8f8f8f.png
# │   │   │   │   ├── channel.b0b0b0.png
# │   │   │   │   ├── channel.d1d1d1.png
# │   │   │   │   ├── channel.fefefe.png
# │   │   │   │   ├── histogram.svg
# │   │   │   │   └── octree.png
# │   │   │   ├── octree16
# │   │   │   │   ├── channel.020202.png
# │   │   │   │   ├── channel.181818.png
# │   │   │   │   ├── channel.272727.png
# │   │   │   │   ├── channel.373737.png
# │   │   │   │   ├── channel.474747.png
# │   │   │   │   ├── channel.575757.png
# │   │   │   │   ├── channel.676767.png
# │   │   │   │   ├── channel.777777.png
# │   │   │   │   ├── channel.878787.png
# │   │   │   │   ├── channel.979797.png
# │   │   │   │   ├── channel.a7a7a7.png
# │   │   │   │   ├── channel.b7b7b7.png
# │   │   │   │   ├── channel.c7c7c7.png
# │   │   │   │   ├── channel.d8d8d8.png
# │   │   │   │   ├── channel.e8e8e8.png
# │   │   │   │   ├── channel.fefefe.png
# │   │   │   │   └── octree.png
# │   │   │   ├── raw.png
# │   │   │   ├── raw_o16.png
# │   │   │   ├── raw_o8.png
# │   │   │   └── testx
# │   │   │       ├── channel.090909.png
# │   │   │       ├── channel.303030.png
# │   │   │       ├── channel.505050.png
# │   │   │       ├── channel.6f6f6f.png
# │   │   │       ├── channel.8f8f8f.png
# │   │   │       ├── channel.b0b0b0.png
# │   │   │       ├── channel.d1d1d1.png
# │   │   │       ├── channel.fefefe.png
# │   │   │       └── octree.png
# │   │   ├── image.3.2.310_546.478_681
# │   │   │   ├── images.html
# │   │   │   ├── octree
# │   │   │   │   ├── binary.png
# │   │   │   │   ├── channel.080808.png
# │   │   │   │   ├── channel.2f2f2f.png
# │   │   │   │   ├── channel.4f4f4f.png
# │   │   │   │   ├── channel.707070.png
# │   │   │   │   ├── channel.8e8e8e.png
# │   │   │   │   ├── channel.adadad.png
# │   │   │   │   ├── channel.d1d1d1.png
# │   │   │   │   ├── channel.fefefe.png
# │   │   │   │   ├── histogram.svg
# │   │   │   │   └── octree.png
# │   │   │   ├── octree16
# │   │   │   │   ├── channel.030303.png
# │   │   │   │   ├── channel.161616.png
# │   │   │   │   ├── channel.282828.png
# │   │   │   │   ├── channel.363636.png
# │   │   │   │   ├── channel.474747.png
# │   │   │   │   ├── channel.575757.png
# │   │   │   │   ├── channel.686868.png
# │   │   │   │   ├── channel.777777.png
# │   │   │   │   ├── channel.868686.png
# │   │   │   │   ├── channel.989898.png
# │   │   │   │   ├── channel.a6a6a6.png
# │   │   │   │   ├── channel.b7b7b7.png
# │   │   │   │   ├── channel.c7c7c7.png
# │   │   │   │   ├── channel.d8d8d8.png
# │   │   │   │   ├── channel.e7e7e7.png
# │   │   │   │   ├── channel.fefefe.png
# │   │   │   │   └── octree.png
# │   │   │   ├── raw.png
# │   │   │   ├── raw_o16.png
# │   │   │   ├── raw_o8.png
# │   │   │   └── testx
# │   │   │       ├── channel.080808.png
# │   │   │       ├── channel.2f2f2f.png
# │   │   │       ├── channel.4f4f4f.png
# │   │   │       ├── channel.707070.png
# │   │   │       ├── channel.8e8e8e.png
# │   │   │       ├── channel.adadad.png
# │   │   │       ├── channel.d1d1d1.png
# │   │   │       ├── channel.fefefe.png
# │   │   │       └── octree.png
# │   │   ├── image.4.1.310_546.71_269
# │   │   │   ├── images.html
# │   │   │   ├── octree
# │   │   │   │   ├── binary.png
# │   │   │   │   ├── channel.050505.png
# │   │   │   │   ├── channel.2d2d2d.png
# │   │   │   │   ├── channel.4e4e4e.png
# │   │   │   │   ├── channel.717171.png
# │   │   │   │   ├── channel.8e8e8e.png
# │   │   │   │   ├── channel.aeaeae.png
# │   │   │   │   ├── channel.cecece.png
# │   │   │   │   ├── channel.fefefe.png
# │   │   │   │   ├── histogram.svg
# │   │   │   │   └── octree.png
# │   │   │   ├── octree16
# │   │   │   │   ├── channel.020202.png
# │   │   │   │   ├── channel.171717.png
# │   │   │   │   ├── channel.272727.png
# │   │   │   │   ├── channel.363636.png
# │   │   │   │   ├── channel.4a4a4a.png
# │   │   │   │   ├── channel.575757.png
# │   │   │   │   ├── channel.676767.png
# │   │   │   │   ├── channel.777777.png
# │   │   │   │   ├── channel.868686.png
# │   │   │   │   ├── channel.969696.png
# │   │   │   │   ├── channel.a6a6a6.png
# │   │   │   │   ├── channel.b8b8b8.png
# │   │   │   │   ├── channel.c8c8c8.png
# │   │   │   │   ├── channel.d8d8d8.png
# │   │   │   │   ├── channel.e6e6e6.png
# │   │   │   │   ├── channel.fefefe.png
# │   │   │   │   └── octree.png
# │   │   │   ├── raw.png
# │   │   │   ├── raw_o16.png
# │   │   │   ├── raw_o8.png
# │   │   │   └── testx
# │   │   │       ├── channel.050505.png
# │   │   │       ├── channel.2d2d2d.png
# │   │   │       ├── channel.4e4e4e.png
# │   │   │       ├── channel.717171.png
# │   │   │       ├── channel.8e8e8e.png
# │   │   │       ├── channel.aeaeae.png
# │   │   │       ├── channel.cecece.png
# │   │   │       ├── channel.fefefe.png
# │   │   │       └── octree.png
# │   │   ├── image.5.1.49_285.71_269
# │   │   │   ├── images.html
# │   │   │   ├── octree
# │   │   │   │   ├── binary.png
# │   │   │   │   ├── channel.070707.png
# │   │   │   │   ├── channel.2d2d2d.png
# │   │   │   │   ├── channel.535353.png
# │   │   │   │   ├── channel.707070.png
# │   │   │   │   ├── channel.8f8f8f.png
# │   │   │   │   ├── channel.adadad.png
# │   │   │   │   ├── channel.d1d1d1.png
# │   │   │   │   ├── channel.fefefe.png
# │   │   │   │   ├── histogram.svg
# │   │   │   │   └── octree.png
# │   │   │   ├── octree16
# │   │   │   │   ├── channel.030303.png
# │   │   │   │   ├── channel.181818.png
# │   │   │   │   ├── channel.272727.png
# │   │   │   │   ├── channel.373737.png
# │   │   │   │   ├── channel.474747.png
# │   │   │   │   ├── channel.585858.png
# │   │   │   │   ├── channel.696969.png
# │   │   │   │   ├── channel.777777.png
# │   │   │   │   ├── channel.878787.png
# │   │   │   │   ├── channel.979797.png
# │   │   │   │   ├── channel.a6a6a6.png
# │   │   │   │   ├── channel.b7b7b7.png
# │   │   │   │   ├── channel.c8c8c8.png
# │   │   │   │   ├── channel.d7d7d7.png
# │   │   │   │   ├── channel.e8e8e8.png
# │   │   │   │   ├── channel.fefefe.png
# │   │   │   │   └── octree.png
# │   │   │   ├── raw.png
# │   │   │   ├── raw_o16.png
# │   │   │   ├── raw_o8.png
# │   │   │   └── testx
# │   │   │       ├── channel.070707.png
# │   │   │       ├── channel.2d2d2d.png
# │   │   │       ├── channel.535353.png
# │   │   │       ├── channel.707070.png
# │   │   │       ├── channel.8f8f8f.png
# │   │   │       ├── channel.adadad.png
# │   │   │       ├── channel.d1d1d1.png
# │   │   │       ├── channel.fefefe.png
# │   │   │       └── octree.png
# │   │   ├── image.6.1.49_285.542_721
# │   │   │   ├── images.html
# │   │   │   ├── octree
# │   │   │   │   ├── binary.png
# │   │   │   │   ├── channel.060606.png
# │   │   │   │   ├── channel.2c2c2c.png
# │   │   │   │   ├── channel.505050.png
# │   │   │   │   ├── channel.6e6e6e.png
# │   │   │   │   ├── channel.8f8f8f.png
# │   │   │   │   ├── channel.b3b3b3.png
# │   │   │   │   ├── channel.cdcdcd.png
# │   │   │   │   ├── channel.fefefe.png
# │   │   │   │   ├── histogram.svg
# │   │   │   │   └── octree.png
# │   │   │   ├── octree16
# │   │   │   │   ├── channel.010101.png
# │   │   │   │   ├── channel.151515.png
# │   │   │   │   ├── channel.262626.png
# │   │   │   │   ├── channel.373737.png
# │   │   │   │   ├── channel.464646.png
# │   │   │   │   ├── channel.535353.png
# │   │   │   │   ├── channel.676767.png
# │   │   │   │   ├── channel.777777.png
# │   │   │   │   ├── channel.878787.png
# │   │   │   │   ├── channel.979797.png
# │   │   │   │   ├── channel.a7a7a7.png
# │   │   │   │   ├── channel.b8b8b8.png
# │   │   │   │   ├── channel.c9c9c9.png
# │   │   │   │   ├── channel.d8d8d8.png
# │   │   │   │   ├── channel.e7e7e7.png
# │   │   │   │   ├── channel.fefefe.png
# │   │   │   │   └── octree.png
# │   │   │   ├── raw.png
# │   │   │   ├── raw_o16.png
# │   │   │   ├── raw_o8.png
# │   │   │   └── testx
# │   │   │       ├── channel.060606.png
# │   │   │       ├── channel.2c2c2c.png
# │   │   │       ├── channel.505050.png
# │   │   │       ├── channel.6e6e6e.png
# │   │   │       ├── channel.8f8f8f.png
# │   │   │       ├── channel.b3b3b3.png
# │   │   │       ├── channel.cdcdcd.png
# │   │   │       ├── channel.fefefe.png
# │   │   │       └── octree.png
# │   │   ├── image.6.2.310_546.511_711
# │   │   │   ├── images.html
# │   │   │   ├── octree
# │   │   │   │   ├── binary.png
# │   │   │   │   ├── channel.090909.png
# │   │   │   │   ├── channel.303030.png
# │   │   │   │   ├── channel.4d4d4d.png
# │   │   │   │   ├── channel.6f6f6f.png
# │   │   │   │   ├── channel.919191.png
# │   │   │   │   ├── channel.afafaf.png
# │   │   │   │   ├── channel.cecece.png
# │   │   │   │   ├── channel.fefefe.png
# │   │   │   │   ├── histogram.svg
# │   │   │   │   └── octree.png
# │   │   │   ├── octree16
# │   │   │   │   ├── channel.030303.png
# │   │   │   │   ├── channel.181818.png
# │   │   │   │   ├── channel.282828.png
# │   │   │   │   ├── channel.373737.png
# │   │   │   │   ├── channel.464646.png
# │   │   │   │   ├── channel.575757.png
# │   │   │   │   ├── channel.676767.png
# │   │   │   │   ├── channel.777777.png
# │   │   │   │   ├── channel.898989.png
# │   │   │   │   ├── channel.979797.png
# │   │   │   │   ├── channel.a6a6a6.png
# │   │   │   │   ├── channel.b9b9b9.png
# │   │   │   │   ├── channel.c7c7c7.png
# │   │   │   │   ├── channel.d7d7d7.png
# │   │   │   │   ├── channel.e8e8e8.png
# │   │   │   │   ├── channel.fefefe.png
# │   │   │   │   └── octree.png
# │   │   │   ├── raw.png
# │   │   │   ├── raw_o16.png
# │   │   │   ├── raw_o8.png
# │   │   │   └── testx
# │   │   │       ├── channel.090909.png
# │   │   │       ├── channel.303030.png
# │   │   │       ├── channel.4d4d4d.png
# │   │   │       ├── channel.6f6f6f.png
# │   │   │       ├── channel.919191.png
# │   │   │       ├── channel.afafaf.png
# │   │   │       ├── channel.cecece.png
# │   │   │       ├── channel.fefefe.png
# │   │   │       └── octree.png
# │   │   ├── image.7.1.49_285.308_507
# │   │   │   ├── images.html
# │   │   │   ├── octree
# │   │   │   │   ├── binary.png
# │   │   │   │   ├── channel.060606.png
# │   │   │   │   ├── channel.2c2c2c.png
# │   │   │   │   ├── channel.4e4e4e.png
# │   │   │   │   ├── channel.6b6b6b.png
# │   │   │   │   ├── channel.8d8d8d.png
# │   │   │   │   ├── channel.aeaeae.png
# │   │   │   │   ├── channel.cecece.png
# │   │   │   │   ├── channel.fefefe.png
# │   │   │   │   ├── histogram.svg
# │   │   │   │   └── octree.png
# │   │   │   ├── octree16
# │   │   │   │   ├── channel.020202.png
# │   │   │   │   ├── channel.171717.png
# │   │   │   │   ├── channel.262626.png
# │   │   │   │   ├── channel.373737.png
# │   │   │   │   ├── channel.4b4b4b.png
# │   │   │   │   ├── channel.575757.png
# │   │   │   │   ├── channel.686868.png
# │   │   │   │   ├── channel.757575.png
# │   │   │   │   ├── channel.888888.png
# │   │   │   │   ├── channel.979797.png
# │   │   │   │   ├── channel.a7a7a7.png
# │   │   │   │   ├── channel.b8b8b8.png
# │   │   │   │   ├── channel.c6c6c6.png
# │   │   │   │   ├── channel.d7d7d7.png
# │   │   │   │   ├── channel.e9e9e9.png
# │   │   │   │   ├── channel.fefefe.png
# │   │   │   │   └── octree.png
# │   │   │   ├── raw.png
# │   │   │   ├── raw_o16.png
# │   │   │   ├── raw_o8.png
# │   │   │   └── testx
# │   │   │       ├── channel.060606.png
# │   │   │       ├── channel.2c2c2c.png
# │   │   │       ├── channel.4e4e4e.png
# │   │   │       ├── channel.6b6b6b.png
# │   │   │       ├── channel.8d8d8d.png
# │   │   │       ├── channel.aeaeae.png
# │   │   │       ├── channel.cecece.png
# │   │   │       ├── channel.fefefe.png
# │   │   │       └── octree.png
# │   │   └── image.7.2.106_489.563_721
# │   │       ├── images.html
# │   │       ├── octree
# │   │       │   ├── binary.png
# │   │       │   ├── channel.060606.png
# │   │       │   ├── channel.2e2e2e.png
# │   │       │   ├── channel.4f4f4f.png
# │   │       │   ├── channel.6f6f6f.png
# │   │       │   ├── channel.8f8f8f.png
# │   │       │   ├── channel.b2b2b2.png
# │   │       │   ├── channel.cfcfcf.png
# │   │       │   ├── channel.fefefe.png
# │   │       │   ├── histogram.svg
# │   │       │   └── octree.png
# │   │       ├── octree16
# │   │       │   ├── channel.010101.png
# │   │       │   ├── channel.161616.png
# │   │       │   ├── channel.272727.png
# │   │       │   ├── channel.353535.png
# │   │       │   ├── channel.474747.png
# │   │       │   ├── channel.555555.png
# │   │       │   ├── channel.676767.png
# │   │       │   ├── channel.777777.png
# │   │       │   ├── channel.878787.png
# │   │       │   ├── channel.979797.png
# │   │       │   ├── channel.a8a8a8.png
# │   │       │   ├── channel.b7b7b7.png
# │   │       │   ├── channel.c5c5c5.png
# │   │       │   ├── channel.d9d9d9.png
# │   │       │   ├── channel.e5e5e5.png
# │   │       │   ├── channel.fefefe.png
# │   │       │   └── octree.png
# │   │       ├── raw.png
# │   │       ├── raw_o16.png
# │   │       ├── raw_o8.png
# │   │       └── testx
# │   │           ├── channel.060606.png
# │   │           ├── channel.2e2e2e.png
# │   │           ├── channel.4f4f4f.png
# │   │           ├── channel.6f6f6f.png
# │   │           ├── channel.8f8f8f.png
# │   │           ├── channel.b2b2b2.png
# │   │           ├── channel.cfcfcf.png
# │   │           ├── channel.fefefe.png
# │   │           └── octree.png
# │   └── svg
# │       ├── fulltext-page.0.svg
# │       ├── fulltext-page.1.svg
# │       ├── fulltext-page.2.svg
# │       ├── fulltext-page.3.svg
# │       ├── fulltext-page.4.svg
# │       ├── fulltext-page.5.svg
# │       ├── fulltext-page.6.svg
# │       ├── fulltext-page.7.svg
# │       └── fulltext-page.8.svg
# ├── logs
# │   └── ami.log
# ├── make_project.json
# ├── rettenwander2016
# │   ├── fulltext.pdf
# │   ├── pdfimages
# │   │   ├── image.4.2.52_288.91_286
# │   │   │   ├── images.html
# │   │   │   ├── octree
# │   │   │   │   ├── binary.png
# │   │   │   │   ├── channel.3e403c.png
# │   │   │   │   ├── channel.605e92.png
# │   │   │   │   ├── channel.628e61.png
# │   │   │   │   ├── channel.907399.png
# │   │   │   │   ├── channel.a29477.png
# │   │   │   │   ├── channel.b15955.png
# │   │   │   │   ├── channel.f9f9f8.png
# │   │   │   │   ├── histogram.svg
# │   │   │   │   └── octree.png
# │   │   │   ├── octree16
# │   │   │   │   ├── channel.3e403c.png
# │   │   │   │   ├── channel.615e93.png
# │   │   │   │   ├── channel.628e61.png
# │   │   │   │   ├── channel.8e7399.png
# │   │   │   │   ├── channel.a29477.png
# │   │   │   │   ├── channel.b15955.png
# │   │   │   │   ├── channel.f9f9f8.png
# │   │   │   │   └── octree.png
# │   │   │   ├── raw.png
# │   │   │   ├── raw_o16.png
# │   │   │   ├── raw_o8.png
# │   │   │   └── testx
# │   │   │       ├── channel.3e403c.png
# │   │   │       ├── channel.605e92.png
# │   │   │       ├── channel.628e61.png
# │   │   │       ├── channel.907399.png
# │   │   │       ├── channel.a29477.png
# │   │   │       ├── channel.b15955.png
# │   │   │       ├── channel.f9f9f8.png
# │   │   │       └── octree.png
# │   │   ├── image.6.1.308_543.481_656
# │   │   │   ├── images.html
# │   │   │   ├── octree
# │   │   │   │   ├── binary.png
# │   │   │   │   ├── channel.4a4856.png
# │   │   │   │   ├── channel.535693.png
# │   │   │   │   ├── channel.f3f3f3.png
# │   │   │   │   ├── histogram.svg
# │   │   │   │   └── octree.png
# │   │   │   ├── octree16
# │   │   │   │   ├── channel.282623.png
# │   │   │   │   ├── channel.3c4a8f.png
# │   │   │   │   ├── channel.3d457a.png
# │   │   │   │   ├── channel.545793.png
# │   │   │   │   ├── channel.5c5a6e.png
# │   │   │   │   ├── channel.f3f3f3.png
# │   │   │   │   └── octree.png
# │   │   │   ├── raw.png
# │   │   │   ├── raw_o16.png
# │   │   │   ├── raw_o8.png
# │   │   │   └── testx
# │   │   │       ├── channel.4a4856.png
# │   │   │       ├── channel.535693.png
# │   │   │       ├── channel.f3f3f3.png
# │   │   │       └── octree.png
# │   │   ├── image.6.2.308_543.91_414
# │   │   │   ├── images.html
# │   │   │   ├── octree
# │   │   │   │   ├── binary.png
# │   │   │   │   ├── channel.309d53.png
# │   │   │   │   ├── channel.47445b.png
# │   │   │   │   ├── channel.51468c.png
# │   │   │   │   ├── channel.63a98f.png
# │   │   │   │   ├── channel.8775a8.png
# │   │   │   │   ├── channel.c25645.png
# │   │   │   │   ├── channel.cd9c45.png
# │   │   │   │   ├── channel.fafaf9.png
# │   │   │   │   ├── histogram.svg
# │   │   │   │   └── octree.png
# │   │   │   ├── octree16
# │   │   │   │   ├── channel.119a52.png
# │   │   │   │   ├── channel.47445b.png
# │   │   │   │   ├── channel.51468c.png
# │   │   │   │   ├── channel.5ba25a.png
# │   │   │   │   ├── channel.659e3c.png
# │   │   │   │   ├── channel.6aab8d.png
# │   │   │   │   ├── channel.8775a8.png
# │   │   │   │   ├── channel.c25645.png
# │   │   │   │   ├── channel.cd9c45.png
# │   │   │   │   ├── channel.fafaf9.png
# │   │   │   │   └── octree.png
# │   │   │   ├── raw.png
# │   │   │   ├── raw_o16.png
# │   │   │   ├── raw_o8.png
# │   │   │   └── testx
# │   │   │       ├── channel.309d53.png
# │   │   │       ├── channel.47445b.png
# │   │   │       ├── channel.51468c.png
# │   │   │       ├── channel.63a98f.png
# │   │   │       ├── channel.8775a8.png
# │   │   │       ├── channel.c25645.png
# │   │   │       ├── channel.cd9c45.png
# │   │   │       ├── channel.fafaf9.png
# │   │   │       └── octree.png
# │   │   ├── image.7.1.303_547.252_737
# │   │   │   ├── images.html
# │   │   │   ├── octree
# │   │   │   │   ├── binary.png
# │   │   │   │   ├── channel.060606.png
# │   │   │   │   ├── channel.2e2e2e.png
# │   │   │   │   ├── channel.4f4f4f.png
# │   │   │   │   ├── channel.6f6f6f.png
# │   │   │   │   ├── channel.8f8f8f.png
# │   │   │   │   ├── channel.afafaf.png
# │   │   │   │   ├── channel.d0d0d0.png
# │   │   │   │   ├── channel.fefefe.png
# │   │   │   │   ├── histogram.svg
# │   │   │   │   └── octree.png
# │   │   │   ├── octree16
# │   │   │   │   ├── channel.030303.png
# │   │   │   │   ├── channel.161616.png
# │   │   │   │   ├── channel.262626.png
# │   │   │   │   ├── channel.373737.png
# │   │   │   │   ├── channel.474747.png
# │   │   │   │   ├── channel.575757.png
# │   │   │   │   ├── channel.676767.png
# │   │   │   │   ├── channel.777777.png
# │   │   │   │   ├── channel.878787.png
# │   │   │   │   ├── channel.979797.png
# │   │   │   │   ├── channel.a7a7a7.png
# │   │   │   │   ├── channel.b7b7b7.png
# │   │   │   │   ├── channel.c7c7c7.png
# │   │   │   │   ├── channel.d6d6d6.png
# │   │   │   │   ├── channel.e9e9e9.png
# │   │   │   │   ├── channel.fefefe.png
# │   │   │   │   └── octree.png
# │   │   │   ├── raw.png
# │   │   │   ├── raw_o16.png
# │   │   │   ├── raw_o8.png
# │   │   │   └── testx
# │   │   │       ├── channel.060606.png
# │   │   │       ├── channel.2e2e2e.png
# │   │   │       ├── channel.4f4f4f.png
# │   │   │       ├── channel.6f6f6f.png
# │   │   │       ├── channel.8f8f8f.png
# │   │   │       ├── channel.afafaf.png
# │   │   │       ├── channel.d0d0d0.png
# │   │   │       ├── channel.fefefe.png
# │   │   │       └── octree.png
# │   │   └── image.7.2.52_288.488_726
# │   │       ├── images.html
# │   │       ├── octree
# │   │       │   ├── binary.png
# │   │       │   ├── channel.50494a.png
# │   │       │   ├── channel.746589.png
# │   │       │   ├── channel.847b77.png
# │   │       │   ├── channel.877497.png
# │   │       │   ├── channel.fcfcfb.png
# │   │       │   ├── histogram.svg
# │   │       │   └── octree.png
# │   │       ├── octree16
# │   │       │   ├── channel.2e2b28.png
# │   │       │   ├── channel.423d39.png
# │   │       │   ├── channel.47413d.png
# │   │       │   ├── channel.5b5355.png
# │   │       │   ├── channel.746589.png
# │   │       │   ├── channel.847b77.png
# │   │       │   ├── channel.877497.png
# │   │       │   ├── channel.fcfcfb.png
# │   │       │   └── octree.png
# │   │       ├── raw.png
# │   │       ├── raw_o16.png
# │   │       ├── raw_o8.png
# │   │       └── testx
# │   │           ├── channel.50494a.png
# │   │           ├── channel.746589.png
# │   │           ├── channel.847b77.png
# │   │           ├── channel.877497.png
# │   │           ├── channel.fcfcfb.png
# │   │           └── octree.png
# │   └── svg
# │       ├── fulltext-page.0.svg
# │       ├── fulltext-page.1.svg
# │       ├── fulltext-page.10.svg
# │       ├── fulltext-page.2.svg
# │       ├── fulltext-page.3.svg
# │       ├── fulltext-page.4.svg
# │       ├── fulltext-page.5.svg
# │       ├── fulltext-page.6.svg
# │       ├── fulltext-page.7.svg
# │       ├── fulltext-page.8.svg
# │       └── fulltext-page.9.svg
# ├── steffen
# │   ├── figures.txt
# │   ├── heitjans2012
# │   │   ├── fulltext.pdf
# │   │   ├── pdfimages
# │   │   │   ├── image.3.1.67_294.51_207
# │   │   │   │   ├── images.html
# │   │   │   │   ├── octree16
# │   │   │   │   │   ├── channel.002c90.png
# │   │   │   │   │   ├── channel.0f1616.png
# │   │   │   │   │   ├── channel.1f53a4.png
# │   │   │   │   │   ├── channel.3b4343.png
# │   │   │   │   │   ├── channel.4b75b6.png
# │   │   │   │   │   ├── channel.5c6262.png
# │   │   │   │   │   ├── channel.7393c6.png
# │   │   │   │   │   ├── channel.7b8182.png
# │   │   │   │   │   ├── channel.eb1118.png
# │   │   │   │   │   ├── channel.f05a61.png
# │   │   │   │   │   ├── channel.fdfdfd.png
# │   │   │   │   │   └── octree.png
# │   │   │   │   ├── raw
# │   │   │   │   │   └── raw.svg
# │   │   │   │   ├── raw.png
# │   │   │   │   ├── raw_o16.png
# │   │   │   │   ├── raw_o8.png
# │   │   │   │   └── testx
# │   │   │   │       ├── channel.002c90.png
# │   │   │   │       ├── channel.1f53a4.png
# │   │   │   │       ├── channel.2b3131.png
# │   │   │   │       ├── channel.4b75b6.png
# │   │   │   │       ├── channel.7a8287.png
# │   │   │   │       ├── channel.ec262c.png
# │   │   │   │       ├── channel.fdfdfd.png
# │   │   │   │       └── octree.png
# │   │   │   ├── image.3.2.110_515.425_709
# │   │   │   │   ├── images.html
# │   │   │   │   ├── octree16
# │   │   │   │   │   ├── channel.002fd7.png
# │   │   │   │   │   ├── channel.005edf.png
# │   │   │   │   │   ├── channel.008f1a.png
# │   │   │   │   │   ├── channel.080c09.png
# │   │   │   │   │   ├── channel.10ac5e.png
# │   │   │   │   │   ├── channel.52719d.png
# │   │   │   │   │   ├── channel.52acaf.png
# │   │   │   │   │   ├── channel.e21f22.png
# │   │   │   │   │   ├── channel.f17d82.png
# │   │   │   │   │   ├── channel.fafcfc.png
# │   │   │   │   │   └── octree.png
# │   │   │   │   ├── raw
# │   │   │   │   ├── raw.orig.png
# │   │   │   │   ├── raw.png
# │   │   │   │   ├── raw_o16.png
# │   │   │   │   ├── raw_o8.png
# │   │   │   │   └── testx
# │   │   │   │       ├── channel.0ca54e.png
# │   │   │   │       ├── channel.252525.png
# │   │   │   │       ├── channel.343e96.png
# │   │   │   │       ├── channel.4fb8b2.png
# │   │   │   │       ├── channel.ea2f36.png
# │   │   │   │       ├── channel.fcfcfc.png
# │   │   │   │       └── octree.png
# │   │   │   ├── image.4.1.135_490.51_391
# │   │   │   │   ├── images.html
# │   │   │   │   ├── octree16
# │   │   │   │   │   ├── channel.003c9a.png
# │   │   │   │   │   ├── channel.009a3a.png
# │   │   │   │   │   ├── channel.09a651.png
# │   │   │   │   │   ├── channel.145ba8.png
# │   │   │   │   │   ├── channel.2d3636.png
# │   │   │   │   │   ├── channel.66c996.png
# │   │   │   │   │   ├── channel.6d9cc9.png
# │   │   │   │   │   ├── channel.778684.png
# │   │   │   │   │   ├── channel.ee3e45.png
# │   │   │   │   │   ├── channel.fbfcfc.png
# │   │   │   │   │   └── octree.png
# │   │   │   │   ├── raw.png
# │   │   │   │   ├── raw_o16.png
# │   │   │   │   ├── raw_o8.png
# │   │   │   │   └── testx
# │   │   │   │       ├── channel.09a54f.png
# │   │   │   │       ├── channel.1559a6.png
# │   │   │   │       ├── channel.2d3636.png
# │   │   │   │       ├── channel.719c90.png
# │   │   │   │       ├── channel.ee3e45.png
# │   │   │   │       ├── channel.fbfcfc.png
# │   │   │   │       └── octree.png
# │   │   │   ├── image.5.1.128_497.51_300
# │   │   │   │   ├── images.html
# │   │   │   │   ├── octree16
# │   │   │   │   │   ├── channel.009a3a.png
# │   │   │   │   │   ├── channel.0aa651.png
# ...
# │   │   │       │   ├── channel.f677f3.png
# │   │   │       │   ├── channel.f71011.png
# │   │   │       │   ├── channel.f85e5f.png
# │   │   │       │   ├── channel.fdfdfd.png
# │   │   │       │   └── octree.png
# │   │   │       ├── raw.png
# │   │   │       ├── raw_o16.png
# │   │   │       ├── raw_o8.png
# │   │   │       └── testx
# │   │   │           ├── channel.222e23.png
# │   │   │           ├── channel.2526f0.png
# │   │   │           ├── channel.369737.png
# │   │   │           ├── channel.f62627.png
# │   │   │           ├── channel.f677f3.png
# │   │   │           ├── channel.fdfdfd.png
# │   │   │           └── octree.png
# │   │   └── svg
# │   │       ├── fulltext-page.0.svg
# │   │       ├── fulltext-page.1.svg
# │   │       ├── fulltext-page.2.svg
# │   │       ├── fulltext-page.3.svg
# │   │       └── fulltext-page.4.svg
# │   └── weppner2011
# │       ├── fulltext.pdf
# │       ├── pdfimages
# │       │   ├── image.2.1.340_532.50_216
# │       │   │   ├── images.html
# │       │   │   ├── octree16
# │       │   │   │   ├── channel.000000.png
# │       │   │   │   ├── channel.ffffff.png
# │       │   │   │   └── octree.png
# │       │   │   ├── raw.png
# │       │   │   ├── raw_o16.png
# │       │   │   ├── raw_o8.png
# │       │   │   └── testx
# │       │   │       ├── channel.000000.png
# │       │   │       ├── channel.ffffff.png
# │       │   │       └── octree.png
# │       │   ├── image.6.1.134_473.50_170
# │       │   │   ├── images.html
# │       │   │   ├── octree16
# │       │   │   │   ├── channel.000000.png
# │       │   │   │   ├── channel.f8f8f8.png
# │       │   │   │   └── octree.png
# │       │   │   ├── raw.png
# │       │   │   ├── raw_o16.png
# │       │   │   ├── raw_o8.png
# │       │   │   └── testx
# │       │   │       ├── channel.000000.png
# │       │   │       ├── channel.f8f8f8.png
# │       │   │       └── octree.png
# │       │   ├── image.7.1.51_292.50_196
# │       │   │   ├── images.html
# │       │   │   ├── octree16
# │       │   │   │   ├── channel.000000.png
# │       │   │   │   ├── channel.f7f7f7.png
# │       │   │   │   └── octree.png
# │       │   │   ├── raw.png
# │       │   │   ├── raw_o16.png
# │       │   │   ├── raw_o8.png
# │       │   │   └── testx
# │       │   │       ├── channel.000000.png
# │       │   │       ├── channel.f7f7f7.png
# │       │   │       └── octree.png
# │       │   └── image.8.1.51_292.50_409
# │       │       ├── images.html
# │       │       ├── octree16
# │       │       │   ├── channel.000000.png
# │       │       │   ├── channel.454545.png
# │       │       │   └── octree.png
# │       │       ├── raw.png
# │       │       ├── raw_o16.png
# │       │       ├── raw_o8.png
# │       │       └── testx
# │       │           ├── channel.000000.png
# │       │           ├── channel.454545.png
# │       │           └── octree.png
# │       └── svg
# │           ├── fulltext-page.0.svg
# │           ├── fulltext-page.1.svg
# │           ├── fulltext-page.2.svg
# │           ├── fulltext-page.3.svg
# │           ├── fulltext-page.4.svg
# │           ├── fulltext-page.5.svg
# │           ├── fulltext-page.6.svg
# │           ├── fulltext-page.7.svg
# │           └── fulltext-page.8.svg
# ├── vaughey2013
# │   ├── fulltext.pdf
# │   ├── pdfimages
# │   │   ├── image.3.1.49_285.71_275
# │   │   │   ├── images.html
# │   │   │   ├── octree
# │   │   │   │   ├── binary.png
# │   │   │   │   ├── channel.34966a.png
# │   │   │   │   ├── channel.3d4248.png
# │   │   │   │   ├── channel.546395.png
# │   │   │   │   ├── channel.6ba69e.png
# │   │   │   │   ├── channel.c57697.png
# │   │   │   │   ├── channel.c65a63.png
# │   │   │   │   ├── channel.fafafa.png
# │   │   │   │   ├── histogram.svg
# │   │   │   │   └── octree.png
# │   │   │   ├── octree16
# │   │   │   │   ├── channel.2c9466.png
# │   │   │   │   ├── channel.3d4248.png
# │   │   │   │   ├── channel.4b9b75.png
# │   │   │   │   ├── channel.546395.png
# │   │   │   │   ├── channel.6ba69e.png
# │   │   │   │   ├── channel.b4565e.png
# │   │   │   │   ├── channel.b57495.png
# │   │   │   │   ├── channel.ce7899.png
# │   │   │   │   ├── channel.d0616a.png
# │   │   │   │   ├── channel.fafafa.png
# │   │   │   │   └── octree.png
# │   │   │   ├── raw.png
# │   │   │   ├── raw_o16.png
# │   │   │   ├── raw_o8.png
# │   │   │   └── testx
# │   │   │       ├── channel.34966a.png
# │   │   │       ├── channel.3d4248.png
# │   │   │       ├── channel.546395.png
# │   │   │       ├── channel.6ba69e.png
# │   │   │       ├── channel.c57697.png
# │   │   │       ├── channel.c65a63.png
# │   │   │       ├── channel.fafafa.png
# │   │   │       └── octree.png
# │   │   ├── image.3.2.49_285.351_596
# │   │   │   ├── images.html
# │   │   │   ├── octree
# │   │   │   │   ├── binary.png
# │   │   │   │   ├── channel.1f8c56.png
# │   │   │   │   ├── channel.25292d.png
# │   │   │   │   ├── channel.525992.png
# │   │   │   │   ├── channel.71a195.png
# │   │   │   │   ├── channel.bf689b.png
# │   │   │   │   ├── channel.d7474d.png
# │   │   │   │   ├── channel.fdfdfd.png
# │   │   │   │   ├── histogram.svg
# │   │   │   │   └── octree.png
# │   │   │   ├── octree16
# │   │   │   │   ├── channel.1f8c56.png
# │   │   │   │   ├── channel.25292d.png
# │   │   │   │   ├── channel.525992.png
# │   │   │   │   ├── channel.71a195.png
# │   │   │   │   ├── channel.bf689b.png
# │   │   │   │   ├── channel.d4363a.png
# │   │   │   │   ├── channel.d83a43.png
# │   │   │   │   ├── channel.da555a.png
# │   │   │   │   ├── channel.fdfdfd.png
# │   │   │   │   └── octree.png
# │   │   │   ├── raw.png
# │   │   │   ├── raw_o16.png
# │   │   │   ├── raw_o8.png
# │   │   │   └── testx
# │   │   │       ├── channel.1f8c56.png
# │   │   │       ├── channel.25292d.png
# │   │   │       ├── channel.525992.png
# │   │   │       ├── channel.71a195.png
# │   │   │       ├── channel.bf689b.png
# │   │   │       ├── channel.d7474d.png
# │   │   │       ├── channel.fdfdfd.png
# │   │   │       └── octree.png
# │   │   ├── image.3.3.310_546.230_446
# │   │   │   ├── images.html
# │   │   │   ├── octree
# │   │   │   │   ├── binary.png
# │   │   │   │   ├── channel.218e58.png
# │   │   │   │   ├── channel.23262b.png
# │   │   │   │   ├── channel.4f5594.png
# │   │   │   │   ├── channel.6eaa9c.png
# │   │   │   │   ├── channel.be689a.png
# │   │   │   │   ├── channel.d4494f.png
# │   │   │   │   ├── channel.fdfdfd.png
# │   │   │   │   ├── histogram.svg
# │   │   │   │   └── octree.png
# │   │   │   ├── octree16
# │   │   │   │   ├── channel.1a8a52.png
# │   │   │   │   ├── channel.23262b.png
# │   │   │   │   ├── channel.4ba275.png
# │   │   │   │   ├── channel.4f5594.png
# │   │   │   │   ├── channel.6eaa9c.png
# │   │   │   │   ├── channel.be689a.png
# │   │   │   │   ├── channel.d2363b.png
# │   │   │   │   ├── channel.d23a44.png
# │   │   │   │   ├── channel.d8585e.png
# │   │   │   │   ├── channel.fdfdfd.png
# │   │   │   │   └── octree.png
# │   │   │   ├── raw.png
# │   │   │   ├── raw_o16.png
# │   │   │   ├── raw_o8.png
# │   │   │   └── testx
# │   │   │       ├── channel.218e58.png
# │   │   │       ├── channel.23262b.png
# │   │   │       ├── channel.4f5594.png
# │   │   │       ├── channel.6eaa9c.png
# │   │   │       ├── channel.be689a.png
# │   │   │       ├── channel.d4494f.png
# │   │   │       ├── channel.fdfdfd.png
# │   │   │       └── octree.png
# │   │   ├── image.3.4.310_546.502_711
# │   │   │   ├── images.html
# │   │   │   ├── octree
# │   │   │   │   ├── binary.png
# │   │   │   │   ├── channel.060606.png
# │   │   │   │   ├── channel.2f2f2f.png
# │   │   │   │   ├── channel.4d4d4d.png
# │   │   │   │   ├── channel.6e6e6e.png
# │   │   │   │   ├── channel.8f8f8f.png
# │   │   │   │   ├── channel.b1b1b1.png
# │   │   │   │   ├── channel.d0d0d0.png
# │   │   │   │   ├── channel.fefefe.png
# │   │   │   │   ├── histogram.svg
# │   │   │   │   └── octree.png
# │   │   │   ├── octree16
# │   │   │   │   ├── channel.030303.png
# │   │   │   │   ├── channel.171717.png
# │   │   │   │   ├── channel.272727.png
# │   │   │   │   ├── channel.353535.png
# │   │   │   │   ├── channel.474747.png
# │   │   │   │   ├── channel.575757.png
# │   │   │   │   ├── channel.686868.png
# │   │   │   │   ├── channel.767676.png
# │   │   │   │   ├── channel.898989.png
# │   │   │   │   ├── channel.989898.png
# │   │   │   │   ├── channel.a7a7a7.png
# │   │   │   │   ├── channel.b9b9b9.png
# │   │   │   │   ├── channel.c7c7c7.png
# │   │   │   │   ├── channel.d6d6d6.png
# │   │   │   │   ├── channel.e7e7e7.png
# │   │   │   │   ├── channel.fefefe.png
# │   │   │   │   └── octree.png
# │   │   │   ├── raw.png
# │   │   │   ├── raw_o16.png
# │   │   │   ├── raw_o8.png
# │   │   │   └── testx
# │   │   │       ├── channel.060606.png
# │   │   │       ├── channel.2f2f2f.png
# │   │   │       ├── channel.4d4d4d.png
# │   │   │       ├── channel.6e6e6e.png
# │   │   │       ├── channel.8f8f8f.png
# │   │   │       ├── channel.b1b1b1.png
# │   │   │       ├── channel.d0d0d0.png
# │   │   │       ├── channel.fefefe.png
# │   │   │       └── octree.png
# │   │   ├── image.4.1.134_461.311_691
# │   │   │   ├── images.html
# │   │   │   ├── octree
# │   │   │   │   ├── binary.png
# │   │   │   │   ├── channel.3b3e3c.png
# │   │   │   │   ├── channel.488c67.png
# │   │   │   │   ├── channel.4d5797.png
# │   │   │   │   ├── channel.72a095.png
# │   │   │   │   ├── channel.ab8579.png
# │   │   │   │   ├── channel.b5688d.png
# │   │   │   │   ├── channel.ca3b47.png
# │   │   │   │   ├── channel.fcfcfc.png
# │   │   │   │   ├── histogram.svg
# │   │   │   │   └── octree.png
# │   │   │   ├── octree16
# │   │   │   │   ├── channel.36845a.png
# │   │   │   │   ├── channel.394a8e.png
# │   │   │   │   ├── channel.3b3e3c.png
# │   │   │   │   ├── channel.52906e.png
# │   │   │   │   ├── channel.565d9b.png
# │   │   │   │   ├── channel.72a194.png
# │   │   │   │   ├── channel.958578.png
# │   │   │   │   ├── channel.b5688d.png
# │   │   │   │   ├── channel.ca3b47.png
# │   │   │   │   ├── channel.fcfcfc.png
# │   │   │   │   └── octree.png
# │   │   │   ├── raw.png
# │   │   │   ├── raw_o16.png
# │   │   │   ├── raw_o8.png
# │   │   │   └── testx
# │   │   │       ├── channel.3b3e3c.png
# │   │   │       ├── channel.488c67.png
# │   │   │       ├── channel.4d5797.png
# │   │   │       ├── channel.72a095.png
# │   │   │       ├── channel.ab8579.png
# │   │   │       ├── channel.b5688d.png
# │   │   │       ├── channel.ca3b47.png
# │   │   │       ├── channel.fcfcfc.png
# │   │   │       └── octree.png
# │   │   ├── image.5.1.49_285.538_711
# │   │   │   ├── images.html
# │   │   │   ├── octree
# │   │   │   │   ├── binary.png
# │   │   │   │   ├── channel.3e3e3e.png
# │   │   │   │   ├── channel.d84850.png
# │   │   │   │   ├── channel.fdfdfd.png
# │   │   │   │   ├── histogram.svg
# │   │   │   │   └── octree.png
# │   │   │   ├── octree16
# │   │   │   │   ├── channel.3e3e3e.png
# │   │   │   │   ├── channel.dc3946.png
# │   │   │   │   ├── channel.dc565d.png
# │   │   │   │   ├── channel.de3439.png
# │   │   │   │   ├── channel.fdfdfd.png
# │   │   │   │   └── octree.png
# │   │   │   ├── raw.png
# │   │   │   ├── raw_o16.png
# │   │   │   ├── raw_o8.png
# │   │   │   └── testx
# │   │   │       ├── channel.3e3e3e.png
# │   │   │       ├── channel.d84850.png
# │   │   │       ├── channel.fdfdfd.png
# │   │   │       └── octree.png
# │   │   └── image.5.3.310_546.531_711
# │   │       ├── images.html
# │   │       ├── octree
# │   │       │   ├── binary.png
# │   │       │   ├── channel.27272a.png
# │   │       │   ├── channel.3e4093.png
# │   │       │   ├── channel.fefefe.png
# │   │       │   ├── histogram.svg
# │   │       │   └── octree.png
# │   │       ├── octree16
# │   │       │   ├── channel.1a1a1a.png
# │   │       │   ├── channel.2f3074.png
# │   │       │   ├── channel.343690.png
# │   │       │   ├── channel.5b5c99.png
# │   │       │   ├── channel.5d5d5e.png
# │   │       │   ├── channel.fefefe.png
# │   │       │   └── octree.png
# │   │       ├── raw.png
# │   │       ├── raw_o16.png
# │   │       ├── raw_o8.png
# │   │       └── testx
# │   │           ├── channel.27272a.png
# │   │           ├── channel.3e4093.png
# │   │           ├── channel.fefefe.png
# │   │           └── octree.png
# │   └── svg
# │       ├── fulltext-page.0.svg
# │       ├── fulltext-page.1.svg
# │       ├── fulltext-page.2.svg
# │       ├── fulltext-page.3.svg
# │       ├── fulltext-page.4.svg
# │       └── fulltext-page.5.svg
# ├── wang2015
# │   ├── fulltext.pdf
# │   ├── pdfimages
# │   │   └── image.4.1.137_449.59_250
# │   │       ├── images.html
# │   │       ├── octree
# │   │       │   ├── binary.png
# │   │       │   ├── channel.222e23.png
# │   │       │   ├── channel.2526f0.png
# │   │       │   ├── channel.369737.png
# │   │       │   ├── channel.f62627.png
# │   │       │   ├── channel.f677f3.png
# │   │       │   ├── channel.fdfdfd.png
# │   │       │   ├── histogram.svg
# │   │       │   └── octree.png
# │   │       ├── octree16
# │   │       │   ├── channel.222e23.png
# │   │       │   ├── channel.2526f0.png
# │   │       │   ├── channel.369737.png
# │   │       │   ├── channel.f677f3.png
# │   │       │   ├── channel.f71011.png
# │   │       │   ├── channel.f85e5f.png
# │   │       │   ├── channel.fdfdfd.png
# │   │       │   └── octree.png
# │   │       ├── raw.png
# │   │       ├── raw_o16.png
# │   │       ├── raw_o8.png
# │   │       └── testx
# │   │           ├── channel.222e23.png
# │   │           ├── channel.2526f0.png
# │   │           ├── channel.369737.png
# │   │           ├── channel.f62627.png
# │   │           ├── channel.f677f3.png
# │   │           ├── channel.fdfdfd.png
# │   │           └── octree.png
# │   └── svg
# │       ├── fulltext-page.0.svg
# │       ├── fulltext-page.1.svg
# │       ├── fulltext-page.2.svg
# │       ├── fulltext-page.3.svg
# │       └── fulltext-page.4.svg
# └── weppner2011
#     ├── fulltext.pdf
#     ├── pdfimages
#     │   ├── image.2.1.340_532.50_216
#     │   │   ├── images.html
#     │   │   ├── octree
#     │   │   │   ├── binary.png
#     │   │   │   ├── channel.000000.png
#     │   │   │   ├── channel.ffffff.png
#     │   │   │   ├── histogram.svg
#     │   │   │   └── octree.png
#     │   │   ├── octree16
#     │   │   │   ├── channel.000000.png
#     │   │   │   ├── channel.ffffff.png
#     │   │   │   └── octree.png
#     │   │   ├── raw.png
#     │   │   ├── raw_o16.png
#     │   │   ├── raw_o8.png
#     │   │   └── testx
#     │   │       ├── channel.000000.png
#     │   │       ├── channel.ffffff.png
#     │   │       └── octree.png
#     │   ├── image.6.1.134_473.50_170
#     │   │   ├── images.html
#     │   │   ├── octree
#     │   │   │   ├── binary.png
#     │   │   │   ├── channel.000000.png
#     │   │   │   ├── channel.f8f8f8.png
#     │   │   │   ├── histogram.svg
#     │   │   │   └── octree.png
#     │   │   ├── octree16
#     │   │   │   ├── channel.000000.png
#     │   │   │   ├── channel.f8f8f8.png
#     │   │   │   └── octree.png
#     │   │   ├── raw.png
#     │   │   ├── raw_o16.png
#     │   │   ├── raw_o8.png
#     │   │   └── testx
#     │   │       ├── channel.000000.png
#     │   │       ├── channel.f8f8f8.png
#     │   │       └── octree.png
#     │   ├── image.7.1.51_292.50_196
#     │   │   ├── images.html
#     │   │   ├── octree
#     │   │   │   ├── binary.png
#     │   │   │   ├── channel.000000.png
#     │   │   │   ├── channel.f7f7f7.png
#     │   │   │   ├── histogram.svg
#     │   │   │   └── octree.png
#     │   │   ├── octree16
#     │   │   │   ├── channel.000000.png
#     │   │   │   ├── channel.f7f7f7.png
#     │   │   │   └── octree.png
#     │   │   ├── raw.png
#     │   │   ├── raw_o16.png
#     │   │   ├── raw_o8.png
#     │   │   └── testx
#     │   │       ├── channel.000000.png
#     │   │       ├── channel.f7f7f7.png
#     │   │       └── octree.png
#     │   └── image.8.1.51_292.50_409
#     │       ├── images.html
#     │       ├── octree
#     │       │   ├── binary.png
#     │       │   ├── channel.000000.png
#     │       │   ├── channel.454545.png
#     │       │   ├── histogram.svg
#     │       │   └── octree.png
#     │       ├── octree16
#     │       │   ├── channel.000000.png
#     │       │   ├── channel.454545.png
#     │       │   └── octree.png
#     │       ├── raw.png
#     │       ├── raw_o16.png
#     │       ├── raw_o8.png
#     │       └── testx
#     │           ├── channel.000000.png
#     │           ├── channel.454545.png
#     │           └── octree.png
#     └── svg
#         ├── fulltext-page.0.svg
#         ├── fulltext-page.1.svg
#         ├── fulltext-page.2.svg
#         ├── fulltext-page.3.svg
#         ├── fulltext-page.4.svg
#         ├── fulltext-page.5.svg
#         ├── fulltext-page.6.svg
#         ├── fulltext-page.7.svg
#         └── fulltext-page.8.svg
#
# 376 directories, 2510 files

# %%
from IPython.display import display
from PIL import Image
path="PMC3211491/pdfimages/image.3.1.64_532.102_571/raw.png"
display(Image.open(path))

import ipyplot
images_array = [\
            "PMC3211491/pdfimages/image.3.1.64_532.102_571/raw.png",\
            "PMC3211491/pdfimages/image.4.1.64_532.102_336/raw.png",\
            "PMC3211491/pdfimages/image.4.2.313_531.492_708/raw.png",\
            "PMC3211491/pdfimages/image.5.1.63_533.240_708/raw.png",\
            "PMC3211491/pdfimages/image.6.1.63_286.483_698/raw.png",\
            "PMC3211491/pdfimages/image.6.2.311_534.102_322/raw.png"\
]

ipyplot.plot_images(images_array, max_images=20, img_width=300)

# %%
! pwd

# %%
# !ls

# %%
# !ls PMC3211491/pdfimages/image.3.1.64_532.102_571/raw.png

# %%
# !tree PMC3211491

# %%
images_array = [\
"PMC3211491/pdfimages/image.4.2.313_531.492_708/raw.png",\
"PMC3463005/pdfimages/image.6.2.86_509.389_714/raw.png",\
"PMC3518813/pdfimages/image.2.2.129_466.69_338/raw.png",\
"PMC3776197/pdfimages/image.4.2.58_538.371_714/raw.png",\
"PMC3776197/pdfimages/image.5.2.107_488.253_704/raw.png",\
"PMC3776197/pdfimages/image.7.2.113_483.69_352/raw.png",\
"PMC3893646/pdfimages/image.5.2.48_547.69_472/raw.png",\
"PMC4062906/pdfimages/image.5.1.66_281.517_691/raw.png",\
"PMC4148673/pdfimages/image.3.2.63_272.69_527/raw.png"\
]
ipyplot.plot_images(images_array, max_images=20, img_width=300)

# %%
cd PMC3211491/pdfimages/image.4.2.313_531.492_708/octree

# %%
ls channel*.png

# %%
import glob
image_array = glob.glob("channel*.png")
# print (image_array)
image_array2 = ["PMC3211491/pdfimages/image.4.2.313_531.492_708/octree/" + s for s in image_array]
print(image_array2)
# ! cd /Users/pm286/workspace/work/battery10/PMC3211491/pdfimages/image.4.2.313_531.492_708/octree
ipyplot.plot_images(image_array2, max_images=20, img_width=300)

# %%
import os
! cd $PROJECT_WORK
! ls
! pwd
os.listdir(".")
