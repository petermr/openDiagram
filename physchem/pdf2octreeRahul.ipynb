# %% [markdown]
# # read PDFs, makeproject, extract images and create octrees

# %% [markdown]
# ### variables

# %%
# where is ami3? (assume you have checked out or copied `ami3` distrib).
# set AMI3 to location of LOCAL AMI repository
# EDIT THIS >>>>>>>
HOME = "/Users/pm286/"
WORKSPACE = HOME + "workspace/"
AMI3 = WORKSPACE + "cmdev/ami3/"
# <<<<<<<<<<

# local workspace
# EDIT this >>>>>>>>
WORK = WORKSPACE + "work/"
# <<<<<<<<<<

# specific problem
# EDIT THIS to your project (battery10, thermo at present)
# >>>>>>>
PROJECT = "rahul"
# <<<<<<<

PROJECT_WORK = WORK + PROJECT + "/"


# specific for projects under ami3/src/test/resources
# PROJECT_DATA = AMI_DATA + PROJECT + ".raw" + "/"
PROJECT_DATA = "/Users/pm286/workspace/jupyter/physchem/rahul/"

# %%
print ("working in " + PROJECT_WORK)
! cd $PROJECT_WORK
! ls
print ("copying raw project " + PROJECT_DATA + " => " + PROJECT_WORK)
! cp -R $PROJECT_DATA $PROJECT_WORK
# Out:
# working in /Users/pm286/workspace/work/rahul/
# /bin/bash: line 0: cd: /Users/pm286/workspace/work/rahul/: No such file or directory
# pdf2octreeBattery.ipynb pdf2octreeSteffen.ipynb thermo1.ipynb
# pdf2octreeRahul.ipynb   rahul
# copying raw project /Users/pm286/workspace/jupyter/physchem/rahul/ => /Users/pm286/workspace/work/rahul/

# %%
import os 
os.chdir(PROJECT_WORK)
cwd = os.getcwd()
print("cwd "+cwd)
os.listdir()
# shutil.copytree(PROJECT_DATA, PROJECT_WORK)
# Out:
# cwd /Users/pm286/workspace/work/rahul
# ['rahul1.pdf', 'rahul2.pdf']

# %%
## make project
! ami -p . makeproject --rawfiletypes pdf
os.listdir()
#! ls */*.pdf
#! ls */*.xml
# Out:
# Generic values (AMIMakeProjectTool)
# ================================
#
# Specific values (AMIMakeProjectTool)
# ================================
# ['target', 'rahul2', 'make_project.json', 'logs', 'rahul1']

# %%
! tree
# Out:
# .
# ├── logs
# │   └── ami.log
# ├── make_project.json
# ├── rahul1
# │   └── fulltext.pdf
# ├── rahul2
# │   └── fulltext.pdf
# └── target
#     └── log.xml
#
# 4 directories, 5 files

# %%
print("cwd "+os.getcwd())
! ami -vv -p . pdfbox
! tree
# Out:
# cwd /Users/pm286/workspace/work/rahul
# (The console will show DEBUG level messages)
# (Logs will also be printed to /Users/pm286/workspace/work/rahul/logs/ami.log)
# Version: ami 2020.08.09_09.54-NEXT-SNAPSHOT
# (jar:file:/Users/pm286/workspace/cmdev/ami3/target/appassembler/repo/ami3-2020.08.09_09.54-NEXT-SNAPSHOT.jar)
# JVM: 14.0.1 (Oracle Corporation Java HotSpot(TM) 64-Bit Server VM 14.0.1+7)
# OS: Mac OS X 10.15.7 x86_64
#
#
# Generic values (AMIPDFTool)
# ================================
# input basename      null
# input basename list null
# cproject            /Users/pm286/workspace/work/rahul/.
# ctree
# cTreeList           [./logs, ./rahul1, ./rahul2, ./target]
# excludeBase         {}
# excludeTrees        {}
# forceMake           false
# includeBase         {}
# includeTrees        null
# log4j               {}
# verbose             2
#
# Specific values (AMIPDFTool)
# ================================
# Command line options for 'ami pdfbox':
# --debug             : d AMI_BRIEF
# --imagedir          : d pdfimages/
# --maxpages          : d         5
# --maxprimitives     : d      5000
# --minimagesize      : d   (10,10)
# --pages             : d      null
# --parser            : d       two
# --no-pdfimages      : d      true
# --pdf2txt           : d     false
# --svgdir            : d      svg/
# --no-svgpages       : d      true
# --tidysvg           : d [concat, spaces]
# --help              : d     false
# --version           : d     false
# AMIPDFTool cTree: logs
# cTree: logs
# pi>include: [-1]
#
# AMIPDFTool cTree: rahul1
# cTree: rahul1
# pi>include: [-1]
#
# make skipped AMIPDFTool cTree: rahul2
# cTree: rahul2
# pi>include: [-1]
#
# make skipped AMIPDFTool cTree: target
# cTree: target
# pi>include: [-1]
#
# .
# ├── logs
# │   └── ami.log
# ├── make_project.json
# ├── rahul1
# │   ├── fulltext.pdf
# │   ├── pdfimages
# │   │   ├── image.1.1.533_555.28_51.png
# │   │   ├── image.3.1.55_296.95_418.png
# │   │   ├── image.4.1.55_554.95_423.png
# │   │   ├── image.5.1.55_554.347_689.png
# │   │   ├── image.6.1.55_554.95_478.png
# │   │   └── image.7.1.55_554.95_406.png
# │   └── svg
# │       ├── fulltext-page.0.svg
# │       ├── fulltext-page.1.svg
# │       ├── fulltext-page.2.svg
# │       ├── fulltext-page.3.svg
# │       ├── fulltext-page.4.svg
# │       ├── fulltext-page.5.svg
# │       ├── fulltext-page.6.svg
# │       ├── fulltext-page.7.svg
# │       ├── fulltext-page.8.svg
# │       └── fulltext-page.9.svg
# ├── rahul2
# │   ├── fulltext.pdf
# │   ├── pdfimages
# │   │   ├── image.10.1.117_220.367_459.png
# │   │   ├── image.10.11.119_226.628_720.png
# │   │   ├── image.10.12.226_333.628_720.png
# │   │   ├── image.10.13.333_440.628_720.png
# │   │   ├── image.10.14.440_476.628_720.png
# │   │   ├── image.10.2.220_255.367_489.png
# │   │   ├── image.10.3.117_220.458_489.png
# │   │   ├── image.10.5.372_478.363_458.png
# │   │   ├── image.10.7.117_226.513_605.png
# │   │   ├── image.10.8.225_333.513_605.png
# │   │   ├── image.10.9.333_441.513_605.png
# │   │   ├── image.4.1.108_194.232_275.png
# │   │   ├── image.4.2.89_187.77_136.png
# │   │   ├── image.4.3.93_180.142_202.png
# │   │   ├── image.4.4.265_311.178_201.png
# │   │   ├── image.4.5.105_189.290_311.png
# │   │   ├── image.4.6.105_189.327_349.png
# │   │   ├── image.4.7.344_530.237_360.png
# │   │   ├── image.4.8.256_326.244_273.png
# │   │   ├── image.5.1.241_352.86_185.png
# │   │   ├── image.5.2.61_201.112_184.png
# │   │   ├── image.5.3.87_338.242_432.png
# │   │   ├── image.5.4.92_259.486_594.png
# │   │   ├── image.5.5.359_534.120_602.png
# │   │   ├── image.9.1.117_216.72_179.png
# │   │   ├── image.9.10.281_412.286_358.png
# │   │   ├── image.9.11.118_219.458_554.png
# │   │   ├── image.9.12.219_320.458_554.png
# │   │   ├── image.9.13.320_421.458_554.png
# │   │   ├── image.9.14.420_454.458_586.png
# │   │   ├── image.9.15.118_421.554_586.png
# │   │   ├── image.9.2.216_314.72_179.png
# │   │   ├── image.9.3.314_412.72_179.png
# │   │   ├── image.9.5.117_216.179_286.png
# │   │   ├── image.9.6.216_314.179_286.png
# │   │   ├── image.9.7.314_412.179_286.png
# │   │   ├── image.9.8.412_478.250_358.png
# │   │   └── image.9.9.117_282.286_358.png
# │   └── svg
# │       ├── fulltext-page.0.svg
# │       ├── fulltext-page.1.svg
# │       ├── fulltext-page.2.svg
# │       ├── fulltext-page.3.svg
# │       ├── fulltext-page.4.svg
# │       ├── fulltext-page.5.svg
# │       ├── fulltext-page.6.svg
# │       ├── fulltext-page.7.svg
# │       ├── fulltext-page.8.svg
# │       └── fulltext-page.9.svg
# └── target
#     └── log.xml
#
# 8 directories, 69 files

# %%
! ami -vv -p .  --inputname raw --output octree image --octree 8 --outputfiles binary channels histogram neighbours octree
# Out:
# (The console will show DEBUG level messages)
# (Logs will also be printed to /Users/pm286/workspace/work/rahul/logs/ami.log)
# Version: ami 2020.08.09_09.54-NEXT-SNAPSHOT
# (jar:file:/Users/pm286/workspace/cmdev/ami3/target/appassembler/repo/ami3-2020.08.09_09.54-NEXT-SNAPSHOT.jar)
# JVM: 14.0.1 (Oracle Corporation Java HotSpot(TM) 64-Bit Server VM 14.0.1+7)
# OS: Mac OS X 10.15.7 x86_64
#
#
# Generic values (AMIImageTool)
# ================================
# input basename      raw
# input basename list null
# cproject            /Users/pm286/workspace/work/rahul/.
# ctree
# cTreeList           [./logs, ./rahul1, ./rahul2, ./target]
# excludeBase         {}
# excludeTrees        {}
# forceMake           false
# includeBase         {}
# includeTrees        null
# log4j               {}
# verbose             2
#
# Specific values (AMIImageTool)
# ================================
# Command line options for 'ami image':
# --borders           : d      null
# --filter            : d     false
# --exclude           : d      null
# --include           : d      null
# --minheight         : d       100
# --minwidth          : d       100
# --annotate          : d     false
# --binarize          : d      null
# --despeckle         : d     false
# --dither            : d      true
# --erodedilate       : d     false
# --maxheight         : d      1000
# --maxwidth          : d      1000
# --mediancut         : d      null
# --merge             : d         0
# --minpixels         : d       100
# --octree            : m         8
# --outputfiles       : m [binary, channels, histogram, neighbours, octree]
# --panels            : d      null
# --posterize         : d      null
# --priority          : d       RAW
# --rotate            : d      null
# --scalefactor       : d      null
# --serpentine        : d      true
# --sharpen           : d      none
# --template          : d      null
# --thinning          : d      null
# --threshold         : d      null
# --toolkit           : d      null
# --help              : d     false
# --version           : d     false
# AMIImageTool cTree: logs
# AMIImageTool processTree
# no pdfimages/ dir and no image/ dir
# AMIImageTool cTree: rahul1
# AMIImageTool processTree
# converting to subdirectories: 6
# converting: ./rahul1/pdfimages/image.1.1.533_555.28_51.png to image.1.1.533_555.28_51/
# made /Users/pm286/workspace/work/rahul/./rahul1/pdfimages/image.1.1.533_555.28_51/raw.png
# converting: ./rahul1/pdfimages/image.3.1.55_296.95_418.png to image.3.1.55_296.95_418/
# made /Users/pm286/workspace/work/rahul/./rahul1/pdfimages/image.3.1.55_296.95_418/raw.png
# converting: ./rahul1/pdfimages/image.4.1.55_554.95_423.png to image.4.1.55_554.95_423/
# made /Users/pm286/workspace/work/rahul/./rahul1/pdfimages/image.4.1.55_554.95_423/raw.png
# converting: ./rahul1/pdfimages/image.5.1.55_554.347_689.png to image.5.1.55_554.347_689/
# made /Users/pm286/workspace/work/rahul/./rahul1/pdfimages/image.5.1.55_554.347_689/raw.png
# converting: ./rahul1/pdfimages/image.6.1.55_554.95_478.png to image.6.1.55_554.95_478/
# made /Users/pm286/workspace/work/rahul/./rahul1/pdfimages/image.6.1.55_554.95_478/raw.png
# converting: ./rahul1/pdfimages/image.7.1.55_554.95_406.png to image.7.1.55_554.95_406/
# made /Users/pm286/workspace/work/rahul/./rahul1/pdfimages/image.7.1.55_554.95_406/raw.png
#  >>>>> imageDirs: 6
# T: 4761/W: 4564/NW: 197
# *****OK...rahul1//image.1.1.533_555.28_51

# made /Users/pm286/workspace/work/rahul/./rahul2/pdfimages/image.9.5.117_216.179_286/raw.png
# converting: ./rahul2/pdfimages/image.9.6.216_314.179_286.png to image.9.6.216_314.179_286/
# made /Users/pm286/workspace/work/rahul/./rahul2/pdfimages/image.9.6.216_314.179_286/raw.png
# converting: ./rahul2/pdfimages/image.9.7.314_412.179_286.png to image.9.7.314_412.179_286/
# made /Users/pm286/workspace/work/rahul/./rahul2/pdfimages/image.9.7.314_412.179_286/raw.png
# converting: ./rahul2/pdfimages/image.9.8.412_478.250_358.png to image.9.8.412_478.250_358/
# made /Users/pm286/workspace/work/rahul/./rahul2/pdfimages/image.9.8.412_478.250_358/raw.png
# converting: ./rahul2/pdfimages/image.9.9.117_282.286_358.png to image.9.9.117_282.286_358/
# made /Users/pm286/workspace/work/rahul/./rahul2/pdfimages/image.9.9.117_282.286_358/raw.png
#  >>>>> imageDirs: 38
# T: 164307/W: 158146/NW: 6161
# *****OK...rahul2//image.10.1.117_220.367_459
# rahul2//image.10.1.117_220.367_459
# transforming: image.10.1.117_220.367_459/raw.png
# Freq: fa3719: 2210
# Freq: 22fc35: 2106
# Freq: fdfdfb: 154101
# Freq: c12dd7: 437
# Freq: e8da22: 4624
# Freq: 2addd6: 762
# neighbours: fdfdfb>  e8da22 fa3719 22fc35 2addd6 c12dd7 4222f9
# e8da22>  fa3719 22fc35 2addd6 c12dd7 4222f9
# fa3719>  22fc35 2addd6 c12dd7 4222f9
# 22fc35>  2addd6 c12dd7 4222f9
# 2addd6>  c12dd7 4222f9
# c12dd7>  4222f9
#
# htmlFile ./rahul2/pdfimages/image.10.1.117_220.367_459/images.html
# Cannot read file: Cannot read image: ./rahul2/pdfimages/image.10.11.119_226.628_720/raw.png
# *****OK...rahul2//image.10.11.119_226.628_720
# rahul2//image.10.11.119_226.628_720
# transforming: image.10.11.119_226.628_720/raw.png
# java.lang.RuntimeException: Cannot read image: ./rahul2/pdfimages/image.10.11.119_226.628_720/raw.png
# 	at org.contentmine.image.ImageUtil.readImage(ImageUtil.java:956)
# 	at org.contentmine.image.ImageUtil.readImageQuietly(ImageUtil.java:1354)
# 	at org.contentmine.ami.tools.AMIImageTool.runTransform(AMIImageTool.java:538)
# 	at org.contentmine.ami.tools.AMIImageTool.processTransformImageDir(AMIImageTool.java:490)
# 	at org.contentmine.ami.tools.AMIImageTool.processSingleImageFile(AMIImageTool.java:461)
# 	at org.contentmine.ami.tools.AMIImageTool.processImageFile(AMIImageTool.java:822)
# 	at org.contentmine.ami.tools.ImageDirProcessor.processInputName(ImageDirProcessor.java:160)
# 	at org.contentmine.ami.tools.ImageDirProcessor.processImageDir(ImageDirProcessor.java:144)
# 	at org.contentmine.ami.tools.ImageDirProcessor.processDir(ImageDirProcessor.java:75)
# 	at org.contentmine.ami.tools.ImageDirProcessor.processImageDirs(ImageDirProcessor.java:58)
# 	at org.contentmine.ami.tools.AMIImageTool.processTree(AMIImageTool.java:452)
# 	at org.contentmine.ami.tools.AbstractAMITool.processTrees(AbstractAMITool.java:612)
# 	at org.contentmine.ami.tools.AMIImageTool.runSpecifics(AMIImageTool.java:432)
# 	at org.contentmine.ami.tools.AbstractAMITool.runCommands(AbstractAMITool.java:197)
# 	at org.contentmine.ami.tools.AbstractAMITool.call(AbstractAMITool.java:177)
# 	at org.contentmine.ami.tools.AbstractAMITool.call(AbstractAMITool.java:45)
# 	at picocli.CommandLine.executeUserObject(CommandLine.java:1933)
# 	at picocli.CommandLine.access$1100(CommandLine.java:145)
# 	at picocli.CommandLine$RunLast.executeUserObjectOfLastSubcommandWithSameParent(CommandLine.java:2332)
# 	at picocli.CommandLine$RunLast.handle(CommandLine.java:2326)
# 	at picocli.CommandLine$RunLast.handle(CommandLine.java:2291)
# 	at picocli.CommandLine$AbstractParseResultHandler.execute(CommandLine.java:2159)
# 	at org.contentmine.ami.tools.AMI.enhancedLoggingExecutionStrategy(AMI.java:201)
# 	at picocli.CommandLine.execute(CommandLine.java:2058)
# 	at org.contentmine.ami.tools.AMI.main(AMI.java:128)
# Caused by: javax.imageio.IIOException: Caught exception during read:
# 	at java.desktop/com.sun.imageio.plugins.png.PNGImageReader.read(PNGImageReader.java:1827)
# 	at java.desktop/javax.imageio.ImageIO.read(ImageIO.java:1468)
# 	at java.desktop/javax.imageio.ImageIO.read(ImageIO.java:1315)
# 	at org.contentmine.image.ImageUtil.readImage(ImageUtil.java:952)
# 	... 24 more
# Caused by: java.lang.IndexOutOfBoundsException
# 	at java.base/java.io.RandomAccessFile.readBytes(Native Method)
# 	at java.base/java.io.RandomAccessFile.read(RandomAccessFile.java:408)
# 	at java.desktop/javax.imageio.stream.FileImageInputStream.read(FileImageInputStream.java:117)
# 	at java.desktop/com.sun.imageio.plugins.common.SubImageInputStream.read(SubImageInputStream.java:61)
# 	at java.desktop/com.sun.imageio.plugins.common.InputStreamAdapter.read(InputStreamAdapter.java:47)
# 	at java.base/java.io.SequenceInputStream.read(SequenceInputStream.java:198)
# 	at java.base/java.util.zip.InflaterInputStream.fill(InflaterInputStream.java:242)
# 	at java.base/java.util.zip.InflaterInputStream.read(InflaterInputStream.java:158)
# 	at java.base/java.io.BufferedInputStream.fill(BufferedInputStream.java:244)
# 	at java.base/java.io.BufferedInputStream.read1(BufferedInputStream.java:284)
# 	at java.base/java.io.BufferedInputStream.read(BufferedInputStream.java:343)
# 	at java.base/java.io.DataInputStream.readFully(DataInputStream.java:199)
# 	at java.desktop/com.sun.imageio.plugins.png.PNGImageReader.decodePass(PNGImageReader.java:1234)
# 	at java.desktop/com.sun.imageio.plugins.png.PNGImageReader.decodeImage(PNGImageReader.java:1370)
# 	at java.desktop/com.sun.imageio.plugins.png.PNGImageReader.readImage(PNGImageReader.java:1503)
# 	at java.desktop/com.sun.imageio.plugins.png.PNGImageReader.read(PNGImageReader.java:1820)
# 	... 27 more
# Bad read: ./rahul2/pdfimages/image.10.11.119_226.628_720 (Cannot read image: ./rahul2/pdfimages/image.10.11.119_226.628_720/raw.png)
# T: 170754/W: 170586/NW: 168
# *****OK...rahul2//image.10.12.226_333.628_720
# rahul2//image.10.12.226_333.628_720
# transforming: image.10.12.226_333.628_720/raw.png
# Freq: fc022d: 130
# Freq: fbfbfb: 170462
# neighbours: fbfbfb>  fc022d f5234f f55670 03fd03 61fb64 fa6b87
# fc022d>  f5234f f55670 03fd03 61fb64 fa6b87
# f5234f>  f55670 03fd03 61fb64 fa6b87
# f55670>  03fd03 61fb64 fa6b87
# 03fd03>  61fb64 fa6b87
# 61fb64>  fa6b87
#
# htmlFile ./rahul2/pdfimages/image.10.12.226_333.628_720/images.html
# T: 170372/W: 170179/NW: 193
# *****OK...rahul2//image.10.13.333_440.628_720
# rahul2//image.10.13.333_440.628_720
# transforming: image.10.13.333_440.628_720/raw.png
# Freq: fbfbfb: 170053
# Freq: fb042e: 151
# neighbours: fbfbfb>  fb042e f9204b 0dfb0c f9738e f95374 55fa58 3bf945
# fb042e>  f9204b 0dfb0c f9738e f95374 55fa58 3bf945
# f9204b>  0dfb0c f9738e f95374 55fa58 3bf945
# 0dfb0c>  f9738e f95374 55fa58 3bf945
# f9738e>  f95374 55fa58 3bf945
# f95374>  55fa58 3bf945
# 55fa58>  3bf945
#
# htmlFile ./rahul2/pdfimages/image.10.13.333_440.628_720/images.html
# T: 57300/W: 57273/NW: 27
# *****OK...rahul2//image.10.14.440_476.628_720
# rahul2//image.10.14.440_476.628_720
# transforming: image.10.14.440_476.628_720/raw.png
# Freq: fdfdfc: 57231
# neighbours: fdfdfc>  0afd0c a3fea8 5bfa61 c6e9be bedcc9 32f72b d2bec0
# 0afd0c>  a3fea8 5bfa61 c6e9be bedcc9 32f72b d2bec0
# a3fea8>  5bfa61 c6e9be bedcc9 32f72b d2bec0
# 5bfa61>  c6e9be bedcc9 32f72b d2bec0
# c6e9be>  bedcc9 32f72b d2bec0
# bedcc9>  32f72b d2bec0
# 32f72b>  d2bec0
#
# htmlFile ./rahul2/pdfimages/image.10.14.440_476.628_720/images.html
# T: 73440/W: 72151/NW: 1289
# *****OK...rahul2//image.10.2.220_255.367_489
# rahul2//image.10.2.220_255.367_489
# transforming: image.10.2.220_255.367_489/raw.png
# Freq: fefefd: 71334
# Freq: 2135fa: 446
# Freq: f99421: 1205
# Freq: 2cfc16: 262
# Freq: fd7708: 113
# neighbours: fefefd>  f99421 2135fa 2cfc16 fd7708 6394f9 b253cf
# f99421>  2135fa 2cfc16 fd7708 6394f9 b253cf
# 2135fa>  2cfc16 fd7708 6394f9 b253cf
# 2cfc16>  fd7708 6394f9 b253cf
# fd7708>  6394f9 b253cf
# 6394f9>  b253cf
#
# htmlFile ./rahul2/pdfimages/image.10.2.220_255.367_489/images.html
# T: 55341/W: 52243/NW: 3098
# *****OK...rahul2//image.10.3.117_220.458_489
# rahul2//image.10.3.117_220.458_489
# transforming: image.10.3.117_220.458_489/raw.png
# Freq: fcfcfd: 50494
# Freq: 1ce1df: 1823
# Freq: e424d7: 1109
# Freq: 2d2bfa: 1439
# Freq: fa1160: 314
# Freq: fd0134: 152
# neighbours: fcfcfd>  1ce1df 2d2bfa e424d7 fa1160 fd0134 f04d72
# 1ce1df>  2d2bfa e424d7 fa1160 fd0134 f04d72
# 2d2bfa>  e424d7 fa1160 fd0134 f04d72
# e424d7>  fa1160 fd0134 f04d72
# fa1160>  fd0134 f04d72
# fd0134>  f04d72
#
# transforming: image.4.1.108_194.232_275/raw.png
# Freq: 8f8f8f: 570
# Freq: 717171: 443
# Freq: 4f4f4f: 575
# Freq: 2d2d2d: 641
# Freq: 070707: 1131
# Freq: fefefe: 58751
# Freq: d0d0d0: 553
# Freq: b0b0b0: 520
# neighbours: fefefe>  070707 2d2d2d 4f4f4f 8f8f8f d0d0d0 b0b0b0 717171
# 070707>  2d2d2d 4f4f4f 8f8f8f d0d0d0 b0b0b0 717171
# 2d2d2d>  4f4f4f 8f8f8f d0d0d0 b0b0b0 717171
# 4f4f4f>  8f8f8f d0d0d0 b0b0b0 717171
# 8f8f8f>  d0d0d0 b0b0b0 717171
# d0d0d0>  b0b0b0 717171
# b0b0b0>  717171
#
# htmlFile ./rahul2/pdfimages/image.4.1.108_194.232_275/images.html
# T: 101270/W: 97978/NW: 3292
# *****OK...rahul2//image.4.2.89_187.77_136
# rahul2//image.4.2.89_187.77_136
# transforming: image.4.2.89_187.77_136/raw.png
# Freq: 2ed6ef: 2060
# Freq: ea1eb9: 1532
# Freq: f7f7f5: 84660
# Freq: 3adb41: 5394
# Freq: 57494c: 6860
# Freq: 857479: 657
# neighbours: f7f7f5>  57494c 3adb41 2ed6ef ea1eb9 857479 84a27a 517a8d
# 57494c>  3adb41 2ed6ef ea1eb9 857479 84a27a 517a8d
# 3adb41>  2ed6ef ea1eb9 857479 84a27a 517a8d
# 2ed6ef>  ea1eb9 857479 84a27a 517a8d
# ea1eb9>  857479 84a27a 517a8d
# 857479>  84a27a 517a8d
# 84a27a>  517a8d
#
# htmlFile ./rahul2/pdfimages/image.4.2.89_187.77_136/images.html
# T: 90520/W: 88452/NW: 2068
# *****OK...rahul2//image.4.3.93_180.142_202
# rahul2//image.4.3.93_180.142_202
# transforming: image.4.3.93_180.142_202/raw.png
# Freq: 4f4e4d: 4180
# Freq: e8ea1c: 1915
# Freq: f8f8f5: 80426
# Freq: 4a50f5: 3246
# Freq: dd1e23: 721
# neighbours: f8f8f5>  4f4e4d 4a50f5 e8ea1c dd1e23 c17ba0 7b835e 7483b4
# 4f4e4d>  4a50f5 e8ea1c dd1e23 c17ba0 7b835e 7483b4
# 4a50f5>  e8ea1c dd1e23 c17ba0 7b835e 7483b4
# e8ea1c>  dd1e23 c17ba0 7b835e 7483b4
# dd1e23>  c17ba0 7b835e 7483b4
# c17ba0>  7b835e 7483b4
# 7b835e>  7483b4
#
# htmlFile ./rahul2/pdfimages/image.4.3.93_180.142_202/images.html
# T: 17949/W: 17567/NW: 382
# *****OK...rahul2//image.4.4.265_311.178_201
# rahul2//image.4.4.265_311.178_201
# transforming: image.4.4.265_311.178_201/raw.png
# Freq: fbfbfb: 2787
# Freq: cfcfcf: 407
# Freq: ababab: 991
# Freq: 4e4e4e: 2789
# Freq: 6c6c6c: 1266
# Freq: 909090: 1286
# Freq: 303030: 4676
# Freq: 181818: 3747
# neighbours: 303030>  181818 4e4e4e fbfbfb 909090 6c6c6c ababab cfcfcf
# 181818>  4e4e4e fbfbfb 909090 6c6c6c ababab cfcfcf
# 403c3c>  d726d5 1a1ad7 15d71c d71219 ddd915 53a7aa
# d726d5>  1a1ad7 15d71c d71219 ddd915 53a7aa
# 1a1ad7>  15d71c d71219 ddd915 53a7aa
# 15d71c>  d71219 ddd915 53a7aa
# d71219>  ddd915 53a7aa
# ddd915>  53a7aa
#
# htmlFile ./rahul2/pdfimages/image.5.4.92_259.486_594/images.html
# T: 1465290/W: 432051/NW: 1033239
# *****OK...rahul2//image.5.5.359_534.120_602
# rahul2//image.5.5.359_534.120_602
# transforming: image.5.5.359_534.120_602/raw.png
# Freq: b30404: 14620
# Freq: 110f01: 1034763
# Freq: 05bf05: 8663
# Freq: fafafa: 407213
# neighbours: 110f01>  fafafa b30404 05bf05 7e8080 83807e 807e80
# fafafa>  b30404 05bf05 7e8080 83807e 807e80
# b30404>  05bf05 7e8080 83807e 807e80
# 05bf05>  7e8080 83807e 807e80
# 7e8080>  83807e 807e80
# 83807e>  807e80
#
# htmlFile ./rahul2/pdfimages/image.5.5.359_534.120_602/images.html
# T: 183717/W: 183708/NW: 9
# *****OK...rahul2//image.9.1.117_216.72_179
# rahul2//image.9.1.117_216.72_179
# transforming: image.9.1.117_216.72_179/raw.png
# Freq: 6ba36c: 484
# Freq: 6969ac: 965
# Freq: 79a39c: 145
# Freq: fcfcfc: 181092
# Freq: 5f6362: 920
# neighbours: fcfcfc>  6969ac 5f6362 6ba36c 79a39c a0af76 837ce0 82787a
# 6969ac>  5f6362 6ba36c 79a39c a0af76 837ce0 82787a
# 5f6362>  6ba36c 79a39c a0af76 837ce0 82787a
# 6ba36c>  79a39c a0af76 837ce0 82787a
# 79a39c>  a0af76 837ce0 82787a
# a0af76>  837ce0 82787a
# 837ce0>  82787a
#
# htmlFile ./rahul2/pdfimages/image.9.1.117_216.72_179/images.html
# T: 163006/W: 162918/NW: 88
# *****OK...rahul2//image.9.10.281_412.286_358
# rahul2//image.9.10.281_412.286_358
# transforming: image.9.10.281_412.286_358/raw.png
# Freq: 525363: 6423
# Freq: 699c6a: 257
# Freq: f5f4f5: 146171
# Freq: c58e77: 175
# Freq: bd5e5c: 4611
# Freq: 6a6e94: 4688
# Freq: 7b8896: 493
# Freq: bd7894: 188
# neighbours: f5f4f5>  525363 6a6e94 bd5e5c 7b8896 699c6a bd7894 c58e77
# 525363>  6a6e94 bd5e5c 7b8896 699c6a bd7894 c58e77
# 6a6e94>  bd5e5c 7b8896 699c6a bd7894 c58e77
# bd5e5c>  7b8896 699c6a bd7894 c58e77
# 7b8896>  699c6a bd7894 c58e77
# 699c6a>  bd7894 c58e77
# bd7894>  c58e77
#
# htmlFile ./rahul2/pdfimages/image.9.10.281_412.286_358/images.html
# T: 168400/W: 166698/NW: 1702
# *****OK...rahul2//image.9.11.118_219.458_554
# rahul2//image.9.11.118_219.458_554
# transforming: image.9.11.118_219.458_554/raw.png
# Freq: c13222: 882
# Freq: 669dd8: 4410
# Freq: 416da5: 1630
# Freq: efa94b: 5153
# Freq: ecefeb: 140117
# Freq: 4e5351: 13731
# 8eab7a>  827bd8 807e7a
# 827bd8>  807e7a
#
# htmlFile ./rahul2/pdfimages/image.9.5.117_216.179_286/images.html
# T: 183270/W: 183221/NW: 49
# *****OK...rahul2//image.9.6.216_314.179_286
# rahul2//image.9.6.216_314.179_286
# transforming: image.9.6.216_314.179_286/raw.png
# Freq: f4f4f5: 171685
# Freq: 689f6b: 1032
# Freq: 798e9b: 596
# Freq: 6564ae: 6683
# Freq: 8379da: 120
# Freq: 5a5d62: 3070
# neighbours: f4f4f5>  6564ae 5a5d62 689f6b 798e9b 8379da 92a478 827c79
# 6564ae>  5a5d62 689f6b 798e9b 8379da 92a478 827c79
# 5a5d62>  689f6b 798e9b 8379da 92a478 827c79
# 689f6b>  798e9b 8379da 92a478 827c79
# 798e9b>  8379da 92a478 827c79
# 8379da>  92a478 827c79
# 92a478>  827c79
#
# htmlFile ./rahul2/pdfimages/image.9.6.216_314.179_286/images.html
# T: 183717/W: 183677/NW: 40
# *****OK...rahul2//image.9.7.314_412.179_286
# rahul2//image.9.7.314_412.179_286
# transforming: image.9.7.314_412.179_286/raw.png
# Freq: f6f6f7: 176343
# Freq: 6462b5: 2779
# Freq: ae76af: 135
# Freq: 689b6b: 265
# Freq: bd5a60: 1072
# Freq: 58595f: 2852
# Freq: 7c8598: 224
# neighbours: f6f6f7>  58595f 6462b5 bd5a60 689b6b 7c8598 ae76af ad957c
# 58595f>  6462b5 bd5a60 689b6b 7c8598 ae76af ad957c
# 6462b5>  bd5a60 689b6b 7c8598 ae76af ad957c
# bd5a60>  689b6b 7c8598 ae76af ad957c
# 689b6b>  7c8598 ae76af ad957c
# 7c8598>  ae76af ad957c
# ae76af>  ad957c
#
# htmlFile ./rahul2/pdfimages/image.9.7.314_412.179_286/images.html
# T: 122478/W: 122468/NW: 10
# *****OK...rahul2//image.9.8.412_478.250_358
# rahul2//image.9.8.412_478.250_358
# transforming: image.9.8.412_478.250_358/raw.png
# Freq: fbfbfb: 120517
# Freq: 626265: 867
# Freq: 6564bb: 989
# neighbours: fbfbfb>  6564bb 626265 7993a8 807edd a8ba76 807ea9 7f847e
# 6564bb>  626265 7993a8 807edd a8ba76 807ea9 7f847e
# 626265>  7993a8 807edd a8ba76 807ea9 7f847e
# 7993a8>  807edd a8ba76 807ea9 7f847e
# 807edd>  a8ba76 807ea9 7f847e
# a8ba76>  807ea9 7f847e
# 807ea9>  7f847e
#
# htmlFile ./rahul2/pdfimages/image.9.8.412_478.250_358/images.html
# T: 203832/W: 203821/NW: 11
# *****OK...rahul2//image.9.9.117_282.286_358
# rahul2//image.9.9.117_282.286_358
# transforming: image.9.9.117_282.286_358/raw.png
# Freq: fbfbfc: 201247
# Freq: 6462b6: 1157
# Freq: 606164: 1304
# neighbours: fbfbfc>  606164 6462b6 847ae5 b5a771 7d81b6 7d807d
# 606164>  6462b6 847ae5 b5a771 7d81b6 7d807d
# 6462b6>  847ae5 b5a771 7d81b6 7d807d
# 847ae5>  b5a771 7d81b6 7d807d
# b5a771>  7d81b6 7d807d
# 7d81b6>  7d807d
#
# htmlFile ./rahul2/pdfimages/image.9.9.117_282.286_358/images.html
# AMIImageTool cTree: target
# AMIImageTool processTree
# no pdfimages/ dir and no image/ dir

# %%
! tree .
# Out:
# .
# ├── figures.txt
# ├── heitjans2012
# │   ├── fulltext.pdf
# │   ├── pdfimages
# │   │   ├── image.3.1.67_294.51_207
# │   │   │   ├── images.html
# │   │   │   ├── octree
# │   │   │   │   ├── binary.png
# │   │   │   │   ├── channel.002c90.png
# │   │   │   │   ├── channel.1f53a4.png
# │   │   │   │   ├── channel.2b3131.png
# │   │   │   │   ├── channel.4b75b6.png
# │   │   │   │   ├── channel.7a8287.png
# │   │   │   │   ├── channel.ec262c.png
# │   │   │   │   ├── channel.fdfdfd.png
# │   │   │   │   ├── histogram.svg
# │   │   │   │   └── octree.png
# │   │   │   ├── octree16
# │   │   │   │   ├── channel.002c90.png
# │   │   │   │   ├── channel.0f1616.png
# │   │   │   │   ├── channel.1f53a4.png
# │   │   │   │   ├── channel.3b4343.png
# │   │   │   │   ├── channel.4b75b6.png
# │   │   │   │   ├── channel.5c6262.png
# │   │   │   │   ├── channel.7393c6.png
# │   │   │   │   ├── channel.7b8182.png
# │   │   │   │   ├── channel.eb1118.png
# │   │   │   │   ├── channel.f05a61.png
# │   │   │   │   ├── channel.fdfdfd.png
# │   │   │   │   └── octree.png
# │   │   │   ├── raw
# │   │   │   │   └── raw.svg
# │   │   │   ├── raw.png
# │   │   │   ├── raw_o16.png
# │   │   │   ├── raw_o8.png
# │   │   │   └── testx
# │   │   │       ├── channel.002c90.png
# │   │   │       ├── channel.1f53a4.png
# │   │   │       ├── channel.2b3131.png
# │   │   │       ├── channel.4b75b6.png
# │   │   │       ├── channel.7a8287.png
# │   │   │       ├── channel.ec262c.png
# │   │   │       ├── channel.fdfdfd.png
# │   │   │       └── octree.png
# │   │   ├── image.3.2.110_515.425_709
# │   │   │   ├── images.html
# │   │   │   ├── octree
# │   │   │   │   ├── binary.png
# │   │   │   │   ├── channel.079c39.png
# │   │   │   │   ├── channel.080c09.png
# │   │   │   │   ├── channel.164ac2.png
# │   │   │   │   ├── channel.52acaf.png
# │   │   │   │   ├── channel.e21f22.png
# │   │   │   │   ├── channel.f17d82.png
# │   │   │   │   ├── channel.fafcfc.png
# │   │   │   │   ├── histogram.svg
# │   │   │   │   └── octree.png
# │   │   │   ├── octree16
# │   │   │   │   ├── channel.002fd7.png
# │   │   │   │   ├── channel.005edf.png
# │   │   │   │   ├── channel.008f1a.png
# │   │   │   │   ├── channel.080c09.png
# │   │   │   │   ├── channel.10ac5e.png
# │   │   │   │   ├── channel.52719d.png
# │   │   │   │   ├── channel.52acaf.png
# │   │   │   │   ├── channel.e21f22.png
# │   │   │   │   ├── channel.f17d82.png
# │   │   │   │   ├── channel.fafcfc.png
# │   │   │   │   └── octree.png
# │   │   │   ├── raw
# │   │   │   ├── raw.orig.png
# │   │   │   ├── raw.png
# │   │   │   ├── raw_o16.png
# │   │   │   ├── raw_o8.png
# │   │   │   └── testx
# │   │   │       ├── channel.0ca54e.png
# │   │   │       ├── channel.252525.png
# │   │   │       ├── channel.343e96.png
# │   │   │       ├── channel.4fb8b2.png
# │   │   │       ├── channel.ea2f36.png
# │   │   │       ├── channel.fcfcfc.png
# │   │   │       └── octree.png
# │   │   ├── image.4.1.135_490.51_391
# │   │   │   ├── images.html
# │   │   │   ├── octree
# │   │   │   │   ├── binary.png
# │   │   │   │   ├── channel.09a54f.png
# │   │   │   │   ├── channel.1559a6.png
# │   │   │   │   ├── channel.2d3636.png
# │   │   │   │   ├── channel.719c90.png
# │   │   │   │   ├── channel.ee3e45.png
# │   │   │   │   ├── channel.fbfcfc.png
# │   │   │   │   ├── histogram.svg
# │   │   │   │   └── octree.png
# │   │   │   ├── octree16
# │   │   │   │   ├── channel.003c9a.png
# │   │   │   │   ├── channel.009a3a.png
# │   │   │   │   ├── channel.09a651.png
# │   │   │   │   ├── channel.145ba8.png
# │   │   │   │   ├── channel.2d3636.png
# │   │   │   │   ├── channel.66c996.png
# │   │   │   │   ├── channel.6d9cc9.png
# │   │   │   │   ├── channel.778684.png
# │   │   │   │   ├── channel.ee3e45.png
# │   │   │   │   ├── channel.fbfcfc.png
# │   │   │   │   └── octree.png
# │   │   │   ├── raw.png
# │   │   │   ├── raw_o16.png
# │   │   │   ├── raw_o8.png
# │   │   │   └── testx
# │   │   │       ├── channel.09a54f.png
# │   │   │       ├── channel.1559a6.png
# │   │   │       ├── channel.2d3636.png
# │   │   │       ├── channel.719c90.png
# │   │   │       ├── channel.ee3e45.png
# │   │   │       ├── channel.fbfcfc.png
# │   │   │       └── octree.png
# │   │   ├── image.5.1.128_497.51_300
# │   │   │   ├── images.html
# │   │   │   ├── octree
# │   │   │   │   ├── binary.png
# │   │   │   │   ├── channel.09a44e.png
# │   │   │   │   ├── channel.201f1f.png
# │   │   │   │   ├── channel.38469c.png
# │   │   │   │   ├── channel.68b796.png
# │   │   │   │   ├── channel.ea242c.png
# │   │   │   │   ├── channel.fcfcfc.png
# │   │   │   │   ├── histogram.svg
# │   │   │   │   └── octree.png
# │   │   │   ├── octree16
# │   │   │   │   ├── channel.009a3a.png
# │   │   │   │   ├── channel.0aa651.png
# │   │   │   │   ├── channel.1e268c.png
# │   │   │   │   ├── channel.201f1f.png
# │   │   │   │   ├── channel.3451a2.png
# │   │   │   │   ├── channel.5563aa.png
# │   │   │   │   ├── channel.63c894.png
# │   │   │   │   ├── channel.70948a.png
# │   │   │   │   ├── channel.ea242c.png
# │   │   │   │   ├── channel.fcfcfc.png
# │   │   │   │   └── octree.png
# │   │   │   ├── raw.png
# │   │   │   ├── raw_o16.png
# │   │   │   ├── raw_o8.png
# │   │   │   └── testx
# │   │   │       ├── channel.09a44e.png
# │   │   │       ├── channel.201f1f.png
# │   │   │       ├── channel.38469c.png
# │   │   │       ├── channel.68b796.png
# │   │   │       ├── channel.ea242c.png
# │   │   │       ├── channel.fcfcfc.png
# │   │   │       └── octree.png
# │   │   ├── image.6.1.96_265.51_189
# │   │   │   ├── images.html
# │   │   │   ├── octree
# │   │   │   │   ├── binary.png
# │   │   │   │   ├── channel.08a349.png
# │   │   │   │   ├── channel.1a1a1a.png
# │   │   │   │   ├── channel.1f3e9a.png
# │   │   │   │   ├── channel.62c196.png
# │   │   │   │   ├── channel.eb1f2a.png
# │   │   │   │   ├── channel.fdfdfd.png
# │   │   │   │   ├── histogram.svg
# │   │   │   │   └── octree.png
# │   │   │   ├── octree16
# │   │   │   │   ├── channel.009836.png
# │   │   │   │   ├── channel.0ca955.png
# │   │   │   │   ├── channel.1a1a1a.png
# │   │   │   │   ├── channel.1f3e9a.png
# │   │   │   │   ├── channel.64c995.png
# │   │   │   │   ├── channel.eb1f2a.png
# │   │   │   │   ├── channel.fdfdfd.png
# │   │   │   │   └── octree.png
# │   │   │   ├── raw.png
# │   │   │   ├── raw_o16.png
# │   │   │   ├── raw_o8.png
# │   │   │   └── testx
# │   │   │       ├── channel.08a349.png
# │   │   │       ├── channel.1a1a1a.png
# │   │   │       ├── channel.1f3e9a.png
# │   │   │       ├── channel.62c196.png
# │   │   │       ├── channel.eb1f2a.png
# │   │   │       ├── channel.fdfdfd.png
# │   │   │       └── octree.png
# │   │   ├── image.6.2.104_521.498_689
# │   │   │   ├── images.html
# │   │   │   ├── octree
# │   │   │   │   ├── binary.png
# │   │   │   │   ├── channel.0e55a5.png
# │   │   │   │   ├── channel.13a64e.png
# │   │   │   │   ├── channel.303636.png
# │   │   │   │   ├── channel.6f9e97.png
# │   │   │   │   ├── channel.ed353c.png
# │   │   │   │   ├── channel.fcfcfd.png
# │   │   │   │   ├── histogram.svg
# │   │   │   │   └── octree.png
# │   │   │   ├── octree16
# │   │   │   │   ├── channel.059934.png
# │   │   │   │   ├── channel.0d55a6.png
# │   │   │   │   ├── channel.11a956.png
# │   │   │   │   ├── channel.303636.png
# │   │   │   │   ├── channel.4cb868.png
# │   │   │   │   ├── channel.66c893.png
# │   │   │   │   ├── channel.6c9bc8.png
# │   │   │   │   ├── channel.768684.png
# │   │   │   │   ├── channel.ed353c.png
# │   │   │   │   ├── channel.fcfcfd.png
# │   │   │   │   └── octree.png
# │   │   │   ├── raw.png
# │   │   │   ├── raw_o16.png
# │   │   │   ├── raw_o8.png
# │   │   │   └── testx
# │   │   │       ├── channel.0e55a5.png
# │   │   │       ├── channel.13a64e.png
# │   │   │       ├── channel.303636.png
# │   │   │       ├── channel.6f9e97.png
# │   │   │       ├── channel.ed353c.png
# │   │   │       ├── channel.fcfcfd.png
# │   │   │       └── octree.png
# │   │   ├── image.7.1.90_535.51_246
# │   │   │   ├── images.html
# │   │   │   ├── octree
# │   │   │   │   ├── binary.png
# │   │   │   │   ├── channel.0ea64c.png
# │   │   │   │   ├── channel.222121.png
# │   │   │   │   ├── channel.33acd2.png
# │   │   │   │   ├── channel.e93339.png
# │   │   │   │   ├── channel.fcfcfd.png
# │   │   │   │   ├── histogram.svg
# │   │   │   │   └── octree.png
# │   │   │   ├── octree16
# │   │   │   │   ├── channel.009d34.png
# │   │   │   │   ├── channel.0a9adf.png
# │   │   │   │   ├── channel.12a956.png
# │   │   │   │   ├── channel.222121.png
# │   │   │   │   ├── channel.50bae7.png
# │   │   │   │   ├── channel.65c5eb.png
# │   │   │   │   ├── channel.65c995.png
# │   │   │   │   ├── channel.e93339.png
# │   │   │   │   ├── channel.fcfcfd.png
# │   │   │   │   └── octree.png
# │   │   │   ├── raw.png
# │   │   │   ├── raw_o16.png
# │   │   │   ├── raw_o8.png
# │   │   │   └── testx
# │   │   │       ├── channel.0ea64c.png
# │   │   │       ├── channel.222121.png
# │   │   │       ├── channel.33acd2.png
# │   │   │       ├── channel.e93339.png
# │   │   │       ├── channel.fcfcfd.png
# │   │   │       └── octree.png
# │   │   ├── image.8.1.127_498.51_224
# │   │   │   ├── images.html
# │   │   │   ├── octree
# │   │   │   │   ├── binary.png
# │   │   │   │   ├── channel.2b3131.png
# │   │   │   │   ├── channel.7c8282.png
# │   │   │   │   ├── channel.e9313c.png
# │   │   │   │   ├── channel.fefdfd.png
# │   │   │   │   ├── histogram.svg
# │   │   │   │   └── octree.png
# │   │   │   ├── octree16
# │   │   │   │   ├── channel.151c1c.png
# │   │   │   │   ├── channel.3b4343.png
# │   │   │   │   ├── channel.5c6161.png
# │   │   │   │   ├── channel.7c8282.png
# │   │   │   │   ├── channel.ee1f2b.png
# │   │   │   │   ├── channel.f03843.png
# │   │   │   │   ├── channel.fefdfd.png
# │   │   │   │   └── octree.png
# │   │   │   ├── raw.png
# │   │   │   ├── raw_o16.png
# │   │   │   ├── raw_o8.png
# │   │   │   └── testx
# │   │   │       ├── channel.2b3131.png
# │   │   │       ├── channel.7c8282.png
# │   │   │       ├── channel.e9313c.png
# │   │   │       ├── channel.fefdfd.png
# │   │   │       └── octree.png
# │   │   └── image.8.2.348_541.510_689
# │   │       ├── images.html
# │   │       ├── octree
# │   │       │   ├── binary.png
# │   │       │   ├── channel.26459a.png
# │   │       │   ├── channel.363a3a.png
# │   │       │   ├── channel.7a848f.png
# │   │       │   ├── channel.e2222c.png
# │   │       │   ├── channel.fefefe.png
# │   │       │   ├── histogram.svg
# │   │       │   └── octree.png
# │   │       ├── octree16
# │   │       │   ├── channel.0e308f.png
# │   │       │   ├── channel.2d4c9f.png
# │   │       │   ├── channel.363a3a.png
# │   │       │   ├── channel.566fb1.png
# │   │       │   ├── channel.7a838a.png
# │   │       │   ├── channel.a12027.png
# │   │       │   ├── channel.ef212c.png
# │   │       │   ├── channel.fefefe.png
# │   │       │   └── octree.png
# │   │       ├── raw.png
# │   │       ├── raw_o16.png
# │   │       ├── raw_o8.png
# │   │       └── testx
# │   │           ├── channel.26459a.png
# │   │           ├── channel.363a3a.png
# │   │           ├── channel.7a848f.png
# │   │           ├── channel.e2222c.png
# │   │           ├── channel.fefefe.png
# │   │           └── octree.png
# │   └── svg
# │       ├── fulltext-page.0.svg
# │       ├── fulltext-page.1.svg
# │       ├── fulltext-page.10.svg
# │       ├── fulltext-page.2.svg
# │       ├── fulltext-page.3.svg
# │       ├── fulltext-page.4.svg
# │       ├── fulltext-page.5.svg
# │       ├── fulltext-page.6.svg
# │       ├── fulltext-page.7.svg
# │       ├── fulltext-page.8.svg
# │       └── fulltext-page.9.svg
# ├── janek2011
# │   ├── fulltext.pdf
# │   ├── pdfimages
# │   │   ├── image.11.1.57_284.78_298
# │   │   │   ├── images.html
# │   │   │   ├── octree
# │   │   │   │   ├── binary.png
# │   │   │   │   ├── channel.2c292a.png
# │   │   │   │   ├── channel.7c7e80.png
# │   │   │   │   ├── channel.7e8082.png
# │   │   │   │   ├── channel.de3639.png
# │   │   │   │   ├── channel.de8678.png
# │   │   │   │   ├── channel.fcfcfa.png
# │   │   │   │   ├── histogram.svg
# │   │   │   │   └── octree.png
# │   │   │   ├── octree16
# │   │   │   │   ├── channel.2c292a.png
# │   │   │   │   ├── channel.7c7e80.png
# │   │   │   │   ├── channel.7e8082.png
# │   │   │   │   ├── channel.de3639.png
# │   │   │   │   ├── channel.e98677.png
# │   │   │   │   ├── channel.fcfcfa.png
# │   │   │   │   └── octree.png
# │   │   │   ├── raw.png
# │   │   │   ├── raw_o16.png
# │   │   │   ├── raw_o8.png
# │   │   │   └── testx
# │   │   │       ├── channel.2c292a.png
# │   │   │       ├── channel.7c7e80.png
# │   │   │       ├── channel.7e8082.png
# │   │   │       ├── channel.de3639.png
# │   │   │       ├── channel.de8678.png
# │   │   │       ├── channel.fcfcfa.png
# │   │   │       └── octree.png
# │   │   ├── image.11.2.312_538.78_260
# │   │   │   ├── images.html
# │   │   │   ├── octree
# │   │   │   │   ├── binary.png
# │   │   │   │   ├── channel.312e2f.png
# │   │   │   │   ├── channel.7d7e80.png
# │   │   │   │   ├── channel.7e8082.png
# │   │   │   │   ├── channel.e5383b.png
# │   │   │   │   ├── channel.eb8677.png
# │   │   │   │   ├── channel.fefdfc.png
# │   │   │   │   ├── histogram.svg
# │   │   │   │   └── octree.png
# │   │   │   ├── octree16
# │   │   │   │   ├── channel.312e2f.png
# │   │   │   │   ├── channel.7d7e80.png
# │   │   │   │   ├── channel.7e8082.png
# │   │   │   │   ├── channel.e53544.png
# │   │   │   │   ├── channel.e65f59.png
# │   │   │   │   ├── channel.e7282e.png
# │   │   │   │   ├── channel.eb8677.png
# │   │   │   │   ├── channel.fefdfc.png
# │   │   │   │   └── octree.png
# │   │   │   ├── raw.png
# │   │   │   ├── raw_o16.png
# │   │   │   ├── raw_o8.png
# │   │   │   └── testx
# │   │   │       ├── channel.312e2f.png
# │   │   │       ├── channel.7d7e80.png
# │   │   │       ├── channel.7e8082.png
# │   │   │       ├── channel.e5383b.png
# │   │   │       ├── channel.eb8677.png
# │   │   │       ├── channel.fefdfc.png
# │   │   │       └── octree.png
# │   │   ├── image.12.1.75_521.339_683
# │   │   │   ├── images.html
# │   │   │   ├── octree
# │   │   │   │   ├── binary.png
# │   │   │   │   ├── channel.3b393b.png
# │   │   │   │   ├── channel.4d5d97.png
# │   │   │   │   ├── channel.7e8084.png
# │   │   │   │   ├── channel.d84940.png
# │   │   │   │   ├── channel.df8c6a.png
# │   │   │   │   ├── channel.fdfdfb.png
# │   │   │   │   ├── histogram.svg
# │   │   │   │   └── octree.png
# │   │   │   ├── octree16
# │   │   │   │   ├── channel.3b393b.png
# │   │   │   │   ├── channel.4d5d97.png
# │   │   │   │   ├── channel.7e8084.png
# │   │   │   │   ├── channel.df8c6a.png
# │   │   │   │   ├── channel.e3262b.png
# │   │   │   │   ├── channel.e46853.png
# │   │   │   │   ├── channel.e85731.png
# │   │   │   │   ├── channel.fdfdfb.png
# │   │   │   │   └── octree.png
# │   │   │   ├── raw.png
# │   │   │   ├── raw_o16.png
# │   │   │   ├── raw_o8.png
# │   │   │   └── testx
# │   │   │       ├── channel.3b393b.png
# │   │   │       ├── channel.4d5d97.png
# │   │   │       ├── channel.7e8084.png
# │   │   │       ├── channel.d84940.png
# │   │   │       ├── channel.df8c6a.png
# │   │   │       ├── channel.fdfdfb.png
# │   │   │       └── octree.png
# │   │   ├── image.4.2.312_539.506_683
# │   │   │   ├── images.html
# │   │   │   ├── octree
# │   │   │   │   ├── binary.png
# │   │   │   │   ├── channel.000000.png
# │   │   │   │   ├── channel.ffffff.png
# │   │   │   │   ├── histogram.svg
# │   │   │   │   └── octree.png
# │   │   │   ├── octree16
# │   │   │   │   ├── channel.000000.png
# │   │   │   │   ├── channel.ffffff.png
# │   │   │   │   └── octree.png
# │   │   │   ├── raw.png
# │   │   │   ├── raw_o16.png
# │   │   │   ├── raw_o8.png
# │   │   │   └── testx
# │   │   │       ├── channel.000000.png
# │   │   │       ├── channel.ffffff.png
# │   │   │       └── octree.png
# │   │   ├── image.5.1.91_250.78_255
# │   │   │   ├── images.html
# │   │   │   ├── octree
# │   │   │   │   ├── binary.png
# │   │   │   │   ├── channel.000000.png
# │   │   │   │   ├── channel.ffffff.png
# │   │   │   │   ├── histogram.svg
# │   │   │   │   └── octree.png
# │   │   │   ├── octree16
# │   │   │   │   ├── channel.000000.png
# │   │   │   │   ├── channel.ffffff.png
# │   │   │   │   └── octree.png
# │   │   │   ├── raw.png
# │   │   │   ├── raw_o16.png
# │   │   │   ├── raw_o8.png
# │   │   │   └── testx
# │   │   │       ├── channel.000000.png
# │   │   │       ├── channel.ffffff.png
# │   │   │       └── octree.png
# │   │   ├── image.5.2.364_487.78_207
# │   │   │   ├── images.html
# │   │   │   ├── octree
# │   │   │   │   ├── binary.png
# │   │   │   │   ├── channel.000000.png
# │   │   │   │   ├── channel.ffffff.png
# │   │   │   │   ├── histogram.svg
# │   │   │   │   └── octree.png
# │   │   │   ├── octree16
# │   │   │   │   ├── channel.000000.png
# │   │   │   │   ├── channel.ffffff.png
# │   │   │   │   └── octree.png
# │   │   │   ├── raw.png
# │   │   │   ├── raw_o16.png
# │   │   │   ├── raw_o8.png
# │   │   │   └── testx
# │   │   │       ├── channel.000000.png
# │   │   │       ├── channel.ffffff.png
# │   │   │       └── octree.png
# │   │   └── image.7.1.58_538.409_623
# │   │       ├── images.html
# │   │       ├── octree
# │   │       │   ├── binary.png
# │   │       │   ├── channel.050505.png
# │   │       │   ├── channel.303030.png
# │   │       │   ├── channel.4e4e4e.png
# │   │       │   ├── channel.6f6f6f.png
# │   │       │   ├── channel.909090.png
# │   │       │   ├── channel.b0b0b0.png
# │   │       │   ├── channel.d0d0d0.png
# │   │       │   ├── channel.fefefe.png
# │   │       │   ├── histogram.svg
# │   │       │   └── octree.png
# │   │       ├── octree16
# │   │       │   ├── channel.020202.png
# │   │       │   ├── channel.161616.png
# │   │       │   ├── channel.272727.png
# │   │       │   ├── channel.373737.png
# │   │       │   ├── channel.464646.png
# │   │       │   ├── channel.575757.png
# │   │       │   ├── channel.686868.png
# │   │       │   ├── channel.777777.png
# │   │       │   ├── channel.878787.png
# │   │       │   ├── channel.979797.png
# │   │       │   ├── channel.a7a7a7.png
# │   │       │   ├── channel.b7b7b7.png
# │   │       │   ├── channel.c7c7c7.png
# │   │       │   ├── channel.d8d8d8.png
# │   │       │   ├── channel.e8e8e8.png
# │   │       │   ├── channel.fefefe.png
# │   │       │   └── octree.png
# │   │       ├── raw.png
# │   │       ├── raw_o16.png
# │   │       ├── raw_o8.png
# │   │       └── testx
# │   │           ├── channel.050505.png
# │   │           ├── channel.303030.png
# │   │           ├── channel.4e4e4e.png
# │   │           ├── channel.6f6f6f.png
# │   │           ├── channel.909090.png
# │   │           ├── channel.b0b0b0.png
# │   │           ├── channel.d0d0d0.png
# │   │           ├── channel.fefefe.png
# │   │           └── octree.png
# │   └── svg
# │       ├── fulltext-page.0.svg
# │       ├── fulltext-page.1.svg
# │       ├── fulltext-page.10.svg
# │       ├── fulltext-page.11.svg
# │       ├── fulltext-page.12.svg
# │       ├── fulltext-page.13.svg
# │       ├── fulltext-page.14.svg
# │       ├── fulltext-page.2.svg
# │       ├── fulltext-page.3.svg
# │       ├── fulltext-page.4.svg
# │       ├── fulltext-page.5.svg
# │       ├── fulltext-page.6.svg
# │       ├── fulltext-page.7.svg
# │       ├── fulltext-page.8.svg
# │       └── fulltext-page.9.svg
# ├── kilner2014
# │   ├── fulltext.pdf
# │   ├── pdfimages
# │   │   ├── image.3.1.326_562.128_273
# │   │   │   ├── images.html
# │   │   │   ├── octree
# │   │   │   │   ├── binary.png
# │   │   │   │   ├── channel.0070bf.png
# │   │   │   │   ├── channel.07b155.png
# │   │   │   │   ├── channel.0d0d0d.png
# │   │   │   │   ├── channel.439fc0.png
# │   │   │   │   ├── channel.fa0b0a.png
# │   │   │   │   ├── channel.fdfdfd.png
# │   │   │   │   ├── histogram.svg
# │   │   │   │   └── octree.png
# │   │   │   ├── octree16
# │   │   │   │   ├── channel.0070bf.png
# │   │   │   │   ├── channel.07b155.png
# │   │   │   │   ├── channel.0d0d0d.png
# │   │   │   │   ├── channel.439fc0.png
# │   │   │   │   ├── channel.835527.png
# │   │   │   │   ├── channel.ab160c.png
# │   │   │   │   ├── channel.fdfdfd.png
# │   │   │   │   ├── channel.fe0101.png
# │   │   │   │   ├── channel.fe4a4a.png
# │   │   │   │   └── octree.png
# │   │   │   ├── raw.png
# │   │   │   ├── raw_o16.png
# │   │   │   ├── raw_o8.png
# │   │   │   └── testx
# │   │   │       ├── channel.0070bf.png
# │   │   │       ├── channel.07b155.png
# │   │   │       ├── channel.0d0d0d.png
# │   │   │       ├── channel.439fc0.png
# │   │   │       ├── channel.fa0b0a.png
# │   │   │       ├── channel.fdfdfd.png
# │   │   │       └── octree.png
# │   │   ├── image.4.2.329_560.51_236
# │   │   │   ├── images.html
# │   │   │   ├── octree
# │   │   │   │   ├── binary.png
# │   │   │   │   ├── channel.0170c0.png
# │   │   │   │   ├── channel.07b254.png
# │   │   │   │   ├── channel.0c0b0b.png
# │   │   │   │   ├── channel.4e90be.png
# │   │   │   │   ├── channel.8064a2.png
# │   │   │   │   ├── channel.f70a0a.png
# │   │   │   │   ├── channel.fdfdfd.png
# │   │   │   │   ├── histogram.svg
# │   │   │   │   └── octree.png
# │   │   │   ├── octree16
# │   │   │   │   ├── channel.0070c0.png
# │   │   │   │   ├── channel.03b152.png
# │   │   │   │   ├── channel.0c0b0b.png
# │   │   │   │   ├── channel.40c47c.png
# │   │   │   │   ├── channel.4e90be.png
# │   │   │   │   ├── channel.8064a2.png
# │   │   │   │   ├── channel.9b0100.png
# │   │   │   │   ├── channel.fdfdfd.png
# │   │   │   │   ├── channel.fe0202.png
# │   │   │   │   ├── channel.fe5353.png
# │   │   │   │   └── octree.png
# │   │   │   ├── raw.png
# │   │   │   ├── raw_o16.png
# │   │   │   ├── raw_o8.png
# │   │   │   └── testx
# │   │   │       ├── channel.0170c0.png
# │   │   │       ├── channel.07b254.png
# │   │   │       ├── channel.0c0b0b.png
# │   │   │       ├── channel.4e90be.png
# │   │   │       ├── channel.8064a2.png
# │   │   │       ├── channel.f70a0a.png
# │   │   │       ├── channel.fdfdfd.png
# │   │   │       └── octree.png
# │   │   ├── image.5.1.95_266.51_154
# │   │   │   ├── images.html
# │   │   │   ├── octree
# │   │   │   │   ├── binary.png
# │   │   │   │   ├── channel.09b052.png
# │   │   │   │   ├── channel.1f2125.png
# │   │   │   │   ├── channel.48bcaf.png
# │   │   │   │   ├── channel.563ea4.png
# │   │   │   │   ├── channel.ed1818.png
# │   │   │   │   ├── channel.fcfcfc.png
# │   │   │   │   ├── histogram.svg
# │   │   │   │   └── octree.png
# │   │   │   ├── octree16
# │   │   │   │   ├── channel.0171c1.png
# │   │   │   │   ├── channel.0962ae.png
# │   │   │   │   ├── channel.09b052.png
# │   │   │   │   ├── channel.1f2125.png
# │   │   │   │   ├── channel.48bcaf.png
# │   │   │   │   ├── channel.6f2f9f.png
# │   │   │   │   ├── channel.ed1818.png
# │   │   │   │   ├── channel.fcfcfc.png
# │   │   │   │   └── octree.png
# │   │   │   ├── raw.png
# │   │   │   ├── raw_o16.png
# │   │   │   ├── raw_o8.png
# │   │   │   └── testx
# │   │   │       ├── channel.09b052.png
# │   │   │       ├── channel.1f2125.png
# │   │   │       ├── channel.48bcaf.png
# │   │   │       ├── channel.563ea4.png
# │   │   │       ├── channel.ed1818.png
# │   │   │       ├── channel.fcfcfc.png
# │   │   │       └── octree.png
# │   │   ├── image.5.2.85_276.512_689
# │   │   │   ├── images.html
# │   │   │   ├── octree
# │   │   │   │   ├── binary.png
# │   │   │   │   ├── channel.141414.png
# │   │   │   │   ├── channel.616161.png
# │   │   │   │   ├── channel.a1a1a1.png
# │   │   │   │   ├── channel.fefefe.png
# │   │   │   │   ├── channel.ff0505.png
# │   │   │   │   ├── channel.ff2f2f.png
# │   │   │   │   ├── channel.ff5e5e.png
# │   │   │   │   ├── channel.ffa2a2.png
# │   │   │   │   ├── histogram.svg
# │   │   │   │   └── octree.png
# │   │   │   ├── octree16
# │   │   │   │   ├── channel.090909.png
# │   │   │   │   ├── channel.2f2f2f.png
# │   │   │   │   ├── channel.4f4f4f.png
# │   │   │   │   ├── channel.707070.png
# │   │   │   │   ├── channel.8f8f8f.png
# │   │   │   │   ├── channel.b0b0b0.png
# │   │   │   │   ├── channel.d0d0d0.png
# │   │   │   │   ├── channel.fefefe.png
# │   │   │   │   ├── channel.ff0505.png
# │   │   │   │   ├── channel.ff2f2f.png
# │   │   │   │   ├── channel.ff4c4c.png
# │   │   │   │   ├── channel.ff6e6e.png
# │   │   │   │   ├── channel.ff8f8f.png
# │   │   │   │   ├── channel.ffa6a6.png
# │   │   │   │   ├── channel.ffb8b8.png
# │   │   │   │   ├── channel.ffd0d0.png
# │   │   │   │   └── octree.png
# │   │   │   ├── raw.png
# │   │   │   ├── raw_o16.png
# │   │   │   ├── raw_o8.png
# │   │   │   └── testx
# │   │   │       ├── channel.141414.png
# │   │   │       ├── channel.616161.png
# │   │   │       ├── channel.a1a1a1.png
# │   │   │       ├── channel.fefefe.png
# │   │   │       ├── channel.ff0505.png
# │   │   │       ├── channel.ff2f2f.png
# │   │   │       ├── channel.ff5e5e.png
# │   │   │       ├── channel.ffa2a2.png
# │   │   │       └── octree.png
# │   │   └── image.6.1.88_273.51_495
# │   │       ├── images.html
# │   │       ├── octree
# │   │       │   ├── binary.png
# │   │       │   ├── channel.000000.png
# │   │       │   ├── channel.3d3d3d.png
# │   │       │   ├── histogram.svg
# │   │       │   └── octree.png
# │   │       ├── octree16
# │   │       │   ├── channel.000000.png
# │   │       │   ├── channel.3d3d3d.png
# │   │       │   └── octree.png
# │   │       ├── raw.png
# │   │       ├── raw_o16.png
# │   │       ├── raw_o8.png
# │   │       └── testx
# │   │           ├── channel.000000.png
# │   │           ├── channel.3d3d3d.png
# │   │           └── octree.png
# │   └── svg
# │       ├── fulltext-page.0.svg
# │       ├── fulltext-page.1.svg
# │       ├── fulltext-page.2.svg
# │       ├── fulltext-page.3.svg
# │       ├── fulltext-page.4.svg
# │       ├── fulltext-page.5.svg
# │       ├── fulltext-page.6.svg
# │       └── fulltext-page.7.svg
# ├── larraz2015
# │   ├── fulltext.pdf
# │   ├── pdfimages
# │   │   ├── image.3.1.310_546.71_250
# │   │   │   ├── images.html
# │   │   │   ├── octree
# │   │   │   │   ├── binary.png
# │   │   │   │   ├── channel.090909.png
# │   │   │   │   ├── channel.303030.png
# │   │   │   │   ├── channel.505050.png
# │   │   │   │   ├── channel.6f6f6f.png
# │   │   │   │   ├── channel.8f8f8f.png
# │   │   │   │   ├── channel.b0b0b0.png
# │   │   │   │   ├── channel.d1d1d1.png
# │   │   │   │   ├── channel.fefefe.png
# │   │   │   │   ├── histogram.svg
# │   │   │   │   └── octree.png
# │   │   │   ├── octree16
# │   │   │   │   ├── channel.020202.png
# │   │   │   │   ├── channel.181818.png
# │   │   │   │   ├── channel.272727.png
# │   │   │   │   ├── channel.373737.png
# │   │   │   │   ├── channel.474747.png
# │   │   │   │   ├── channel.575757.png
# │   │   │   │   ├── channel.676767.png
# │   │   │   │   ├── channel.777777.png
# │   │   │   │   ├── channel.878787.png
# │   │   │   │   ├── channel.979797.png
# │   │   │   │   ├── channel.a7a7a7.png
# │   │   │   │   ├── channel.b7b7b7.png
# │   │   │   │   ├── channel.c7c7c7.png
# │   │   │   │   ├── channel.d8d8d8.png
# │   │   │   │   ├── channel.e8e8e8.png
# │   │   │   │   ├── channel.fefefe.png
# │   │   │   │   └── octree.png
# │   │   │   ├── raw.png
# │   │   │   ├── raw_o16.png
# │   │   │   ├── raw_o8.png
# │   │   │   └── testx
# │   │   │       ├── channel.090909.png
# │   │   │       ├── channel.303030.png
# │   │   │       ├── channel.505050.png
# │   │   │       ├── channel.6f6f6f.png
# │   │   │       ├── channel.8f8f8f.png
# │   │   │       ├── channel.b0b0b0.png
# │   │   │       ├── channel.d1d1d1.png
# │   │   │       ├── channel.fefefe.png
# │   │   │       └── octree.png
# │   │   ├── image.3.2.310_546.478_681
# │   │   │   ├── images.html
# │   │   │   ├── octree
# │   │   │   │   ├── binary.png
# │   │   │   │   ├── channel.080808.png
# │   │   │   │   ├── channel.2f2f2f.png
# │   │   │   │   ├── channel.4f4f4f.png
# │   │   │   │   ├── channel.707070.png
# │   │   │   │   ├── channel.8e8e8e.png
# │   │   │   │   ├── channel.adadad.png
# │   │   │   │   ├── channel.d1d1d1.png
# │   │   │   │   ├── channel.fefefe.png
# │   │   │   │   ├── histogram.svg
# │   │   │   │   └── octree.png
# │   │   │   ├── octree16
# │   │   │   │   ├── channel.030303.png
# │   │   │   │   ├── channel.161616.png
# │   │   │   │   ├── channel.282828.png
# │   │   │   │   ├── channel.363636.png
# │   │   │   │   ├── channel.474747.png
# │   │   │   │   ├── channel.575757.png
# │   │   │   │   ├── channel.686868.png
# │   │   │   │   ├── channel.777777.png
# │   │   │   │   ├── channel.868686.png
# │   │   │   │   ├── channel.989898.png
# │   │   │   │   ├── channel.a6a6a6.png
# │   │   │   │   ├── channel.b7b7b7.png
# │   │   │   │   ├── channel.c7c7c7.png
# │   │   │   │   ├── channel.d8d8d8.png
# │   │   │   │   ├── channel.e7e7e7.png
# │   │   │   │   ├── channel.fefefe.png
# │   │   │   │   └── octree.png
# │   │   │   ├── raw.png
# │   │   │   ├── raw_o16.png
# │   │   │   ├── raw_o8.png
# │   │   │   └── testx
# │   │   │       ├── channel.080808.png
# │   │   │       ├── channel.2f2f2f.png
# │   │   │       ├── channel.4f4f4f.png
# │   │   │       ├── channel.707070.png
# │   │   │       ├── channel.8e8e8e.png
# │   │   │       ├── channel.adadad.png
# │   │   │       ├── channel.d1d1d1.png
# │   │   │       ├── channel.fefefe.png
# │   │   │       └── octree.png
# │   │   ├── image.4.1.310_546.71_269
# │   │   │   ├── images.html
# │   │   │   ├── octree
# │   │   │   │   ├── binary.png
# │   │   │   │   ├── channel.050505.png
# │   │   │   │   ├── channel.2d2d2d.png
# │   │   │   │   ├── channel.4e4e4e.png
# │   │   │   │   ├── channel.717171.png
# │   │   │   │   ├── channel.8e8e8e.png
# │   │   │   │   ├── channel.aeaeae.png
# │   │   │   │   ├── channel.cecece.png
# │   │   │   │   ├── channel.fefefe.png
# │   │   │   │   ├── histogram.svg
# │   │   │   │   └── octree.png
# │   │   │   ├── octree16
# │   │   │   │   ├── channel.020202.png
# │   │   │   │   ├── channel.171717.png
# │   │   │   │   ├── channel.272727.png
# │   │   │   │   ├── channel.363636.png
# │   │   │   │   ├── channel.4a4a4a.png
# │   │   │   │   ├── channel.575757.png
# │   │   │   │   ├── channel.676767.png
# │   │   │   │   ├── channel.777777.png
# │   │   │   │   ├── channel.868686.png
# │   │   │   │   ├── channel.969696.png
# │   │   │   │   ├── channel.a6a6a6.png
# │   │   │   │   ├── channel.b8b8b8.png
# │   │   │   │   ├── channel.c8c8c8.png
# │   │   │   │   ├── channel.d8d8d8.png
# │   │   │   │   ├── channel.e6e6e6.png
# │   │   │   │   ├── channel.fefefe.png
# │   │   │   │   └── octree.png
# │   │   │   ├── raw.png
# │   │   │   ├── raw_o16.png
# │   │   │   ├── raw_o8.png
# │   │   │   └── testx
# │   │   │       ├── channel.050505.png
# │   │   │       ├── channel.2d2d2d.png
# │   │   │       ├── channel.4e4e4e.png
# │   │   │       ├── channel.717171.png
# │   │   │       ├── channel.8e8e8e.png
# │   │   │       ├── channel.aeaeae.png
# │   │   │       ├── channel.cecece.png
# │   │   │       ├── channel.fefefe.png
# │   │   │       └── octree.png
# │   │   ├── image.5.1.49_285.71_269
# │   │   │   ├── images.html
# │   │   │   ├── octree
# │   │   │   │   ├── binary.png
# │   │   │   │   ├── channel.070707.png
# │   │   │   │   ├── channel.2d2d2d.png
# │   │   │   │   ├── channel.535353.png
# │   │   │   │   ├── channel.707070.png
# │   │   │   │   ├── channel.8f8f8f.png
# │   │   │   │   ├── channel.adadad.png
# │   │   │   │   ├── channel.d1d1d1.png
# │   │   │   │   ├── channel.fefefe.png
# │   │   │   │   ├── histogram.svg
# │   │   │   │   └── octree.png
# │   │   │   ├── octree16
# │   │   │   │   ├── channel.030303.png
# │   │   │   │   ├── channel.181818.png
# │   │   │   │   ├── channel.272727.png
# │   │   │   │   ├── channel.373737.png
# │   │   │   │   ├── channel.474747.png
# │   │   │   │   ├── channel.585858.png
# │   │   │   │   ├── channel.696969.png
# │   │   │   │   ├── channel.777777.png
# │   │   │   │   ├── channel.878787.png
# │   │   │   │   ├── channel.979797.png
# │   │   │   │   ├── channel.a6a6a6.png
# │   │   │   │   ├── channel.b7b7b7.png
# │   │   │   │   ├── channel.c8c8c8.png
# │   │   │   │   ├── channel.d7d7d7.png
# │   │   │   │   ├── channel.e8e8e8.png
# │   │   │   │   ├── channel.fefefe.png
# │   │   │   │   └── octree.png
# │   │   │   ├── raw.png
# │   │   │   ├── raw_o16.png
# │   │   │   ├── raw_o8.png
# │   │   │   └── testx
# │   │   │       ├── channel.070707.png
# │   │   │       ├── channel.2d2d2d.png
# │   │   │       ├── channel.535353.png
# │   │   │       ├── channel.707070.png
# │   │   │       ├── channel.8f8f8f.png
# │   │   │       ├── channel.adadad.png
# │   │   │       ├── channel.d1d1d1.png
# │   │   │       ├── channel.fefefe.png
# │   │   │       └── octree.png
# │   │   ├── image.6.1.49_285.542_721
# │   │   │   ├── images.html
# │   │   │   ├── octree
# │   │   │   │   ├── binary.png
# │   │   │   │   ├── channel.060606.png
# │   │   │   │   ├── channel.2c2c2c.png
# │   │   │   │   ├── channel.505050.png
# │   │   │   │   ├── channel.6e6e6e.png
# │   │   │   │   ├── channel.8f8f8f.png
# │   │   │   │   ├── channel.b3b3b3.png
# │   │   │   │   ├── channel.cdcdcd.png
# │   │   │   │   ├── channel.fefefe.png
# │   │   │   │   ├── histogram.svg
# │   │   │   │   └── octree.png
# │   │   │   ├── octree16
# │   │   │   │   ├── channel.010101.png
# │   │   │   │   ├── channel.151515.png
# │   │   │   │   ├── channel.262626.png
# │   │   │   │   ├── channel.373737.png
# │   │   │   │   ├── channel.464646.png
# │   │   │   │   ├── channel.535353.png
# │   │   │   │   ├── channel.676767.png
# │   │   │   │   ├── channel.777777.png
# │   │   │   │   ├── channel.878787.png
# │   │   │   │   ├── channel.979797.png
# │   │   │   │   ├── channel.a7a7a7.png
# │   │   │   │   ├── channel.b8b8b8.png
# │   │   │   │   ├── channel.c9c9c9.png
# │   │   │   │   ├── channel.d8d8d8.png
# │   │   │   │   ├── channel.e7e7e7.png
# │   │   │   │   ├── channel.fefefe.png
# │   │   │   │   └── octree.png
# │   │   │   ├── raw.png
# │   │   │   ├── raw_o16.png
# │   │   │   ├── raw_o8.png
# │   │   │   └── testx
# │   │   │       ├── channel.060606.png
# │   │   │       ├── channel.2c2c2c.png
# │   │   │       ├── channel.505050.png
# │   │   │       ├── channel.6e6e6e.png
# │   │   │       ├── channel.8f8f8f.png
# │   │   │       ├── channel.b3b3b3.png
# │   │   │       ├── channel.cdcdcd.png
# │   │   │       ├── channel.fefefe.png
# │   │   │       └── octree.png
# │   │   ├── image.6.2.310_546.511_711
# │   │   │   ├── images.html
# │   │   │   ├── octree
# │   │   │   │   ├── binary.png
# │   │   │   │   ├── channel.090909.png
# │   │   │   │   ├── channel.303030.png
# │   │   │   │   ├── channel.4d4d4d.png
# │   │   │   │   ├── channel.6f6f6f.png
# │   │   │   │   ├── channel.919191.png
# │   │   │   │   ├── channel.afafaf.png
# │   │   │   │   ├── channel.cecece.png
# │   │   │   │   ├── channel.fefefe.png
# │   │   │   │   ├── histogram.svg
# │   │   │   │   └── octree.png
# │   │   │   ├── octree16
# │   │   │   │   ├── channel.030303.png
# │   │   │   │   ├── channel.181818.png
# │   │   │   │   ├── channel.282828.png
# │   │   │   │   ├── channel.373737.png
# │   │   │   │   ├── channel.464646.png
# │   │   │   │   ├── channel.575757.png
# │   │   │   │   ├── channel.676767.png
# │   │   │   │   ├── channel.777777.png
# │   │   │   │   ├── channel.898989.png
# │   │   │   │   ├── channel.979797.png
# │   │   │   │   ├── channel.a6a6a6.png
# │   │   │   │   ├── channel.b9b9b9.png
# │   │   │   │   ├── channel.c7c7c7.png
# │   │   │   │   ├── channel.d7d7d7.png
# │   │   │   │   ├── channel.e8e8e8.png
# │   │   │   │   ├── channel.fefefe.png
# │   │   │   │   └── octree.png
# │   │   │   ├── raw.png
# │   │   │   ├── raw_o16.png
# │   │   │   ├── raw_o8.png
# │   │   │   └── testx
# │   │   │       ├── channel.090909.png
# │   │   │       ├── channel.303030.png
# │   │   │       ├── channel.4d4d4d.png
# │   │   │       ├── channel.6f6f6f.png
# │   │   │       ├── channel.919191.png
# │   │   │       ├── channel.afafaf.png
# │   │   │       ├── channel.cecece.png
# │   │   │       ├── channel.fefefe.png
# │   │   │       └── octree.png
# │   │   ├── image.7.1.49_285.308_507
# │   │   │   ├── images.html
# │   │   │   ├── octree
# │   │   │   │   ├── binary.png
# │   │   │   │   ├── channel.060606.png
# │   │   │   │   ├── channel.2c2c2c.png
# │   │   │   │   ├── channel.4e4e4e.png
# │   │   │   │   ├── channel.6b6b6b.png
# │   │   │   │   ├── channel.8d8d8d.png
# │   │   │   │   ├── channel.aeaeae.png
# │   │   │   │   ├── channel.cecece.png
# │   │   │   │   ├── channel.fefefe.png
# │   │   │   │   ├── histogram.svg
# │   │   │   │   └── octree.png
# │   │   │   ├── octree16
# │   │   │   │   ├── channel.020202.png
# │   │   │   │   ├── channel.171717.png
# │   │   │   │   ├── channel.262626.png
# │   │   │   │   ├── channel.373737.png
# │   │   │   │   ├── channel.4b4b4b.png
# │   │   │   │   ├── channel.575757.png
# │   │   │   │   ├── channel.686868.png
# │   │   │   │   ├── channel.757575.png
# │   │   │   │   ├── channel.888888.png
# │   │   │   │   ├── channel.979797.png
# │   │   │   │   ├── channel.a7a7a7.png
# │   │   │   │   ├── channel.b8b8b8.png
# │   │   │   │   ├── channel.c6c6c6.png
# │   │   │   │   ├── channel.d7d7d7.png
# │   │   │   │   ├── channel.e9e9e9.png
# │   │   │   │   ├── channel.fefefe.png
# │   │   │   │   └── octree.png
# │   │   │   ├── raw.png
# │   │   │   ├── raw_o16.png
# │   │   │   ├── raw_o8.png
# │   │   │   └── testx
# │   │   │       ├── channel.060606.png
# │   │   │       ├── channel.2c2c2c.png
# │   │   │       ├── channel.4e4e4e.png
# │   │   │       ├── channel.6b6b6b.png
# │   │   │       ├── channel.8d8d8d.png
# │   │   │       ├── channel.aeaeae.png
# │   │   │       ├── channel.cecece.png
# │   │   │       ├── channel.fefefe.png
# │   │   │       └── octree.png
# │   │   └── image.7.2.106_489.563_721
# │   │       ├── images.html
# │   │       ├── octree
# │   │       │   ├── binary.png
# │   │       │   ├── channel.060606.png
# │   │       │   ├── channel.2e2e2e.png
# │   │       │   ├── channel.4f4f4f.png
# │   │       │   ├── channel.6f6f6f.png
# │   │       │   ├── channel.8f8f8f.png
# │   │       │   ├── channel.b2b2b2.png
# │   │       │   ├── channel.cfcfcf.png
# │   │       │   ├── channel.fefefe.png
# │   │       │   ├── histogram.svg
# │   │       │   └── octree.png
# │   │       ├── octree16
# │   │       │   ├── channel.010101.png
# │   │       │   ├── channel.161616.png
# │   │       │   ├── channel.272727.png
# │   │       │   ├── channel.353535.png
# │   │       │   ├── channel.474747.png
# │   │       │   ├── channel.555555.png
# │   │       │   ├── channel.676767.png
# │   │       │   ├── channel.777777.png
# │   │       │   ├── channel.878787.png
# │   │       │   ├── channel.979797.png
# │   │       │   ├── channel.a8a8a8.png
# │   │       │   ├── channel.b7b7b7.png
# │   │       │   ├── channel.c5c5c5.png
# │   │       │   ├── channel.d9d9d9.png
# │   │       │   ├── channel.e5e5e5.png
# │   │       │   ├── channel.fefefe.png
# │   │       │   └── octree.png
# │   │       ├── raw.png
# │   │       ├── raw_o16.png
# │   │       ├── raw_o8.png
# │   │       └── testx
# │   │           ├── channel.060606.png
# │   │           ├── channel.2e2e2e.png
# │   │           ├── channel.4f4f4f.png
# │   │           ├── channel.6f6f6f.png
# │   │           ├── channel.8f8f8f.png
# │   │           ├── channel.b2b2b2.png
# │   │           ├── channel.cfcfcf.png
# │   │           ├── channel.fefefe.png
# │   │           └── octree.png
# │   └── svg
# │       ├── fulltext-page.0.svg
# │       ├── fulltext-page.1.svg
# │       ├── fulltext-page.2.svg
# │       ├── fulltext-page.3.svg
# │       ├── fulltext-page.4.svg
# │       ├── fulltext-page.5.svg
# │       ├── fulltext-page.6.svg
# │       ├── fulltext-page.7.svg
# │       └── fulltext-page.8.svg
# ├── logs
# │   └── ami.log
# ├── make_project.json
# ├── rettenwander2016
# │   ├── fulltext.pdf
# │   ├── pdfimages
# │   │   ├── image.4.2.52_288.91_286
# │   │   │   ├── images.html
# │   │   │   ├── octree
# │   │   │   │   ├── binary.png
# │   │   │   │   ├── channel.3e403c.png
# │   │   │   │   ├── channel.605e92.png
# │   │   │   │   ├── channel.628e61.png
# │   │   │   │   ├── channel.907399.png
# │   │   │   │   ├── channel.a29477.png
# │   │   │   │   ├── channel.b15955.png
# │   │   │   │   ├── channel.f9f9f8.png
# │   │   │   │   ├── histogram.svg
# │   │   │   │   └── octree.png
# │   │   │   ├── octree16
# │   │   │   │   ├── channel.3e403c.png
# │   │   │   │   ├── channel.615e93.png
# │   │   │   │   ├── channel.628e61.png
# │   │   │   │   ├── channel.8e7399.png
# │   │   │   │   ├── channel.a29477.png
# │   │   │   │   ├── channel.b15955.png
# │   │   │   │   ├── channel.f9f9f8.png
# │   │   │   │   └── octree.png
# │   │   │   ├── raw.png
# │   │   │   ├── raw_o16.png
# │   │   │   ├── raw_o8.png
# │   │   │   └── testx
# │   │   │       ├── channel.3e403c.png
# │   │   │       ├── channel.605e92.png
# │   │   │       ├── channel.628e61.png
# │   │   │       ├── channel.907399.png
# │   │   │       ├── channel.a29477.png
# │   │   │       ├── channel.b15955.png
# │   │   │       ├── channel.f9f9f8.png
# │   │   │       └── octree.png
# │   │   ├── image.6.1.308_543.481_656
# │   │   │   ├── images.html
# │   │   │   ├── octree
# │   │   │   │   ├── binary.png
# │   │   │   │   ├── channel.4a4856.png
# │   │   │   │   ├── channel.535693.png
# │   │   │   │   ├── channel.f3f3f3.png
# │   │   │   │   ├── histogram.svg
# │   │   │   │   └── octree.png
# │   │   │   ├── octree16
# │   │   │   │   ├── channel.282623.png
# │   │   │   │   ├── channel.3c4a8f.png
# │   │   │   │   ├── channel.3d457a.png
# │   │   │   │   ├── channel.545793.png
# │   │   │   │   ├── channel.5c5a6e.png
# │   │   │   │   ├── channel.f3f3f3.png
# │   │   │   │   └── octree.png
# │   │   │   ├── raw.png
# │   │   │   ├── raw_o16.png
# │   │   │   ├── raw_o8.png
# │   │   │   └── testx
# │   │   │       ├── channel.4a4856.png
# │   │   │       ├── channel.535693.png
# │   │   │       ├── channel.f3f3f3.png
# │   │   │       └── octree.png
# │   │   ├── image.6.2.308_543.91_414
# │   │   │   ├── images.html
# │   │   │   ├── octree
# │   │   │   │   ├── binary.png
# │   │   │   │   ├── channel.309d53.png
# │   │   │   │   ├── channel.47445b.png
# │   │   │   │   ├── channel.51468c.png
# │   │   │   │   ├── channel.63a98f.png
# │   │   │   │   ├── channel.8775a8.png
# │   │   │   │   ├── channel.c25645.png
# │   │   │   │   ├── channel.cd9c45.png
# │   │   │   │   ├── channel.fafaf9.png
# │   │   │   │   ├── histogram.svg
# │   │   │   │   └── octree.png
# │   │   │   ├── octree16
# │   │   │   │   ├── channel.119a52.png
# │   │   │   │   ├── channel.47445b.png
# │   │   │   │   ├── channel.51468c.png
# │   │   │   │   ├── channel.5ba25a.png
# │   │   │   │   ├── channel.659e3c.png
# │   │   │   │   ├── channel.6aab8d.png
# │   │   │   │   ├── channel.8775a8.png
# │   │   │   │   ├── channel.c25645.png
# │   │   │   │   ├── channel.cd9c45.png
# │   │   │   │   ├── channel.fafaf9.png
# │   │   │   │   └── octree.png
# │   │   │   ├── raw.png
# │   │   │   ├── raw_o16.png
# │   │   │   ├── raw_o8.png
# │   │   │   └── testx
# │   │   │       ├── channel.309d53.png
# │   │   │       ├── channel.47445b.png
# │   │   │       ├── channel.51468c.png
# │   │   │       ├── channel.63a98f.png
# │   │   │       ├── channel.8775a8.png
# │   │   │       ├── channel.c25645.png
# │   │   │       ├── channel.cd9c45.png
# │   │   │       ├── channel.fafaf9.png
# │   │   │       └── octree.png
# │   │   ├── image.7.1.303_547.252_737
# │   │   │   ├── images.html
# │   │   │   ├── octree
# │   │   │   │   ├── binary.png
# │   │   │   │   ├── channel.060606.png
# │   │   │   │   ├── channel.2e2e2e.png
# │   │   │   │   ├── channel.4f4f4f.png
# │   │   │   │   ├── channel.6f6f6f.png
# │   │   │   │   ├── channel.8f8f8f.png
# │   │   │   │   ├── channel.afafaf.png
# │   │   │   │   ├── channel.d0d0d0.png
# │   │   │   │   ├── channel.fefefe.png
# │   │   │   │   ├── histogram.svg
# │   │   │   │   └── octree.png
# │   │   │   ├── octree16
# │   │   │   │   ├── channel.030303.png
# │   │   │   │   ├── channel.161616.png
# │   │   │   │   ├── channel.262626.png
# │   │   │   │   ├── channel.373737.png
# │   │   │   │   ├── channel.474747.png
# │   │   │   │   ├── channel.575757.png
# │   │   │   │   ├── channel.676767.png
# │   │   │   │   ├── channel.777777.png
# │   │   │   │   ├── channel.878787.png
# │   │   │   │   ├── channel.979797.png
# │   │   │   │   ├── channel.a7a7a7.png
# │   │   │   │   ├── channel.b7b7b7.png
# │   │   │   │   ├── channel.c7c7c7.png
# │   │   │   │   ├── channel.d6d6d6.png
# │   │   │   │   ├── channel.e9e9e9.png
# │   │   │   │   ├── channel.fefefe.png
# │   │   │   │   └── octree.png
# │   │   │   ├── raw.png
# │   │   │   ├── raw_o16.png
# │   │   │   ├── raw_o8.png
# │   │   │   └── testx
# │   │   │       ├── channel.060606.png
# │   │   │       ├── channel.2e2e2e.png
# │   │   │       ├── channel.4f4f4f.png
# │   │   │       ├── channel.6f6f6f.png
# │   │   │       ├── channel.8f8f8f.png
# │   │   │       ├── channel.afafaf.png
# │   │   │       ├── channel.d0d0d0.png
# │   │   │       ├── channel.fefefe.png
# │   │   │       └── octree.png
# │   │   └── image.7.2.52_288.488_726
# │   │       ├── images.html
# │   │       ├── octree
# │   │       │   ├── binary.png
# │   │       │   ├── channel.50494a.png
# │   │       │   ├── channel.746589.png
# │   │       │   ├── channel.847b77.png
# │   │       │   ├── channel.877497.png
# │   │       │   ├── channel.fcfcfb.png
# │   │       │   ├── histogram.svg
# │   │       │   └── octree.png
# │   │       ├── octree16
# │   │       │   ├── channel.2e2b28.png
# │   │       │   ├── channel.423d39.png
# │   │       │   ├── channel.47413d.png
# │   │       │   ├── channel.5b5355.png
# │   │       │   ├── channel.746589.png
# │   │       │   ├── channel.847b77.png
# │   │       │   ├── channel.877497.png
# │   │       │   ├── channel.fcfcfb.png
# │   │       │   └── octree.png
# │   │       ├── raw.png
# │   │       ├── raw_o16.png
# │   │       ├── raw_o8.png
# │   │       └── testx
# │   │           ├── channel.50494a.png
# │   │           ├── channel.746589.png
# │   │           ├── channel.847b77.png
# │   │           ├── channel.877497.png
# │   │           ├── channel.fcfcfb.png
# │   │           └── octree.png
# │   └── svg
# │       ├── fulltext-page.0.svg
# │       ├── fulltext-page.1.svg
# │       ├── fulltext-page.10.svg
# │       ├── fulltext-page.2.svg
# │       ├── fulltext-page.3.svg
# │       ├── fulltext-page.4.svg
# │       ├── fulltext-page.5.svg
# │       ├── fulltext-page.6.svg
# │       ├── fulltext-page.7.svg
# │       ├── fulltext-page.8.svg
# │       └── fulltext-page.9.svg
# ├── steffen
# │   ├── figures.txt
# │   ├── heitjans2012
# │   │   ├── fulltext.pdf
# │   │   ├── pdfimages
# │   │   │   ├── image.3.1.67_294.51_207
# │   │   │   │   ├── images.html
# │   │   │   │   ├── octree16
# │   │   │   │   │   ├── channel.002c90.png
# │   │   │   │   │   ├── channel.0f1616.png
# │   │   │   │   │   ├── channel.1f53a4.png
# │   │   │   │   │   ├── channel.3b4343.png
# │   │   │   │   │   ├── channel.4b75b6.png
# │   │   │   │   │   ├── channel.5c6262.png
# │   │   │   │   │   ├── channel.7393c6.png
# │   │   │   │   │   ├── channel.7b8182.png
# │   │   │   │   │   ├── channel.eb1118.png
# │   │   │   │   │   ├── channel.f05a61.png
# │   │   │   │   │   ├── channel.fdfdfd.png
# │   │   │   │   │   └── octree.png
# │   │   │   │   ├── raw
# │   │   │   │   │   └── raw.svg
# │   │   │   │   ├── raw.png
# │   │   │   │   ├── raw_o16.png
# │   │   │   │   ├── raw_o8.png
# │   │   │   │   └── testx
# │   │   │   │       ├── channel.002c90.png
# │   │   │   │       ├── channel.1f53a4.png
# │   │   │   │       ├── channel.2b3131.png
# │   │   │   │       ├── channel.4b75b6.png
# │   │   │   │       ├── channel.7a8287.png
# │   │   │   │       ├── channel.ec262c.png
# │   │   │   │       ├── channel.fdfdfd.png
# │   │   │   │       └── octree.png
# │   │   │   ├── image.3.2.110_515.425_709
# │   │   │   │   ├── images.html
# │   │   │   │   ├── octree16
# │   │   │   │   │   ├── channel.002fd7.png
# │   │   │   │   │   ├── channel.005edf.png
# │   │   │   │   │   ├── channel.008f1a.png
# │   │   │   │   │   ├── channel.080c09.png
# │   │   │   │   │   ├── channel.10ac5e.png
# │   │   │   │   │   ├── channel.52719d.png
# │   │   │   │   │   ├── channel.52acaf.png
# │   │   │   │   │   ├── channel.e21f22.png
# │   │   │   │   │   ├── channel.f17d82.png
# │   │   │   │   │   ├── channel.fafcfc.png
# │   │   │   │   │   └── octree.png
# │   │   │   │   ├── raw
# │   │   │   │   ├── raw.orig.png
# │   │   │   │   ├── raw.png
# │   │   │   │   ├── raw_o16.png
# │   │   │   │   ├── raw_o8.png
# │   │   │   │   └── testx
# │   │   │   │       ├── channel.0ca54e.png
# │   │   │   │       ├── channel.252525.png
# │   │   │   │       ├── channel.343e96.png
# │   │   │   │       ├── channel.4fb8b2.png
# │   │   │   │       ├── channel.ea2f36.png
# │   │   │   │       ├── channel.fcfcfc.png
# │   │   │   │       └── octree.png
# │   │   │   ├── image.4.1.135_490.51_391
# │   │   │   │   ├── images.html
# │   │   │   │   ├── octree16
# │   │   │   │   │   ├── channel.003c9a.png
# │   │   │   │   │   ├── channel.009a3a.png
# │   │   │   │   │   ├── channel.09a651.png
# │   │   │   │   │   ├── channel.145ba8.png
# │   │   │   │   │   ├── channel.2d3636.png
# │   │   │   │   │   ├── channel.66c996.png
# │   │   │   │   │   ├── channel.6d9cc9.png
# │   │   │   │   │   ├── channel.778684.png
# │   │   │   │   │   ├── channel.ee3e45.png
# │   │   │   │   │   ├── channel.fbfcfc.png
# │   │   │   │   │   └── octree.png
# │   │   │   │   ├── raw.png
# │   │   │   │   ├── raw_o16.png
# │   │   │   │   ├── raw_o8.png
# │   │   │   │   └── testx
# │   │   │   │       ├── channel.09a54f.png
# │   │   │   │       ├── channel.1559a6.png
# │   │   │   │       ├── channel.2d3636.png
# │   │   │   │       ├── channel.719c90.png
# │   │   │   │       ├── channel.ee3e45.png
# │   │   │   │       ├── channel.fbfcfc.png
# │   │   │   │       └── octree.png
# │   │   │   ├── image.5.1.128_497.51_300
# │   │   │   │   ├── images.html
# │   │   │   │   ├── octree16
# │   │   │   │   │   ├── channel.009a3a.png
# │   │   │   │   │   ├── channel.0aa651.png
# ...
# │   │   │       │   ├── channel.f677f3.png
# │   │   │       │   ├── channel.f71011.png
# │   │   │       │   ├── channel.f85e5f.png
# │   │   │       │   ├── channel.fdfdfd.png
# │   │   │       │   └── octree.png
# │   │   │       ├── raw.png
# │   │   │       ├── raw_o16.png
# │   │   │       ├── raw_o8.png
# │   │   │       └── testx
# │   │   │           ├── channel.222e23.png
# │   │   │           ├── channel.2526f0.png
# │   │   │           ├── channel.369737.png
# │   │   │           ├── channel.f62627.png
# │   │   │           ├── channel.f677f3.png
# │   │   │           ├── channel.fdfdfd.png
# │   │   │           └── octree.png
# │   │   └── svg
# │   │       ├── fulltext-page.0.svg
# │   │       ├── fulltext-page.1.svg
# │   │       ├── fulltext-page.2.svg
# │   │       ├── fulltext-page.3.svg
# │   │       └── fulltext-page.4.svg
# │   └── weppner2011
# │       ├── fulltext.pdf
# │       ├── pdfimages
# │       │   ├── image.2.1.340_532.50_216
# │       │   │   ├── images.html
# │       │   │   ├── octree16
# │       │   │   │   ├── channel.000000.png
# │       │   │   │   ├── channel.ffffff.png
# │       │   │   │   └── octree.png
# │       │   │   ├── raw.png
# │       │   │   ├── raw_o16.png
# │       │   │   ├── raw_o8.png
# │       │   │   └── testx
# │       │   │       ├── channel.000000.png
# │       │   │       ├── channel.ffffff.png
# │       │   │       └── octree.png
# │       │   ├── image.6.1.134_473.50_170
# │       │   │   ├── images.html
# │       │   │   ├── octree16
# │       │   │   │   ├── channel.000000.png
# │       │   │   │   ├── channel.f8f8f8.png
# │       │   │   │   └── octree.png
# │       │   │   ├── raw.png
# │       │   │   ├── raw_o16.png
# │       │   │   ├── raw_o8.png
# │       │   │   └── testx
# │       │   │       ├── channel.000000.png
# │       │   │       ├── channel.f8f8f8.png
# │       │   │       └── octree.png
# │       │   ├── image.7.1.51_292.50_196
# │       │   │   ├── images.html
# │       │   │   ├── octree16
# │       │   │   │   ├── channel.000000.png
# │       │   │   │   ├── channel.f7f7f7.png
# │       │   │   │   └── octree.png
# │       │   │   ├── raw.png
# │       │   │   ├── raw_o16.png
# │       │   │   ├── raw_o8.png
# │       │   │   └── testx
# │       │   │       ├── channel.000000.png
# │       │   │       ├── channel.f7f7f7.png
# │       │   │       └── octree.png
# │       │   └── image.8.1.51_292.50_409
# │       │       ├── images.html
# │       │       ├── octree16
# │       │       │   ├── channel.000000.png
# │       │       │   ├── channel.454545.png
# │       │       │   └── octree.png
# │       │       ├── raw.png
# │       │       ├── raw_o16.png
# │       │       ├── raw_o8.png
# │       │       └── testx
# │       │           ├── channel.000000.png
# │       │           ├── channel.454545.png
# │       │           └── octree.png
# │       └── svg
# │           ├── fulltext-page.0.svg
# │           ├── fulltext-page.1.svg
# │           ├── fulltext-page.2.svg
# │           ├── fulltext-page.3.svg
# │           ├── fulltext-page.4.svg
# │           ├── fulltext-page.5.svg
# │           ├── fulltext-page.6.svg
# │           ├── fulltext-page.7.svg
# │           └── fulltext-page.8.svg
# ├── vaughey2013
# │   ├── fulltext.pdf
# │   ├── pdfimages
# │   │   ├── image.3.1.49_285.71_275
# │   │   │   ├── images.html
# │   │   │   ├── octree
# │   │   │   │   ├── binary.png
# │   │   │   │   ├── channel.34966a.png
# │   │   │   │   ├── channel.3d4248.png
# │   │   │   │   ├── channel.546395.png
# │   │   │   │   ├── channel.6ba69e.png
# │   │   │   │   ├── channel.c57697.png
# │   │   │   │   ├── channel.c65a63.png
# │   │   │   │   ├── channel.fafafa.png
# │   │   │   │   ├── histogram.svg
# │   │   │   │   └── octree.png
# │   │   │   ├── octree16
# │   │   │   │   ├── channel.2c9466.png
# │   │   │   │   ├── channel.3d4248.png
# │   │   │   │   ├── channel.4b9b75.png
# │   │   │   │   ├── channel.546395.png
# │   │   │   │   ├── channel.6ba69e.png
# │   │   │   │   ├── channel.b4565e.png
# │   │   │   │   ├── channel.b57495.png
# │   │   │   │   ├── channel.ce7899.png
# │   │   │   │   ├── channel.d0616a.png
# │   │   │   │   ├── channel.fafafa.png
# │   │   │   │   └── octree.png
# │   │   │   ├── raw.png
# │   │   │   ├── raw_o16.png
# │   │   │   ├── raw_o8.png
# │   │   │   └── testx
# │   │   │       ├── channel.34966a.png
# │   │   │       ├── channel.3d4248.png
# │   │   │       ├── channel.546395.png
# │   │   │       ├── channel.6ba69e.png
# │   │   │       ├── channel.c57697.png
# │   │   │       ├── channel.c65a63.png
# │   │   │       ├── channel.fafafa.png
# │   │   │       └── octree.png
# │   │   ├── image.3.2.49_285.351_596
# │   │   │   ├── images.html
# │   │   │   ├── octree
# │   │   │   │   ├── binary.png
# │   │   │   │   ├── channel.1f8c56.png
# │   │   │   │   ├── channel.25292d.png
# │   │   │   │   ├── channel.525992.png
# │   │   │   │   ├── channel.71a195.png
# │   │   │   │   ├── channel.bf689b.png
# │   │   │   │   ├── channel.d7474d.png
# │   │   │   │   ├── channel.fdfdfd.png
# │   │   │   │   ├── histogram.svg
# │   │   │   │   └── octree.png
# │   │   │   ├── octree16
# │   │   │   │   ├── channel.1f8c56.png
# │   │   │   │   ├── channel.25292d.png
# │   │   │   │   ├── channel.525992.png
# │   │   │   │   ├── channel.71a195.png
# │   │   │   │   ├── channel.bf689b.png
# │   │   │   │   ├── channel.d4363a.png
# │   │   │   │   ├── channel.d83a43.png
# │   │   │   │   ├── channel.da555a.png
# │   │   │   │   ├── channel.fdfdfd.png
# │   │   │   │   └── octree.png
# │   │   │   ├── raw.png
# │   │   │   ├── raw_o16.png
# │   │   │   ├── raw_o8.png
# │   │   │   └── testx
# │   │   │       ├── channel.1f8c56.png
# │   │   │       ├── channel.25292d.png
# │   │   │       ├── channel.525992.png
# │   │   │       ├── channel.71a195.png
# │   │   │       ├── channel.bf689b.png
# │   │   │       ├── channel.d7474d.png
# │   │   │       ├── channel.fdfdfd.png
# │   │   │       └── octree.png
# │   │   ├── image.3.3.310_546.230_446
# │   │   │   ├── images.html
# │   │   │   ├── octree
# │   │   │   │   ├── binary.png
# │   │   │   │   ├── channel.218e58.png
# │   │   │   │   ├── channel.23262b.png
# │   │   │   │   ├── channel.4f5594.png
# │   │   │   │   ├── channel.6eaa9c.png
# │   │   │   │   ├── channel.be689a.png
# │   │   │   │   ├── channel.d4494f.png
# │   │   │   │   ├── channel.fdfdfd.png
# │   │   │   │   ├── histogram.svg
# │   │   │   │   └── octree.png
# │   │   │   ├── octree16
# │   │   │   │   ├── channel.1a8a52.png
# │   │   │   │   ├── channel.23262b.png
# │   │   │   │   ├── channel.4ba275.png
# │   │   │   │   ├── channel.4f5594.png
# │   │   │   │   ├── channel.6eaa9c.png
# │   │   │   │   ├── channel.be689a.png
# │   │   │   │   ├── channel.d2363b.png
# │   │   │   │   ├── channel.d23a44.png
# │   │   │   │   ├── channel.d8585e.png
# │   │   │   │   ├── channel.fdfdfd.png
# │   │   │   │   └── octree.png
# │   │   │   ├── raw.png
# │   │   │   ├── raw_o16.png
# │   │   │   ├── raw_o8.png
# │   │   │   └── testx
# │   │   │       ├── channel.218e58.png
# │   │   │       ├── channel.23262b.png
# │   │   │       ├── channel.4f5594.png
# │   │   │       ├── channel.6eaa9c.png
# │   │   │       ├── channel.be689a.png
# │   │   │       ├── channel.d4494f.png
# │   │   │       ├── channel.fdfdfd.png
# │   │   │       └── octree.png
# │   │   ├── image.3.4.310_546.502_711
# │   │   │   ├── images.html
# │   │   │   ├── octree
# │   │   │   │   ├── binary.png
# │   │   │   │   ├── channel.060606.png
# │   │   │   │   ├── channel.2f2f2f.png
# │   │   │   │   ├── channel.4d4d4d.png
# │   │   │   │   ├── channel.6e6e6e.png
# │   │   │   │   ├── channel.8f8f8f.png
# │   │   │   │   ├── channel.b1b1b1.png
# │   │   │   │   ├── channel.d0d0d0.png
# │   │   │   │   ├── channel.fefefe.png
# │   │   │   │   ├── histogram.svg
# │   │   │   │   └── octree.png
# │   │   │   ├── octree16
# │   │   │   │   ├── channel.030303.png
# │   │   │   │   ├── channel.171717.png
# │   │   │   │   ├── channel.272727.png
# │   │   │   │   ├── channel.353535.png
# │   │   │   │   ├── channel.474747.png
# │   │   │   │   ├── channel.575757.png
# │   │   │   │   ├── channel.686868.png
# │   │   │   │   ├── channel.767676.png
# │   │   │   │   ├── channel.898989.png
# │   │   │   │   ├── channel.989898.png
# │   │   │   │   ├── channel.a7a7a7.png
# │   │   │   │   ├── channel.b9b9b9.png
# │   │   │   │   ├── channel.c7c7c7.png
# │   │   │   │   ├── channel.d6d6d6.png
# │   │   │   │   ├── channel.e7e7e7.png
# │   │   │   │   ├── channel.fefefe.png
# │   │   │   │   └── octree.png
# │   │   │   ├── raw.png
# │   │   │   ├── raw_o16.png
# │   │   │   ├── raw_o8.png
# │   │   │   └── testx
# │   │   │       ├── channel.060606.png
# │   │   │       ├── channel.2f2f2f.png
# │   │   │       ├── channel.4d4d4d.png
# │   │   │       ├── channel.6e6e6e.png
# │   │   │       ├── channel.8f8f8f.png
# │   │   │       ├── channel.b1b1b1.png
# │   │   │       ├── channel.d0d0d0.png
# │   │   │       ├── channel.fefefe.png
# │   │   │       └── octree.png
# │   │   ├── image.4.1.134_461.311_691
# │   │   │   ├── images.html
# │   │   │   ├── octree
# │   │   │   │   ├── binary.png
# │   │   │   │   ├── channel.3b3e3c.png
# │   │   │   │   ├── channel.488c67.png
# │   │   │   │   ├── channel.4d5797.png
# │   │   │   │   ├── channel.72a095.png
# │   │   │   │   ├── channel.ab8579.png
# │   │   │   │   ├── channel.b5688d.png
# │   │   │   │   ├── channel.ca3b47.png
# │   │   │   │   ├── channel.fcfcfc.png
# │   │   │   │   ├── histogram.svg
# │   │   │   │   └── octree.png
# │   │   │   ├── octree16
# │   │   │   │   ├── channel.36845a.png
# │   │   │   │   ├── channel.394a8e.png
# │   │   │   │   ├── channel.3b3e3c.png
# │   │   │   │   ├── channel.52906e.png
# │   │   │   │   ├── channel.565d9b.png
# │   │   │   │   ├── channel.72a194.png
# │   │   │   │   ├── channel.958578.png
# │   │   │   │   ├── channel.b5688d.png
# │   │   │   │   ├── channel.ca3b47.png
# │   │   │   │   ├── channel.fcfcfc.png
# │   │   │   │   └── octree.png
# │   │   │   ├── raw.png
# │   │   │   ├── raw_o16.png
# │   │   │   ├── raw_o8.png
# │   │   │   └── testx
# │   │   │       ├── channel.3b3e3c.png
# │   │   │       ├── channel.488c67.png
# │   │   │       ├── channel.4d5797.png
# │   │   │       ├── channel.72a095.png
# │   │   │       ├── channel.ab8579.png
# │   │   │       ├── channel.b5688d.png
# │   │   │       ├── channel.ca3b47.png
# │   │   │       ├── channel.fcfcfc.png
# │   │   │       └── octree.png
# │   │   ├── image.5.1.49_285.538_711
# │   │   │   ├── images.html
# │   │   │   ├── octree
# │   │   │   │   ├── binary.png
# │   │   │   │   ├── channel.3e3e3e.png
# │   │   │   │   ├── channel.d84850.png
# │   │   │   │   ├── channel.fdfdfd.png
# │   │   │   │   ├── histogram.svg
# │   │   │   │   └── octree.png
# │   │   │   ├── octree16
# │   │   │   │   ├── channel.3e3e3e.png
# │   │   │   │   ├── channel.dc3946.png
# │   │   │   │   ├── channel.dc565d.png
# │   │   │   │   ├── channel.de3439.png
# │   │   │   │   ├── channel.fdfdfd.png
# │   │   │   │   └── octree.png
# │   │   │   ├── raw.png
# │   │   │   ├── raw_o16.png
# │   │   │   ├── raw_o8.png
# │   │   │   └── testx
# │   │   │       ├── channel.3e3e3e.png
# │   │   │       ├── channel.d84850.png
# │   │   │       ├── channel.fdfdfd.png
# │   │   │       └── octree.png
# │   │   └── image.5.3.310_546.531_711
# │   │       ├── images.html
# │   │       ├── octree
# │   │       │   ├── binary.png
# │   │       │   ├── channel.27272a.png
# │   │       │   ├── channel.3e4093.png
# │   │       │   ├── channel.fefefe.png
# │   │       │   ├── histogram.svg
# │   │       │   └── octree.png
# │   │       ├── octree16
# │   │       │   ├── channel.1a1a1a.png
# │   │       │   ├── channel.2f3074.png
# │   │       │   ├── channel.343690.png
# │   │       │   ├── channel.5b5c99.png
# │   │       │   ├── channel.5d5d5e.png
# │   │       │   ├── channel.fefefe.png
# │   │       │   └── octree.png
# │   │       ├── raw.png
# │   │       ├── raw_o16.png
# │   │       ├── raw_o8.png
# │   │       └── testx
# │   │           ├── channel.27272a.png
# │   │           ├── channel.3e4093.png
# │   │           ├── channel.fefefe.png
# │   │           └── octree.png
# │   └── svg
# │       ├── fulltext-page.0.svg
# │       ├── fulltext-page.1.svg
# │       ├── fulltext-page.2.svg
# │       ├── fulltext-page.3.svg
# │       ├── fulltext-page.4.svg
# │       └── fulltext-page.5.svg
# ├── wang2015
# │   ├── fulltext.pdf
# │   ├── pdfimages
# │   │   └── image.4.1.137_449.59_250
# │   │       ├── images.html
# │   │       ├── octree
# │   │       │   ├── binary.png
# │   │       │   ├── channel.222e23.png
# │   │       │   ├── channel.2526f0.png
# │   │       │   ├── channel.369737.png
# │   │       │   ├── channel.f62627.png
# │   │       │   ├── channel.f677f3.png
# │   │       │   ├── channel.fdfdfd.png
# │   │       │   ├── histogram.svg
# │   │       │   └── octree.png
# │   │       ├── octree16
# │   │       │   ├── channel.222e23.png
# │   │       │   ├── channel.2526f0.png
# │   │       │   ├── channel.369737.png
# │   │       │   ├── channel.f677f3.png
# │   │       │   ├── channel.f71011.png
# │   │       │   ├── channel.f85e5f.png
# │   │       │   ├── channel.fdfdfd.png
# │   │       │   └── octree.png
# │   │       ├── raw.png
# │   │       ├── raw_o16.png
# │   │       ├── raw_o8.png
# │   │       └── testx
# │   │           ├── channel.222e23.png
# │   │           ├── channel.2526f0.png
# │   │           ├── channel.369737.png
# │   │           ├── channel.f62627.png
# │   │           ├── channel.f677f3.png
# │   │           ├── channel.fdfdfd.png
# │   │           └── octree.png
# │   └── svg
# │       ├── fulltext-page.0.svg
# │       ├── fulltext-page.1.svg
# │       ├── fulltext-page.2.svg
# │       ├── fulltext-page.3.svg
# │       └── fulltext-page.4.svg
# └── weppner2011
#     ├── fulltext.pdf
#     ├── pdfimages
#     │   ├── image.2.1.340_532.50_216
#     │   │   ├── images.html
#     │   │   ├── octree
#     │   │   │   ├── binary.png
#     │   │   │   ├── channel.000000.png
#     │   │   │   ├── channel.ffffff.png
#     │   │   │   ├── histogram.svg
#     │   │   │   └── octree.png
#     │   │   ├── octree16
#     │   │   │   ├── channel.000000.png
#     │   │   │   ├── channel.ffffff.png
#     │   │   │   └── octree.png
#     │   │   ├── raw.png
#     │   │   ├── raw_o16.png
#     │   │   ├── raw_o8.png
#     │   │   └── testx
#     │   │       ├── channel.000000.png
#     │   │       ├── channel.ffffff.png
#     │   │       └── octree.png
#     │   ├── image.6.1.134_473.50_170
#     │   │   ├── images.html
#     │   │   ├── octree
#     │   │   │   ├── binary.png
#     │   │   │   ├── channel.000000.png
#     │   │   │   ├── channel.f8f8f8.png
#     │   │   │   ├── histogram.svg
#     │   │   │   └── octree.png
#     │   │   ├── octree16
#     │   │   │   ├── channel.000000.png
#     │   │   │   ├── channel.f8f8f8.png
#     │   │   │   └── octree.png
#     │   │   ├── raw.png
#     │   │   ├── raw_o16.png
#     │   │   ├── raw_o8.png
#     │   │   └── testx
#     │   │       ├── channel.000000.png
#     │   │       ├── channel.f8f8f8.png
#     │   │       └── octree.png
#     │   ├── image.7.1.51_292.50_196
#     │   │   ├── images.html
#     │   │   ├── octree
#     │   │   │   ├── binary.png
#     │   │   │   ├── channel.000000.png
#     │   │   │   ├── channel.f7f7f7.png
#     │   │   │   ├── histogram.svg
#     │   │   │   └── octree.png
#     │   │   ├── octree16
#     │   │   │   ├── channel.000000.png
#     │   │   │   ├── channel.f7f7f7.png
#     │   │   │   └── octree.png
#     │   │   ├── raw.png
#     │   │   ├── raw_o16.png
#     │   │   ├── raw_o8.png
#     │   │   └── testx
#     │   │       ├── channel.000000.png
#     │   │       ├── channel.f7f7f7.png
#     │   │       └── octree.png
#     │   └── image.8.1.51_292.50_409
#     │       ├── images.html
#     │       ├── octree
#     │       │   ├── binary.png
#     │       │   ├── channel.000000.png
#     │       │   ├── channel.454545.png
#     │       │   ├── histogram.svg
#     │       │   └── octree.png
#     │       ├── octree16
#     │       │   ├── channel.000000.png
#     │       │   ├── channel.454545.png
#     │       │   └── octree.png
#     │       ├── raw.png
#     │       ├── raw_o16.png
#     │       ├── raw_o8.png
#     │       └── testx
#     │           ├── channel.000000.png
#     │           ├── channel.454545.png
#     │           └── octree.png
#     └── svg
#         ├── fulltext-page.0.svg
#         ├── fulltext-page.1.svg
#         ├── fulltext-page.2.svg
#         ├── fulltext-page.3.svg
#         ├── fulltext-page.4.svg
#         ├── fulltext-page.5.svg
#         ├── fulltext-page.6.svg
#         ├── fulltext-page.7.svg
#         └── fulltext-page.8.svg
#
# 376 directories, 2510 files

# %%
from IPython.display import display
from PIL import Image
path="PMC3211491/pdfimages/image.3.1.64_532.102_571/raw.png"
display(Image.open(path))

import ipyplot
images_array = [\
            "PMC3211491/pdfimages/image.3.1.64_532.102_571/raw.png",\
            "PMC3211491/pdfimages/image.4.1.64_532.102_336/raw.png",\
            "PMC3211491/pdfimages/image.4.2.313_531.492_708/raw.png",\
            "PMC3211491/pdfimages/image.5.1.63_533.240_708/raw.png",\
            "PMC3211491/pdfimages/image.6.1.63_286.483_698/raw.png",\
            "PMC3211491/pdfimages/image.6.2.311_534.102_322/raw.png"\
]

ipyplot.plot_images(images_array, max_images=20, img_width=300)

# %%
! pwd

# %%
# !ls

# %%
# !ls PMC3211491/pdfimages/image.3.1.64_532.102_571/raw.png

# %%
# !tree PMC3211491

# %%
images_array = [\
"PMC3211491/pdfimages/image.4.2.313_531.492_708/raw.png",\
"PMC3463005/pdfimages/image.6.2.86_509.389_714/raw.png",\
"PMC3518813/pdfimages/image.2.2.129_466.69_338/raw.png",\
"PMC3776197/pdfimages/image.4.2.58_538.371_714/raw.png",\
"PMC3776197/pdfimages/image.5.2.107_488.253_704/raw.png",\
"PMC3776197/pdfimages/image.7.2.113_483.69_352/raw.png",\
"PMC3893646/pdfimages/image.5.2.48_547.69_472/raw.png",\
"PMC4062906/pdfimages/image.5.1.66_281.517_691/raw.png",\
"PMC4148673/pdfimages/image.3.2.63_272.69_527/raw.png"\
]
ipyplot.plot_images(images_array, max_images=20, img_width=300)

# %%
cd PMC3211491/pdfimages/image.4.2.313_531.492_708/octree

# %%
ls channel*.png

# %%
import glob
image_array = glob.glob("channel*.png")
# print (image_array)
image_array2 = ["PMC3211491/pdfimages/image.4.2.313_531.492_708/octree/" + s for s in image_array]
print(image_array2)
# ! cd /Users/pm286/workspace/work/battery10/PMC3211491/pdfimages/image.4.2.313_531.492_708/octree
ipyplot.plot_images(image_array2, max_images=20, img_width=300)

# %%
import os
! cd $PROJECT_WORK
! ls
! pwd
os.listdir(".")
